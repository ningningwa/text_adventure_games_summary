# %% [markdown]
# ## Data for Learning to Speak and Act in a Fantasy Text Adventure Game
#
#
# Facebook AI Research released a dataset for their paper [Learning to Speak and Act in a Fantasy Text Adventure Game](https://arxiv.org/abs/1903.03094).
#
# Here's paper's abstract:
#
# > We introduce a large-scale crowdsourced text adventure game as a research platform for studying grounded dialogue. In it, agents can perceive, emote, and act while conducting dialogue with other agents. Models and humans can both act as characters within the game. We describe the results of training state-of-the-art generative and retrieval models in this setting. We show that in addition to using past dialogue, these models are able to effectively use the state of the underlying world to condition their predictions. In particular, we show that grounding on the details of the local environment, including location descriptions, and the objects (and their affordances) and characters (and their previous actions) present within it allows better predictions of agent behavior and dialogue. We analyze the ingredients necessary for successful grounding in this setting, and how each of these factors relate to agents that can talk and act successfully.
#
# Their data is called the LIGHT dataset (Learning in Interactive Games with Humans and Text).  It contains 663 locations, 3462 objects and 1755 characters.  I have divided this data into training/dev/test splits.

# %% [markdown]
# ## Load the data
#
# The LIGHT data was released as part of the Facebook's ParlAI system. I extracted the data into several JSON files:
# * ```light_environment_train.json``` contains information about the locations, objects, and characters in the text-adventure games.
# * ```light_dialogue_data.json``` contains sample conversations between pairs of characters.   We'll use this later in the semester.

# %%
# !wget https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class-data/master/light_dialogue/light_environment_train.json
# Out:
# --2022-01-30 17:19:15--  https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class-data/master/light_dialogue/light_environment_train.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3541467 (3.4M) [text/plain]
# Saving to: ‘light_environment_train.json’
#
# light_environment_t 100%[===================>]   3.38M  --.-KB/s    in 0.05s
#
# 2022-01-30 17:19:15 (65.6 MB/s) - ‘light_environment_train.json’ saved [3541467/3541467]

# %%
import sys
import os
import json

json_filename = 'light_environment_train.json'

f = open(json_filename)
light_environment = json.load(f)

# %% [markdown]
# # LIGHT Environment Data
#
# This section of the Python Notebook will walk you through the LIGHT environment data to show you the different elements of the JSON file.  We will use different pieces of these to fine-tune GPT3 in order to generate new locations and objects for our own text adventure games.

# %% [markdown]
# ### Categories
#
# The locations in LIGHT environment are grouped by categories.
#
# ```
# categories =  light_environment['categories']
#
# categories
#
#  {'11': 'Graveyard',
#  '12': 'Wasteland',
#  '13': 'Abandoned',
#  '14': 'Mountain',
#  '15': 'Cave',
#  '16': 'Tavern',
#  '17': 'Jungle',
#  '18': 'Trail',
#  '19': 'Town',
#  '2': 'Forest',
#  '20': 'Dungeon',
#  '21': 'Inside Cottage',
#  ... }
# ```

# %% [markdown]
# I split the LIGHT environment data into training/dev/test splits based on cateogries.  Here are the categories that ended up in the training partition.

# %%
def get_categories(light_environment):
  return light_environment['categories'].values()
categories = get_categories(light_environment)

print("\n".join(categories))
# Out:
# Forest
# Shore
# Countryside
# Port
# Swamp
# Lake
# Graveyard
# Abandoned
# Cave
# Trail
# Dungeon
# Outside Cottage
# Inside Castle
# Outside Castle
# Inside Church
# Outside Church
# Inside Temple
# Outside Temple
# Inside Tower
# Outside Tower
# Inside Palace
# Outside Palace
# Farm
# city in the clouds
# magical realm
# netherworld
# supernatural
# underwater aquapolis

# %% [markdown]
# ### Rooms
#
# In text-adventure games, locations or settings are often called "rooms".  Rooms have a primary description of the location, a secondary description of the location with its background information, connections to neighboring rooms, and they can contain objects or non-player characters.
#
# Here's what the data structure looks like for a particular room in LIGHT (room number 62, 'An Unfinished Mausoleum', part of the 'Graveyard' category.
#
# ```
# rooms = light_environment['rooms']
# rooms['62']
#
# {'background': "Bright white stone was all the fad for funerary architecture, once upon a time. It's difficult to understand why someone would abandon such a large and expensive undertaking. If they didn't have the money to finish it, they could have sold the stone, surely - or the mausoleum itself. Maybe they just haven't needed it yet? A bit odd, though, given how old it is. Maybe the gravedigger remembers... if he's sober.",
#  'category': 'Graveyard',
#  'description': 'Two-and-a-half walls of the finest, whitest stone stand here, weathered by the passing of countless seasons. There is no roof, nor sign that there ever was one. All indications are that the work was abruptly abandoned. There is no door, nor markings on the walls. Nor is there any indication that any coffin has ever lain here... yet.',
#  'ex_characters': [204, 75, 156, 720],
#  'ex_objects': [1791, 1792, 439],
#  'in_characters': [203, 203],
#  'in_objects': [1790],
#  'neighbors': [108, 109],
#  'room_id': 62,
#  'setting': 'An Unfinished Mausoleum'}
# ```
#
# The **in_objects** and **in_characters** are people and things that are explictly mentioned  listed in the description or the backstory.  The **ex_characters** and **ex_objects** are objects that are possibly present but not mentioned directly. These characters and objects are referenced by a numeric ID which are stored in a seperate part of the LIGHT environment file.

# %% [markdown]
# Here are the rooms that are in the 'Graveyard' category.

# %%
from collections import defaultdict

rooms_by_id = light_environment['rooms']

rooms_by_category = defaultdict(set)
for room_id in rooms_by_id:
  category = light_environment['rooms'][room_id]['category']
  rooms_by_category[category].add(room_id)

def get_room_name(room_id, rooms_by_id=rooms_by_id):
  return rooms_by_id[room_id]['setting']

def print_rooms_for_category(category, rooms_by_category, rooms_by_id):
  rooms = rooms_by_category[category]
  print(category.capitalize())
  for room_id in rooms:
    print('\t', room_id, '-', get_room_name(room_id))

print_rooms_for_category('Graveyard', rooms_by_category, rooms_by_id)
# Out:
# Graveyard
# 	 702 - Main street
# 	 431 - Abandoned workers shed
# 	 340 - A cursed grave
# 	 62 - An Unfinished Mausoleum
# 	 277 - Graveyard
# 	 661 - Main graveyard
# 	 462 - Dead Tree
# 	 100 - Old Crypt
# 	 158 - the fountain
# 	 162 - Reception area
# 	 144 - Cemetery
# 	 386 - Tombstones of the Kings

# %% [markdown]
# ### Neighbors
#
# Rooms are connected to other rooms.  The LIGHT dataset stores the connections in a variable called ```light_environment['neighbors']```.  Here is an example of what is information is stored about these connections.
#
# ```
#  '108': {'connection': 'walking carefully between fallen headstones',
#   'destination': 'Fresh Grave',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 62},
#  '109': {'connection': 'following a dirt trail behind the mausoleum',
#   'destination': 'Dead Tree',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 62},
# ```
#
# These can be thought of as arcs in a directed graph, where the rooms are nodes, and these elements are the arcs that connect a pair of nodes.  The head of the arc (the ***to node***) is specified by the ```destination``` field (a description rather than an ID), and tail of the arc (the ***from node***) is specified by the ```room_id```.

# %%
arcs = light_environment['neighbors']

# Create a dictionary that maps room names ('setting') to IDs
room_names_to_id = {room['setting']:room_id for (room_id,room) in rooms_by_id.items()}


def make_connections(arcs):
#  direction, connected_location, travel_description
  for arc_id, arc in arcs.items():
    try:
      source_id = str(arc['room_id'])
      target_id = str(room_names_to_id[arc['destination']])
      direction = arc['direction']
      travel_description = arc['connection']
      source_name = get_room_name(source_id)
      target_name = get_room_name(target_id)
      # Print out the room connections in the Graveyard
      if source_id in rooms_by_category['Graveyard']:
        print('====')
        print(source_name, '-->', target_name)
        print(direction)
        print(travel_description)
    except:
      pass

make_connections(arcs)
# Out:
# ====
# An Unfinished Mausoleum --> Dead Tree
# South
# following a dirt trail behind the mausoleum
# ====
# Old Crypt --> Abandoned workers shed
# South
# walking down the cobbled path
# ====
# Cemetery --> Main street
# West
# following the cobblestone path
# ====
# Reception area --> Main graveyard
# East
# walking
# ====
# Tombstones of the Kings --> Church
# North
# exiting the graveyard
# ====
# Abandoned workers shed --> Old Crypt
# North
# walking down the cobbled path
# ====
# Main street --> Cemetery
# South
# traveling the road south
# ====
# Main street --> Cemetery
# East
# following the cobblestone path

# %% [markdown]
# ### Characters
#
#
# Characters have a description, a persona (a first person description of who they are and what their motivations might be), a character type (person, creature or object), a location (```in_room_id```) and an an inventory (```carrying_objects```)
#
# The Gravedigger character is listed in the Unfinished Mausoleum's ``in_characters`` variable.  The ``in_characters`` are characters that are explictly mentioned in the location's ``description`` or ``background`` variables.  In this case, the Gravedigger is mentioned in the Unfinished Mausoleum's ``background variahle``.
# ```
# light_environment['characters']['203']
#
# {'base_form': ['gravedigger'],
#  'carrying_objects': [890],
#  'char_type': 'person',
#  'character_id': 203,
#  'corrected_name': 'gravedigger',
#  'desc': 'You might want to talk to the gravedigger, specially if your looking for a friend, he might be odd but you will find a friend in him.',
#  'ex_room_ids': [100, 349],
#  'in_room_ids': [62],
#  'is_plural': 0,
#  'name': 'gravedigger',
#  'orig_room_id': 349,
#  'personas': ["I am low paid labor in this town. I do a job that many people shun because of my contact with death. I am very lonely and wish I had someone to talk to who isn't dead."],
#  'wearing_objects': [],
#  'wielding_objects': []}
#
#  ```
#  Here are the ``ex_characters`` from the Unfinished Mausoleum.  They are not explicitly mentioned in the room's description or background, but the annotators thought that these characters were the kinds of characters that might be found there.
#
# ```
# for id in "204, 75, 156, 720".split(','):
#   print(light_environment['characters'][id.strip()]['corrected_name'])
#
# thief
# peasant
# mouse
# bat
# ```

# %%
for id in "204, 75, 156, 720".split(','):
  print(light_environment['characters'][id.strip()]['corrected_name'])
# Out:
# thief
# peasant
# mouse
# bat

# %% [markdown]
# Here is the Gravedigger character.  Characters have descriptions, name, and personas.  We'll use personas later in the semester when we look at generating dialogue for characters.

# %%
light_environment['characters']['203']
# Out:
# {'base_form': ['gravedigger'],
#  'carrying_objects': [890],
#  'char_type': 'person',
#  'character_id': 203,
#  'corrected_name': 'gravedigger',
#  'desc': 'You might want to talk to the gravedigger, specially if your looking for a friend, he might be odd but you will find a friend in him.',
#  'ex_room_ids': [100, 349],
#  'in_room_ids': [62],
#  'is_plural': 0,
#  'name': 'gravedigger',
#  'orig_room_id': 349,
#  'personas': ["I am low paid labor in this town. I do a job that many people shun because of my contact with death. I am very lonely and wish I had someone to talk to who isn't dead."],
#  'wearing_objects': [],
#  'wielding_objects': []}

# %%
characters_by_id = light_environment['characters']
characters_by_id['203']

from collections import Counter

def count_character_types(characters_by_id):
  character_types = Counter()
  for character_id in characters_by_id:
    character = characters_by_id[character_id]
    char_type = character['char_type']
    character_types[char_type] += 1
  return character_types

character_types = count_character_types(characters_by_id)
print(character_types)
# Out:
# Counter({'person': 1028, 'creature': 304, 'object': 38})

# %% [markdown]
# ### Objects
#
# Objects are inanimate things in the game.  They have descriptions, locations, and a set of properties that could be used to govern how a player interacts with them.  The properties of objects in the light dataset are
# * is_container
# * is_drink
# * is_food
# * is_gettable
# * is_plural
# * is_surface
# * is_weapon
# * is_wearable
#
# These properties have numeric values associated with them.  The values seem to be something like 0.0 = false, 1.0 = true, 0.5 = possibly.
#
# Here is an example object:
# ```
# light_environment['objects']['1188']
#
#  {'base_form': ['sword', 'Sword'],
#  'desc_entries': 2,
#  'descriptions': ['The sword is very old, you would assume it had once belonged to a legendary warrior.',
#   "The sword's legend is known by everyone, it is famous throughout the land."],
#  'ex_room_ids': [],
#  'holding_character_ids': [],
#  'in_room_ids': [12],
#  'is_container': 0.0,
#  'is_drink': 0.0,
#  'is_food': 0.0,
#  'is_gettable': 1.0,
#  'is_plural': 1.0,
#  'is_surface': 0.0,
#  'is_weapon': 1.0,
#  'is_wearable': 0.0,
#  'link_entries': 1,
#  'name': 'Legendary swords',
#  'object_id': 1188}
#  ```

# %%
light_environment['objects']['1188']
# Out:
# {'base_form': ['sword', 'Sword'],
#  'desc_entries': 2,
#  'descriptions': ['The sword is very old, you would assume it had once belonged to a legendary warrior.',
#   "The sword's legend is known by everyone, it is famous throughout the land."],
#  'ex_room_ids': [],
#  'holding_character_ids': [],
#  'in_room_ids': [12],
#  'is_container': 0.0,
#  'is_drink': 0.0,
#  'is_food': 0.0,
#  'is_gettable': 1.0,
#  'is_plural': 1.0,
#  'is_surface': 0.0,
#  'is_weapon': 1.0,
#  'is_wearable': 0.0,
#  'link_entries': 1,
#  'name': 'Legendary swords',
#  'object_id': 1188}

# %%
obj = light_environment['objects']['1188']
print(obj['name'])
print(obj['object_id'])
for label, value in obj.items():
  if label.startswith('is_') and value == 1.0:
    print(label, value)
# Out:
# Legendary swords
# 1188
# is_gettable 1.0
# is_weapon 1.0
# is_plural 1.0

# %%
objects_by_id = light_environment['objects']

def sort_objects_by_property(objects_by_id):
  objects_by_property = defaultdict(set)
  for object_id, obj in objects_by_id.items(): 
    name = obj['name']
    for label, value in obj.items():
      if label.startswith('is_') and value == 1:
        objects_by_property[label].add(object_id)
  return objects_by_property

objects_by_property = sort_objects_by_property(objects_by_id)

# print 20 objects for each property
for prop in objects_by_property:
  print(prop)
  for counter, object_id in enumerate(objects_by_property[prop]):
    if counter < 20:
      obj_name = objects_by_id[object_id]['name']
      print('\t', obj_name)
# Out:
# is_gettable
# 	 sand
# 	 water buckets
# 	 a barrel
# 	 black rock
# 	 needles
# 	 religious idols
# 	 underground plant-life
# 	 chamber pot
# 	 benches made from wood
# 	 fetilizer
# 	 mace
# 	 a holy book on a shelf underneath the seat
# 	 Daggers
# 	 two home made wooden crosses
# 	 hammer
# 	 finest linens
# 	 cutting board
# 	 bedding
# 	 branches
# 	 silks
# is_plural
# 	 herd some sheep
# 	 water buckets
# 	 needles
# 	 tiles
# 	 fancy dinners
# 	 religious idols
# 	 underground plant-life
# 	 benches made from wood
# 	 fruit trees
# 	 ornate railings
# 	 two home made wooden crosses
# 	 tombs for every empress and emperor
# 	 stalagmites
# 	 finest linens
# 	 open plains
# 	 ceilings
# 	 branches
# 	 jeweled eyes
# 	 beds
# 	 silks
# is_weapon
# 	 whip
# 	 Self-portraits
# 	 black rock
# 	 needles
# 	 compass
# 	 igneous rock
# 	 A broken fishing pole
# 	 stars
# 	 hunting rifles
# 	 garden bench
# 	 broken cutlass
# 	 benches made from wood
# 	 Pitch fork
# 	 a cooking pot
# 	 mace
# 	 a holy book on a shelf underneath the seat
# 	 Swords
# 	 Daggers
# 	 Empty mug
# 	 bows and arrows
# is_surface
# 	 sand
# 	 big table
# 	 wine glasses
# 	 stairs
# 	 table
# 	 black rock
# 	 small table with a candle
# 	 wooden wardrobe
# 	 tiles
# 	 bed
# 	 stone bench
# 	 stage
# 	 Plates
# 	 wooden chairs
# 	 garden bench
# 	 dart board
# 	 chair,
# 	 gentle rolling hills
# 	 a cooking pot
# 	 round stone table
# is_container
# 	 water buckets
# 	 Empty fish tank
# 	 wooden wardrobe
# 	 barrels
# 	 mysterious tent
# 	 empty coin bag
# 	 cargo
# 	 stage
# 	 potion supplies
# 	 chamber pot
# 	 hollowed out tree
# 	 barrel of salted herring
# 	 cases for jewels
# 	 garden
# 	 Empty mug
# 	 tombs for every empress and emperor
# 	 a chamber pot, discreetly hidden
# 	 cauldron
# 	 gold decorations
# 	 jars
# is_wearable
# 	 knights armor
# 	 a king's armor
# 	 Bits for the horses
# 	 some clothes
# 	 many gems
# 	 treasures
# 	 Old ragged clothes
# 	 gold hair
# 	 sea turtles
# 	 Tack for the work horses
# 	 rug
# 	 Chain mail
# 	 brazier
# 	 precious jewels
# 	 jewels
# 	 gold decorations
# 	 crowns
# 	 silks
# 	 variety of drapes
# 	 old armor
# is_drink
# 	 drinks
# 	 a jug of water
# 	 fancy dinners
# 	 potions
# 	 potion supplies
# 	 turquoise color water
# 	 dripping water
# 	 wine
# 	 grog
# 	 gurgling water
# 	 good drinks
# 	 lake
# 	 bodily fluids
# 	 homes
# 	 teapot
# 	 baptism pool
# 	 potions
# 	 Blood
# 	 small lake
# 	 thick water
# is_food
# 	 spiders
# 	 cows
# 	 herd some sheep
# 	 meals
# 	 plants
# 	 leaves
# 	 worms
# 	 dozens and dozens of brim fish
# 	 fruit
# 	 the remains
# 	 salt
# 	 fancy dinners
# 	 wildlife
# 	 grass
# 	 various plants
# 	 candy
# 	 vegetable or plant
# 	 honeysuckle has been allowed to climb the garden wall
# 	 sheep
# 	 crackers

# %% [markdown]
# # Format Data for Fine-Tuning
#
# Below, I show how to create data to fine-tune OpenAI.  The OpenAI API documentation has a [guide to fine-tuning models](https://beta.openai.com/docs/guides/fine-tuning) that you should read.   The basic format of fine-tuning data is a JSONL file (one JSON object per line) with two key-value pairs: `prompt:` and `completion:`.
#
# ```
# {"prompt": "<prompt text>", "completion": "<ideal generated text>"}
# {"prompt": "<prompt text>", "completion": "<ideal generated text>"}
# {"prompt": "<prompt text>", "completion": "<ideal generated text>"}
# ...
# ```
#
# In the code below, I'll extract a prompt that contains the `Category` and `Setting` variables from a LIGHT Environment room, and I'll have the completion be the room's `Description`.

# %%
def get_room_description(room_id, rooms_by_id, light_environment):
  """
  This generates a prompt and a completion which can be used to fine-tune OpenAI.
  This version just gnnerates 
  """
  prompt = ""
  completion = ""
  prompt += "Category: {category}\n".format(category=rooms_by_id[room_id]['category'].capitalize())
  prompt += "Setting: {setting}\n".format(setting=rooms_by_id[room_id]['setting'].capitalize())
  completion += "Description: {description}\n".format(description=rooms_by_id[room_id]['description'])
  completion += "###\n"

  return prompt, completion


def create_location_finetuning_data(filename='fine_tuning_location_descriptions.jsonl'):
  fine_tuning_data = []
  for category in categories:
    rooms = rooms_by_category[category]
    for room_id in rooms:
      data = {}
      prompt, completion = get_room_description(room_id, rooms_by_id, light_environment)
      data['prompt'] = prompt
      data['completion'] = completion
      print(prompt, end="")
      print(completion)
      fine_tuning_data.append(data)

  with open(filename, 'w') as out:
    for data in fine_tuning_data:
        out.write(json.dumps(data))
        out.write('\n')

create_location_finetuning_data()
# Out:
# Category: Forest
# Setting: Woodlands
# Description: The lush hunting grounds cover acres of land, tall trees and thickets of bushes sprawling across the land. Fields of open land are under the deep blue sky, showing the depth of the landscape. The grounds forest is thick but full of light, letting the multitude of wildlife be seen by the naked eye. The abundance of greenery makes it a prime location for hogs and oxen as they explore the land.
# ###
#
# Category: Forest
# Setting: Forbidden forest
# Description: The forbidden forest is a dark and very scary place. The trees are covered in spider web nets and huge spiders. The forest echoes sounds of witches' laughs and creepy crawly animals.  There is a brisk breeze that runs through the trees that will put chills down your spine.
# ###
#
# Category: Forest
# Setting: North forest
# Description: Filled with huge trees, the forest is home to many types of animals. Huge predators such as tigers and bears roam the grounds as do small animals like squirrels. Colorful birds fly among the trees. Wildflowers grow on the ground. Dappled sunlight streams through the huge canopy of trees.
# ###
#
# Category: Forest
# Setting: Ant hill
# Description: The ant hill is very large, over 5 feet high, and is wrapped around the base of a pine tree. The ants are huge compared to normal ants, and jut in and out of large holes in the ant hill. Bones of animals and even people can be seen sticking out of the red dirt ant hill.
# ###
#
# Category: Forest
# Setting: Unsettling forest area
# Description: The forest is actually very creepy even during the day. The trees are so tall that they block the sunlight. There is always fog in the forest which makes it very hard to see. There are a lot of mushrooms near the trees and none of them are edible
# ###
#
# Category: Forest
# Setting: A wooded magical village
# Description: The village lay hidden in a secret grotto that is set in a sort of valley between trees. The village is populated by child-like peoples who wear clothes made of various plant matter such as large leaves and vines. The homes are made of wood, and seemingly blend into the green dense backdrop.
# ###
#
# Category: Forest
# Setting: Entrance to the pine trees
# Description: Very tall and towering pine trees that create a dark canopy of shade. Long skinny trees sway in the sky from the soft breeze. Pine needles scatter the ground like plush carpet.
# ###
#
# Category: Forest
# Setting: Woods
# Description: The woods are vast. Everywhere you turn it all looks the same. There are scratches on the trees from lost travelers marking their path. There are sounds coming from everywhere and yet no where. There are faint yellow circles up in the trees and bushes, possibly eyes starting at you.
# ###
#
# Category: Forest
# Setting: Along the banks of a river in the forest
# Description: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.
# ###
#
# Category: Forest
# Setting: Mysterious forest outskirts
# Description: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.
# ###
#
# Category: Forest
# Setting: Riverbed
# Description: With clear air and the sound of gurgling water near it, the river bed is silty and muddy. The river rushes by the land as more and more dirt separates from the land. The land of the riverbed slick with mud and filled with bugs and worms/
# ###
#
# Category: Forest
# Setting: South forest
# Description: The forest is lined with tall trees but has a long walkway for travelers. I the middle of the forest is a long river surrounded by tall grass with clear blue waters and lots of colorful fish.
# ###
#
# Category: Forest
# Setting: The brush den
# Description: The entryway to the brush den is made of arched bushes and various plants, as is the ceiling and walls. The inside is furnished with seats made of plant roots that have grown together, and a table made of wood adorned with flowers and wooden cups and plates. A small vine dangles with a glowing floor from the middle of the ceiling that lights the room dimly. Three small beds lay in one corner of the room made of interlaced grass and leaves.
# ###
#
# Category: Forest
# Setting: Firewood forest
# Description: The forest has many trees. The majority of the trees are green however a few are orange and red. The forest is huge and seems to never end.
# ###
#
# Category: Forest
# Setting: Picnic area
# Description: In this picnic area, there is a wide clearing with some cut down tree stumps made for people to sit and enjoy their lunch.  There's also a small pond nearby where people can feed fish and watch turtles sunbathe.
# ###
#
# Category: Forest
# Setting: Fairy forest
# Description: The fairy forest is full of brightly colored flowers that grow up to 30 feet tall.  There are also ornate birds that live here.  When you whistle, a fairy will come to you and tweak your nose.  They don't like a lot of nose so it irritates them enough for them to come out of their homes made from watermelon skins.
# ###
#
# Category: Forest
# Setting: A room hidden in the dense canopy
# Description: Its a large room with types of beings you have never seen before. There is a counter and a person who greets people suprise when you arrive because you are not one of them. The room has an unfamiliar feel to it. with doors leading to walkways, other buildings, an entire city
# ###
#
# Category: Forest
# Setting: Forest entrance
# Description: The path quickly narrows and darkens upon entering the forest.  Dense branches overhead block all but a few stray rays of sunshine.  Fallen leaves just beginning to rot blanket the forest floor, and every footstep kicks up a rich, loamy scent as fresh ground is unearthed.
# ###
#
# Category: Forest
# Setting: Flower garden
# Description: This clearing is in reveal a wide circle of trees. Proud oaks stand close enough that only the smallest of fauna can squeeze through, protecting the garden within from curious deer and hungry rabbits. Flowers of every hue and shade crowd the soft lawn of grass, soaking up what light they can through the shadows cast by the branches above. Purple, yellow, red, blue - even green blossoms bob in the breeze, their scents mixing to create a heady perfume. Vines and creepers climb up the tree trunks, dripping with grapes and berries.
# ###
#
# Category: Forest
# Setting: The clearing
# Description: the clearing is surrounded by old pine trees where knights used to practice swinging their swords. There are haystacks where they take wenches and pay them a sickle.
# ###
#
# Category: Forest
# Setting: The stream
# Description: The stream is always going. The water moves quickly in some places and slowly in other places. There is a dry spot on each side of the water. In some areas you will see animals drinking the water. There are also fish swimming around in the deeper parts of the stream.
# ###
#
# Category: Forest
# Setting: Pine tree graveyard
# Description: Once known as a forest of solitude, the entrance to the pine trees is now a bleak and dreary graveyard.  Dead grass and moss fill the ground along with crawling critters that mark fear in the mind among the he who venture here.  Tombstones so old many of the names are no longer eligible.  Dense fog surrounds the area, thick tree tops blotting out the sunlight, and an eerie silence fills the air.  Cold it feels, the air, but the ground is soft and warm.  Sound can not enter, no escape this dwelling.
# ###
#
# Category: Forest
# Setting: Pond
# Description: A small area with a body of water in the center along with turtles, frogs, and other wildlife that live here.  Surrounding this pone are a dense set of trees along with some rocks here and there.
# ###
#
# Category: Shore
# Setting: Enchanted light house
# Description: Slightly rusted and corroded from the crashing waves, elegant and tall. each window and opening is lined with a bronze trim.  Some gears can be seen turning along the side, rotating a middle section of the light house.
# ###
#
# Category: Shore
# Setting: A battleship
# Description: It is a glamorous wooden ship.  It glistens like there are diamonds encrusted on the hull.  There are ornate railings on the stairs as it is a massive boat.  There is even a sea monster on the bow, complete with jeweled eyes and gold hair.
# ###
#
# Category: Shore
# Setting: King's quarters
# Description: The room is large. The largest of all the throne rooms. The carvings on the wall are ornate and historical. The room is clearly built for royalty. The bed is covered in designed covers. It is truly a sight to see.
# ###
#
# Category: Shore
# Setting: Fishing pier
# Description: A spindly, long fishing pier that sits right outside the village. Barnacles cover its pilings in vast numbers. Many villagers can be seen fishing atop of it. Birds and pelicans squawk and fly above it.
# ###
#
# Category: Shore
# Setting: Large cliffs
# Description: Towering cliffs of gray granite line the coast. A few meters of sand lie between the ocean and the base of the cliffs.
# ###
#
# Category: Shore
# Setting: The beach
# Description: Sand that is white as snow. the water is as clear as a crystal. down the shore is some cliffs
# ###
#
# Category: Shore
# Setting: Old docks
# Description: The shore near the docks. There is fog except on rare occasions. More dangerous than most people would like. You never know what dangers luck from creatures leaving and entering the waters.
# ###
#
# Category: Shore
# Setting: Turquoise shore
# Description: A beautiful turquoise color water by the shore. It is filled with many gems and gold.
# ###
#
# Category: Shore
# Setting: Pier walkway
# Description: On the seashore facing the pier, seagulls squawk as they swirl overhead. The smell of salt fills the air, and the gentle, dull roar of the waves lapping the beach is omnipresent. A gentle breeze blows, and the chatter of the villagers fishing drifts down to the shoreline from the pier.
# ###
#
# Category: Shore
# Setting: Coast
# Description: The coast seems to stretch on for miles in either direction.  The ocean itself has receded some and the tide has not yet rolled in.  The water laps half-heartedly at the sand and the glistening shades of seashells dot the wet sand.  All around the sand gleams a shade of white.
# ###
#
# Category: Shore
# Setting: Throne room
# Description: ornate and luxurious, the throne room gleams with gold and precious jewels. Priceless painting of past kings line the sides. underneath a vaulted ceiling regal a red carpet connect the throne room entrance to the golden throne itself.
# ###
#
# Category: Shore
# Setting: Beach house
# Description: A marvelous beach house that sits upon the fine white sand of the beach. It looks mighty expensive, as the house has solid gold walls. A gigantic and lavish marble pier extends into the ocean out in front of the house.
# ###
#
# Category: Shore
# Setting: Lighthouse
# Description: The lighthouse is an off-white color, towering fifty feet over the shore. The light from the building extends out for miles past the shoreline.
# ###
#
# Category: Shore
# Setting: Beach house
# Description: the beach house is falling apart due to the storms, it's door is hanging and it's humid inside. There is no floor, just sand, and a hole to serve as the outhouse.
# ###
#
# Category: Countryside
# Setting: The forest
# Description: The forest has many trees. It has other plants too. There are animals and many livings things. The forest is very much full of life. When you look at it you might only see plants that are green and different shades of brown but there are many other living things in there too.
# ###
#
# Category: Countryside
# Setting: Peasant's cottage
# Description: The peasant's cottage is a fairly simple wood building with a straw thatched roof.  Inside, you have a fireplace and large pot for cooking, a long wooden dinner table, and some hay filled beds lying on the floor.  There are two chests lying inside with personal belongings such as clothes and family heirlooms.
# ###
#
# Category: Countryside
# Setting: Meadow
# Description: Large clear outdoor meadow. Flowers of blue and white appearing in bunches here and there. The grass glows with a green light. Not much can be said about its appearance, however there is a mystical allure associated with the place as if a meadow for spirits instead of livestock.
# ###
#
# Category: Countryside
# Setting: Valley of doom
# Description: The Valley of Doom is overrun by dead trees and grasses.  Eerie looking animals peer at you through the brushes.  It is a dark and wicked place.
# ###
#
# Category: Countryside
# Setting: A cabin
# Description: Plain, pretty basic wooden cabin.  In a field of wildflowers, there is also a pen for the chickens, a clothes line.
# ###
#
# Category: Countryside
# Setting: Nearby road
# Description: The road cuts through the countryside. It is a dirt road, with a fence lining the eastern side and a grassy meadow to the west.
# ###
#
# Category: Countryside
# Setting: Countryside
# Description: The countryside is quite nice, it's not filled with a lot of people but with travelers here and there. Some in small groups some on their own. They are hosting a campfire where everyone has some to sit and is telling stories about their adventures. Someone is showing local children how to wield some weapons. Another is offering lodge, and stable for travelers and their animals.
# ###
#
# Category: Countryside
# Setting: Meadow
# Description: This meadow is composed of green, luscious, rolling hills. Flowers dot the expanse. In the evening, one may stand from the hills of this meadow and see the sun set beneath the horizon off in the distance.
# ###
#
# Category: Countryside
# Setting: Main gate
# Description: The main gate is tall and strong enough to protect the mansion from invaders, and has large wooden doors reinforced by planks and steel sheets. There are two towers on either side of the gate for the town's watchmen to use as their post.
# ###
#
# Category: Countryside
# Setting: Lush meadow in the country side
# Description: Green large trees surround the meadow that if filled with beautiful seasonal flowers. A deer is grazing in the far end of the field. A small dirt country road gentle crooks past on the outside of the road.
# ###
#
# Category: Countryside
# Setting: Cottage
# Description: The small cottage was white with two, shuttered windows. It was in the unique shape of a circle and was built of plaster. Smoke billowed from the chimney.
# ###
#
# Category: Countryside
# Setting: Hillside mansion
# Description: I sweeping villa that rests on the grand hills. Everyone can see how grand it is when they approach from the country road. A tall, wrought-iron fence surround its grounds, which extends for miles.
# ###
#
# Category: Countryside
# Setting: Flower field
# Description: The flower field contains acres of wild growing flowers that are a bright pink when they are in bloom. There are woods surrounding it, but no trees in the field, only flowers. There are paths that work their way through the field.
# ###
#
# Category: Countryside
# Setting: Maidens cottage
# Description: Free standing in the vast countryside, with gentle rolling hills and lush green grass and vegetation sits the cottage. There are a couple of Oak trees close to the cottage as the only tall trees around for miles. Colorful Dandelions, perennials, and daisies grow wildly and freely along the hills.
# ###
#
# Category: Countryside
# Setting: Path to the manor
# Description: The outside of the manor is rather imposing with a large stone building and two immense guardian sculptures on the outside depicting mythical beasts. There are also small gardens to the left and right.  The main path itself is a cobbled one that only beckons visitors if they are worthy enough.
# ###
#
# Category: Countryside
# Setting: Chicken pen
# Description: The chicken pen has wire cages situated on three different levels, with hay at the bottom for the chicken's to sit in. There lie small holes in the cages for the eggs to fall through and be easily harvested by the farmers. The old wooden walls of the chicken pen are beginning to deteriorate and show signs of age.
# ###
#
# Category: Countryside
# Setting: Pig pen
# Description: A filthy pen where tons of squalling pigs rut and throw a ruckus, Their snorts and farts can be heard from any passerby miles before getting to the pen. The pig pen is a few feet from Farmer Bob's cottage. The pigs never sleep and are always eating and playing in the mud.
# ###
#
# Category: Countryside
# Setting: Hillside manor
# Description: A quaint manor that sits in the rolling hills. It is surrounded by a small stone fence and looks quite inviting to passersby. It looks like any other home that a well off business man would own.
# ###
#
# Category: Countryside
# Setting: Horse field
# Description: The horse field includes a huge plains for horses to ride. The fields are yellow and green. The place smells of musk and horse.
# ###
#
# Category: Countryside
# Setting: The small dirt road
# Description: This small dirt road is flanked by a lush green forest on each side with birds chirping and the occasional deer running about.  Sometimes, you can find broken down wooden wagons left behind from ambushes carried out by bandits.
# ###
#
# Category: Port
# Setting: The docks
# Description: The docks are a rough place with a lot of rough group of individuals who hang out there.  It is where the ships port and deport, only few know what really goes on there.
# ###
#
# Category: Port
# Setting: Boat house
# Description: A small house type establishment that serves as a hang out for people about to board the boats.  There is nautical themed decor everywhere.  Life Buoys, mounted fish, replica boats.  It's all wood inside with a bar as well.  A lot of creaky looking wood too, probably weathered a good bit as the house is old itself.
# ###
#
# Category: Port
# Setting: Fishing store
# Description: This store is a small one room stone building with wares laid about on tables.  One can see fishing poles, wooden buckets with dirt and bait inside, along with some mounted trophies.
# ###
#
# Category: Port
# Setting: Wharf
# Description: The waves lash gently against the wooden posts, the water here has always been calm and passive, it seems to represent the people of this small town. The fishermen here are not boisterous, they are quiet, at least when it comes to sound. They'll talk your ear off if you let them, they have lots of stories to tell. The pier here is long, it extends at least forty feet into the ocean, many ships are anchored to it, many people traverse down it buying and selling their local catches.
# ###
#
# Category: Port
# Setting: Pirate ship
# Description: A majestic, shimmering, black pirate ship sits upon the water. Its numerous cannons give it a menacing look. Tons of pirates hop upon its decks in a furious jig. The lone captain plods around in his cabin, plotting on where to seize his treasure next.
# ###
#
# Category: Port
# Setting: Port skyline
# Description: The local port sits an a majestic inlet of the ocean. The countless docks are constantly bustling with new arrivals and departures. People of all kinds come here for business or leisure. On the shore sits a skyline of many buildings packed with residents going about their day. The smell of salt and seafood fills the air.
# ###
#
# Category: Port
# Setting: Port tavern
# Description: The port tavern is the shadiest of all the shady bars in the city. Every night, on its grimy stools at the wooden bar, you can find some of the slimiest sailors in the world. The walls are of peeling blue paint and are always dripping with condensation. Women of ill-repute line one wall, old men on the verge of passing out line another. The floor is littered with trash, barnacles, and bodily fluids. Tending the bar is a small, round man with a bushy mustache.
# ###
#
# Category: Port
# Setting: Warehouses
# Description: The warehouses are the largest structures in the port, rising well above the adjoining buildings. Constructed from virgin timber, the beams overhead support lofts that are filled to capacity with boxes, crates, and barrels full of goods from all over the world. Carefully checking each parcel that crosses the doorway, the warehouse manager knows exactly where everything belongs inside.
# ###
#
# Category: Port
# Setting: Dock
# Description: There are creaky wooden walkways with empty sections where boats can rest.  There are a few buildings surrounding this area that sell supplies to sailors.
# ###
#
# Category: Port
# Setting: Loading dock
# Description: The loading dock is filled with life and movement. Many trucks back up into the
# ###
#
# Category: Port
# Setting: Fish market
# Description: The port is filled with many different small shops that sell fishes caught throughout the day. It is incredibly loud and busy with many customers and fisherman walking around and haggling for a good price on the fishes. There are tons of boxes sitting on the floors everywhere filled with ice, fish, and the fishermen's belongings.
# ###
#
# Category: Port
# Setting: Marketplace
# Description: Merchants call out their wares and try desperately to get the attention of the wealthier passerby. People from all over the world hustle to and fro, some keenly eyeing the many tapestries, spices, tools and foods, others openly staring in wonder. Still others hurry along, heads down and avoiding eye contact. Colors, smells and sounds assault the senses. The cries of the gulls can hardly be deciphered from the chatter of the crowds, the ringing of the blacksmith's hammer, the bells of the nearby shipyard, and the hollers of the merchants.
# ###
#
# Category: Port
# Setting: Supply store
# Description: With so many ships docked at the port, sailor from all the ships crowd the bazaar. The supply store is filled with buyers today. The inside is plain and unadorned. Sturdy shelves hold common supplies. Along the walls are the larger items for sale.
# ###
#
# Category: Port
# Setting: Royal shipyard
# Description: A massive shipyard with different Five dry docks. each dry dock has several wooden cranes and rope works. The dry docks are made of stone and the water gate is all harden wood.
# ###
#
# Category: Port
# Setting: Crew berthing
# Description: The main quarters for the crew of the vessel. Its dirty, smelly and not a place where anyone but a pirate would want to stay. There are bunks stacked on bunks the place is cramped and no one goes there for any reason besides sleeping.
# ###
#
# Category: Port
# Setting: Ferry terminal
# Description: A huge terminal with a lot of traffic. The Ferry Terminal has a warm and positive vibe that welcomes all travelers across the land. It has an open space with a lot of illumination during the night.
# ###
#
# Category: Port
# Setting: Large galleon
# Description: The deck of this rather large ship is strong and freshly swapped with tar. Its mast reaches far into the sky like gleaming pillar of hope and freedom. Its sturdy ship made for long voyages with thick planks and strong rails.
# ###
#
# Category: Port
# Setting: Captain's cabin
# Description: The captain's cabin is a complete mess. There are multiple maps on the wall, pinned over one another, each with messy writing scrawled over it and multiple X marks in random places. Papers overflow off the desk and across the floor in waves, impeding the captain as he paces, muttering angrily. The bed is messy and unmade, giving the impression that the captain has spent the night tossing and turning. Random objects have been thrown about the room.
# ###
#
# Category: Port
# Setting: Fishmonger's stall
# Description: A small booth near the edge of the port, it's protected by a piece of old, sun-bleached sailcloth. Baskets of freshly-caught fish, bivalves, and eels sit in the shade in stained wooden troughs of water. A small, aggressive-looking dog is chained to one table, presumably to keep cats away. The stall is redolent with the aroma of fish.
# ###
#
# Category: Port
# Setting: Quay
# Description: During the day, the quay is bustling with typical activity of a port: burly longshoremen carry crates and roll barrels away from ships for storage and sailors who still have their sea-legs saunter past on their way to drink and more adventures. By night, the quay is teeming with unsavory characters: men who are hardly men any more after losing their way through drink and gambling hunker amongst coils of rope stiffened by the salt water while rats scramble from box to box gnawing their way into the goods contained inside.
# ###
#
# Category: Port
# Setting: Dock at the port
# Description: This dock has seen better days.  It is wobbly and broken in areas.  There are holes through to the ocean below if you are not careful.  It is covered with every means of trash.
# ###
#
# Category: Port
# Setting: The village of tamerak
# Description: A thriving sea port filled with merchants, foods, women, and gold.  Hundreds of boats fill the shores, fisherman pushing out to sea and pulling into dock.  Seagulls hover silently above the merchants selling fish.  Pirates can be seen causing trouble with the locals.  Brothels and bars are in abundance, as well as the smell of fish.
# ###
#
# Category: Swamp
# Setting: Murky water
# Description: The water is murky and dark. There are unknown dangers lurking in it, such as alligators and poisonous snakes. Plants and trees hide more dangerous animals. It is cold.
# ###
#
# Category: Swamp
# Setting: Haunted swamp
# Description: A misty, foggy area with the swamp. It is dirty and smelly.
# ###
#
# Category: Swamp
# Setting: Boathouse
# Description: The boathouse is a very small building with peeling paint. It is made out of wood, with one half planted in the water on stilts. Inside, there are boats floating in the water. There are hinged doors which can be opened to allow boats to come in and out. There are some ropes and other tools a boater may need stored in the boathouse.
# ###
#
# Category: Swamp
# Setting: Darkest part of the swamp
# Description: The light doesn't pierce the heavy overhanging trees in this near pitch black area of the swamp.  The water is extremely murky and there are occasional fins poking up from the water belonging to some kind of creature.  The air is thick and heavy and insects constantly buzz about.
# ###
#
# Category: Swamp
# Setting: Soldiers camp
# Description: The camp is hidden away in a light forest of trees and brush that might be hard to find if there had not been a symbol on the trees leading up to it. You can feel the anxiety of the soldiers here, as this camp is not well fortified by any conventional means, but instead is supposed to be hidden and camouflaged to throw off anyone that might pursue. The camp is nothing more than a fire and some barracks. Nothing fancy to see.
# ###
#
# Category: Swamp
# Setting: Witch's house
# Description: Old and worn by the time that has passed and the environment where it was built, the wood rotted and worn by the swamp. It should have sunk years ago into the swamp but somehow it remains standing despite the ever sinking earth around it.
# ###
#
# Category: Swamp
# Setting: Troll's bridge
# Description: Muddy and murky waters lie under a bridge that seems to go nowhere. It is made of cobblestone and just as long as it is wide. Beneath it live a hideous troll that makes people pay to cross.
# ###
#
# Category: Swamp
# Setting: A military outpost at the heart of the swamp
# Description: Moist, and murky the bog remained. As you reach the outpost that description doesn't change seeing the bog gobbers swimming through the thick water, and fermenting goblins perched atop the outpost's walls.
# ###
#
# Category: Swamp
# Setting: Bank
# Description: This is a grassy area that surrounds much of the swamp.  It's a plain field with some trees nearby along with some rocks.
# ###
#
# Category: Swamp
# Setting: Bog
# Description: Frogs croak in the reeds that surround the bog. The water is very murky and underneath the surface tadpoles dart around. There are minimal places to stand to stay dry.
# ###
#
# Category: Swamp
# Setting: Quicksand pit
# Description: A large, gurgling pit of quicksand. Many adventurers and poor critters lie at the bottom of the pit. The pit is surrounded by an extensive swampland and is shielded by the many trees and shrubs that surround it.
# ###
#
# Category: Lake
# Setting: The lagoon
# Description: The Lagoon is a dark and mysterious place during the night hours.  A lot of moss and lily pads surround the shore.  The water is very murky.
# ###
#
# Category: Lake
# Setting: Lake
# Description: The beautiful lake glistens in the sun as water can be seen in all directions. you can see several feet beneath the water because it is so clear.
# ###
#
# Category: Lake
# Setting: Northern shore
# Description: The lake gives way to a slightly sandy and rocky shore. It is dotted with small shrubs and a few trees, but mostly it is a fairly open expanse. It is covered in places by a green short grass. The lake level falls away swiftly from the beach going from a few feet to well over ten feet in a short span.
# ###
#
# Category: Lake
# Setting: Clean water lake
# Description: The lake is crystal clear, lined with trees, to the far back of the lake there's a small formation of rocks almost like a small waterfall allowing water to flow into the lake. It's quite beautiful, the sun bathing the surrounding area in a warmth so comforting you could easily fall asleep on the shore. There's an old wooden bath, for its age it seems to look like almost new, and rarely used. There are no animals nearby except for birds softly chirping in the trees.
# ###
#
# Category: Lake
# Setting: Dock
# Description: The wood used to make the dock is of highest quality, commissioned from trees that stand towering in the local forests. Despite time having passed it has been taken care of to the point where even a hint of warping from the water beneath will have a plank torn and replaced within a night.
# ###
#
# Category: Lake
# Setting: Brim canal
# Description: Slow flowing branching from the large lake, is the brim canal where dozens and dozens of brim fish call it home. The edges are lined with irregular rocks and lush green vegetation. Tall pine trees overlook the canal and lake making it a peaceful place to just go sick and watch the brim swim by.
# ###
#
# Category: Lake
# Setting: Fishing shack
# Description: The fishing shack is a small wooden structure that is crudely built and is surrounded by boats. The wood flooring around the shack is well weathered and often used.
# ###
#
# Category: Lake
# Setting: Lakeside house
# Description: Its white and vibrant, certainly a location for some lord, It has 3 floors, and fine gardening surround the house. Its open and breezy this place is calm and peaceful.
# ###
#
# Category: Lake
# Setting: The swimming hole
# Description: The swimming hole is calm and clear.  The sun sparkles off the ripples that form on the surface of the water.  Fish occasionally jump from the water and splash back in.
# ###
#
# Category: Lake
# Setting: Fishing dock
# Description: Folks call the area a Lake, but it's more like a pond.  Small and unimportant looking, yet peaceful.  The dock is no prize winner either.  Narrow in width, boards broken with several down right missing all together!  No tree nearby, no canopy, nothing to shade oneself on a hot day while fishing.  The watering hole may look small in size, but it deceives the eyes.  The water is as deep as the heavens.  No man knows what lurks beyond the light in this Lake.
# ###
#
# Category: Lake
# Setting: Drinking water lake
# Description: Surrounded by skittering chipmunks and chirping crickets, the drinking lake teems with life. Flora and fauna both thrive near the pristine waters. Tall thick plant life surrounds the lake, with strong roots and stems protruding from the nutrient rich soil. The lake water shimmers in the sun, so clear and clean that one can see the rock lake floor many feet below.
# ###
#
# Category: Lake
# Setting: Island
# Description: This island is located in the center of a lake. It is smaller than a ship and covered in moss.
# ###
#
# Category: Lake
# Setting: Launching point
# Description: The Launching point features a number of large wooden planks sitting at a downward slope going straight into the water.  On each side of the launching point there sits a large, ornate bronze figure of a light house that is used to tether the ships to the dock and keep them from casting away while the sailors prepare to board the ship. The launching point is very narrow, with large stone braces on either side of the dock.
# ###
#
# Category: Graveyard
# Setting: Main street
# Description: main street is bleak and outdated. it wears the atmosphere of the cemetery based on association. it is dark even in sunlight and has a unique odor
# ###
#
# Category: Graveyard
# Setting: Abandoned workers shed
# Description: Moss now grows across what was once a red painted wooden shed, standing in the area just outside the graveyard. The wood shed is splintering, and there is evidence that termites have eaten away at the walls as holes poke through the shed. Inside the shed there lies leaves and plants that have been dragged in their by the wild animals that at one point called the abandoned shed their home.
# ###
#
# Category: Graveyard
# Setting: A cursed grave
# Description: The sun never seems to shine on this grave.  The letters on the tombstone have long since faded, and many stories are told about whose bones lay buried in the dirt.  Until recently, it was overgrown with grass and weeds.  Someone had come and cleared the weeds, and the dirt looked as if it had been turned over.
# ###
#
# Category: Graveyard
# Setting: An unfinished mausoleum
# Description: Two-and-a-half walls of the finest, whitest stone stand here, weathered by the passing of countless seasons. There is no roof, nor sign that there ever was one. All indications are that the work was abruptly abandoned. There is no door, nor markings on the walls. Nor is there any indication that any coffin has ever lain here... yet.
# ###
#
# Category: Graveyard
# Setting: Graveyard
# Description: The dark and gloomy graveyard has fog all the time and has a large amount of graves everywhere you step. There are whispers and shadows that appear from the darkness and there is always a light drizzle that seems to moisten the place.
# ###
#
# Category: Graveyard
# Setting: Main graveyard
# Description: This is an ominous place that a thick fog envelops.  There are rows of primitive gravestones and crosses along with some angelic statues for the more wealthy.  You can hear sobs in the distance as a funeral ceremony is underway.
# ###
#
# Category: Graveyard
# Setting: Dead tree
# Description: The dead tree is many, many decades old. It lies on its side, and is rotted through and through. It is blackened on its top. It is humongous. It would have been very, very tall once upon a time. It smells dank. It cannot be moved.
# ###
#
# Category: Graveyard
# Setting: Old crypt
# Description: Broken stones and a iron gate closing the entrance with a name placard that the name is worn off.
# ###
#
# Category: Graveyard
# Setting: The fountain
# Description: the fountain is the only thing you can hear in the graveyard. It's eerily quiet, not even a bird chirping. The fountain is teen feet high, and it is dry as a desert. It makes the graveyard more eerie than any other one.
# ###
#
# Category: Graveyard
# Setting: Reception area
# Description: The building itself is ordinary in appearance and is somewhat foreboding.  It is surrounding by a dense fog and high grass.  Sometimes, one can hear whispers in the wind.
# ###
#
# Category: Graveyard
# Setting: Cemetery
# Description: Dim and low lit. The aura from this cemetery emits sadness and pain perpetually. You can feel and sense the eerie nature of the graveyard crawl up your spine. There seems to be a slight fog slowly making its way across the open parts of the cemetery.
# ###
#
# Category: Graveyard
# Setting: Tombstones of the kings
# Description: The tombstones of the kings are the most notable part of the graveyard. These tombstones are erected from fine marble and have piles of gold and riches lying next to them. A small metal fence surrounds this section of the graveyard, and cuts it off from the common folk.
# ###
#
# Category: Abandoned
# Setting: An abandoned castle on an ocean cliff side
# Description: The castle is located at the top of an erosive cliff face of a vast ocean. An entire wing of the castle appear to have collapsed into the ocean due to the erosion of the cliff face, perhaps the reason why the castle now lay abandoned.
# ###
#
# Category: Abandoned
# Setting: Weathered shack
# Description: A weathered shack with a roof made of old broken tiles sits in the middle of the forest. The wood is starting to split and the shack appears as if it will crumble at any moment.
# ###
#
# Category: Abandoned
# Setting: A lonely island
# Description: the island only has one coconut tree and waves crashing and appearing missing wooden boat parts. The pirates are nowhere to be seen.
# ###
#
# Category: Abandoned
# Setting: Abandoned mine entrance
# Description: The abandoned mine is located in a field with a few trees. It is unable to be seen from far away. The closer you get the more you  notice the ground caving in around the hole. When you peer down into the mine, you see crumbling walls and concrete and a hole so deep you can't see where it ends.
# ###
#
# Category: Abandoned
# Setting: Gold mine
# Description: The entrance is very unstable, with parts falling to the ground. As you enter, the walls have been crudely chipped away to make the path to the old mine. There is trash from the previous miners scattered on the dirt ground. Rocks are all around the area, where one would stumble as they go inside. It used to be a very productive gold mine, now falling to bits. There are broken lanterns, with shattered glass.
# ###
#
# Category: Abandoned
# Setting: Abandoned mine
# Description: It's dark, cold, and musty. There is old machinery lying around, rusting, and discarded tools lie on the ground. Cobwebs are everywhere. The rock walls are damp, and a trickle of water can be heard coming from somewhere off in the dark.
# ###
#
# Category: Abandoned
# Setting: The forsaken castle
# Description: Old and creepy, the castle has been abandoned for centuries now. It is broken and destroyed.
# ###
#
# Category: Abandoned
# Setting: Land beyond the wasteland
# Description: Not a man in sight nor an animal to hear. This land is completely barren and hot, unfit for any agricultural activity. It has been left abandoned so much so that the King has not even had time give it a name, so people simply refer to is as "Abandoned"
# ###
#
# Category: Abandoned
# Setting: Ruined house
# Description: A dilapidated wooden structure with a caved in roof and debris everywhere.  Even the trees outside the house are falling apart.  There's waist high grass leading to the house along with a dirt path.
# ###
#
# Category: Abandoned
# Setting: Collapsed west wing
# Description: The rocks have all but fallen into the ocean.  There is moss and other plant life climbing the remaining rocks, making it a very moist and gloomy environment.  There are some small left-behind pieces of what appear to have been some furniture, and possibly a cradle.
# ###
#
# Category: Cave
# Setting: Secret tunnel
# Description: Your senses are met with the dank moisture of a secret tunnel. The stony walls are full of lichen and cave moss. Stalactites and stalagmites pepper the small channel, which bleeds in a pinpoint light from a far off point. The chill air of the King's forest whistles through the tunnel interior.
# ###
#
# Category: Cave
# Setting: Cave
# Description: This cave is big but has no lights. It is made from stone and has a small pool of water in the back. The floor is made from dirt.
# ###
#
# Category: Cave
# Setting: Bat room
# Description: It is cold, dark and filled with bats. it is humid and there are some paddles on the ground.
# ###
#
# Category: Cave
# Setting: Cave exit
# Description: The large cave is covered along the walls with bright torches.  A large hole has been carved in the ceiling of the cave, right above the ladder that descends into the underground cave.  On good bright days, sunlight directly surround the hole with the gold ornate ladder descending into the underground part of the cave.  On the walls of the cave the torches illuminate many ornate drawings and paintings mainly dealing with the history of Kings of the realm.
# ###
#
# Category: Cave
# Setting: Entrance
# Description: The entrance to his cave is covered in hanging moss with shrubs on either side of the entrance.  The path to this cave is a small dirt one with low grass on the floor.
# ###
#
# Category: Cave
# Setting: Bandit lair
# Description: The outside of the cave looks normal. Inside goes for about 10 feet til' you reach the front of the Bandit lair. Inside is a barracks and dining hall with beds and a big table with chairs around it.
# ###
#
# Category: Cave
# Setting: Underground chamber
# Description: This location is very gloomy, damp and magical. Has a lot of geodes and various types of crystals.
# ###
#
# Category: Cave
# Setting: Underground cavern
# Description: The underground cavern is covered in precious metals and gems. In the wall, rubies, emeralds and sapphires sparkle. There is gold and silver, shining brightly. It is cool in the underground cavern.
# ###
#
# Category: Cave
# Setting: The troll's lair
# Description: Covered with rotting meat from nearby wildlife, the Troll's lair reeks of death.  If the stench alone wasn't enough to scare off an unfortunate travelers who stumbled upon it, the bones of unlucky spelunkers would be.  The Troll places his spoils near the numerous stalagmites on the damp cave wall, his red eyes patiently scanning the dark cave interior for anything that may disturb his isolation.
# ###
#
# Category: Cave
# Setting: Underwater cave
# Description: The underwater cave is dark and rocky. Inside the cave fish and tadpoles have taken over. The water is cold, no light gets in. Once inside, a rocky outcrop allows swimmers to come up for air.
# ###
#
# Category: Cave
# Setting: The underground river
# Description: The river is small and winding and hard to see because there are no lights within its' location. The river has many colorful rocks and gems.
# ###
#
# Category: Cave
# Setting: Gallery
# Description: The cave is pitch black and smells of dank and mold. It's quiet except for a faint dripping noise from water overhead and the occasionally scurrying of an unseen rodent through the darkness. Barely discernable by the light of a torch is a small pile of bones in one corner. From what type of animal they are from is unclear.
# ###
#
# Category: Cave
# Setting: Orc cave
# Description: It is a dark cave that is cold and damp inside. The floor is rocks covered it bat poop. It is damp from the ceiling dripping of water. The cave just goes on what seems to be endlessly into the dark abyss. The only lite you can see is from the distance entrance of the cave.
# ###
#
# Category: Cave
# Setting: Primary cave
# Description: Dark and with a lot of space in it. The primary cave has a scary look that scares people away. Underneath, in the floor, many precious minerals that no one dares to get out.
# ###
#
# Category: Cave
# Setting: Dark cave
# Description: Its dark, not much light can be seen in this hollow and empty cave site. Its made of stone that has been here seemingly since time began, the walls are hard as diamond, yet black like darkness itself.
# ###
#
# Category: Cave
# Setting: Cave
# Description: Cold and dark, the moist cool walls enclose all who proceed. With just torches to light the way the large opening gets smaller and smaller.
# ###
#
# Category: Trail
# Setting: Grassy plains
# Description: Flowers are blooming all around and the sun is shining. Small animals are roaming the area looking for food and relaxing. The trail is located in the center of the grassy plain and is made of stone.
# ###
#
# Category: Trail
# Setting: Scenic overlook
# Description: This lovely clearing overlooks the great mountain range. It is covered in wildflowers of all different colors. There are stone benches where one can sit.
# ###
#
# Category: Trail
# Setting: Hunting grounds
# Description: The hunting grounds are spacious and full of wildlife. A variety of hogs and oxen cross the grounds every day. The fields are lush with green and the skies always deep blue.
# ###
#
# Category: Trail
# Setting: Knight's hunting ground
# Description: The knight's hunting ground is lush and full of animals and other organisms. This area features trees, a long dirt path, and a variety of colorful wildlife.
# ###
#
# Category: Trail
# Setting: Across the king's garden
# Description: Heavily forested with dense undergrowth that stretches for miles. A cool mist enshrouds the trees and shrubs. The sounds of birds chirping fills the air and in the distance, the rumbling of a waterfall can be heard.
# ###
#
# Category: Trail
# Setting: The ghost trail
# Description: The Ghost Trail is dark, with no torches or writing.  The stars shine over head, the glow of the moon seems to beam in lulls. The trail seems to go on east or west as far as the eye can see.
# ###
#
# Category: Trail
# Setting: Tree of spirits
# Description: The Tree of Spirits is a large oak tree that is over 500 years old. It exceeds 100 feet tall and 10 feet wide. It's branches spread out several feet and it is home to several animals.
# ###
#
# Category: Trail
# Setting: The opening to the drawbridge of the castle
# Description: The trailhead to the forest is a dirt trail, dusty as it has not rained in a while. The overhang of the trees is luscious and green with only patches of sunlight beaming through the dense canopy. There are many large trees, some with arrows still stuck in their trunks. The trail is treacherous as it leads through the densest part of the forest, through a stream and to a well-hidden castle. Once inside the forest, the shade and canopy has provided plenty of opportunities for foliage to grow making it harder to follow.
# ###
#
# Category: Trail
# Setting: Trailhead
# Description: the trailhead is a worn down area leading in many directions, it has shown the wear of constant horse travel and other methods of transportation. it is till well used but in need of a makeover
# ###
#
# Category: Trail
# Setting: Path in forest
# Description: The trail path is a well designed path in the middle of a deep, dark forest. It is made purely from the bones of the innocent that were sacrificed to the ogre. There are eyes looking in the dark at you as you walk on the trail.
# ###
#
# Category: Trail
# Setting: Trail exit
# Description: The woodland area creates a gentle, peaceful feel as one walks along past the leafy fronds and gently shifting foliage.  The path is firm and wide, having been traversed by many feet, but not so wide as to allow a merchant's cart to pass through.  A bird's cry sounds in the distance, followed by a ruffle of feathers, and then silence.  The beauty of the forest hides the struggle of nature that lies within...
# ###
#
# Category: Dungeon
# Setting: Prisoner's cell
# Description: The prisoner's cell is incredibly dreary and dark. The walls are black and made of cobblestone. The atmosphere and smell are damp and repugnant.
# ###
#
# Category: Dungeon
# Setting: Torture room
# Description: An absolutely filthy and disgusting place.  Blood from the recently tortured covers the floors and walls, and the place is generally filthy and grimy.  There are various pieces of torture equipment lying around the room as well as instruments, tables, and chairs.
# ###
#
# Category: Dungeon
# Setting: A wet dungeon
# Description: It is dark and eerie, especially because there is only one candle. The candle is low on wax, it will be out soon. The brick walls surrounding the dungeon are scratched with fingernails, moss is growing.
# ###
#
# Category: Dungeon
# Setting: Dungeon within a castle
# Description: The castles dungeon lay buried below the village on the outskirts of the castles garden. Only the guards have access to light, and light is given as a privilege. The interior is stone and smells of mildew and deadly black mold.
# ###
#
# Category: Dungeon
# Setting: Prisoners cells
# ...
# ###
#
# Category: Magical realm
# Setting: Inside of a troll cave
# Description: A damp and vile smelling cave that only is lit by the sun that goes through the entrance. Skeletons from small animals can be seen sprawled across the floor. A little pile of leaves sit in a corner next to a campfire.
# ###
#
# Category: Magical realm
# Setting: A creature cave
# Description: This cave is very dark and damp. The smell is a stale and strong scent. There is little to no light. The walls are wet and the floor is slippery. Mice are all over and some bats are hanging from the ceiling.
# ###
#
# Category: Magical realm
# Setting: Faeries den
# Description: Stunning with silver walls and gold decorations, Magical items can be found on the shelves, including crystals, faery wands, and a crown.
# ###
#
# Category: Magical realm
# Setting: Echo hall
# Description: A gigantic dome-like building with a round table in the center of it. There is magelight above it and encircles the dome. Traces of wizards' histories appear on the walls and disappear from time to time.
# ###
#
# Category: Magical realm
# Setting: Wizard's lair
# Description: The wizard's lair is a mystical room. The walls are painted to resemble the night sky and pots of overgrown plants line the walls. Cages that once held creatures sit on top of an oak table in the center of the lair.
# ###
#
# Category: Magical realm
# Setting: Elf's room
# Description: A tiny room in a red mushroom. Tiny frames with photos of an elf family decorate the walls of a well-lit room. A miniscule lantern lit with a single morsel shines on a table made of oak bark.
# ###
#
# Category: Magical realm
# Setting: The cabin of an ogre
# Description: The wooden walls of the cabin are crudely adorned with a green, suspicious ooze. A dusty rug lays on the cold wooden floor of the cabin, dimly lit with a lantern situated in a corner in front of a large cobweb.
# ###
#
# Category: Magical realm
# Setting: Swamp
# Description: The swamp is glowing with wonder and color.  There are parts that range from dark red to bright yellow.  People often visit here to speak with the gods and claim it can be both harmful to those it dislikes and healing to those who it deems worthy.
# ###
#
# Category: Magical realm
# Setting: Secret magician's workshop
# Description: This is the hidden workshop of the most powerful wizard in the land.  There are ornate tapestries on the walls depicting wizards using their powers and potions in battle.
# ###
#
# Category: Magical realm
# Setting: The fountain of youth
# Description: The water here bubbles softly, cascading down the golden framework of the fountain.  The water is clear as crystal, and shimmers softly with a faint glow that doesn't seem to quite reflect the light around it.  The fountain itself is made of elaborately filigrees of gold and silver that twist and curve to show the sparkle of the water best, and it breathtaking to behold. While the fountain's beauty is what first draws the eye, a careful glace down at the earth around it reveals a frightening sight.  Skeletons, some clad in ancient armor from kingdoms long turned to dust, others worn down so that even what clothing they had has long since disintegrated, litter the earth.  Beautiful flowers grow up from them, partially obscuring whatever carnage caused these people to perish.
# ###
#
# Category: Netherworld
# Setting: Torture chanber
# Description: This room is very grim and evil. There are many torturing devices strewn about. There is also blood all over the walls. The smell is putrid and relentless.
# ###
#
# Category: Netherworld
# Setting: Cavern
# Description: a lonely and isolated place, a cavernous hole in the side of a craggy mountain that leads to a network of underground tunnels.
# ###
#
# Category: Netherworld
# Setting: The thrones of death
# Description: The main part of this room room would be the throne.  It is a shiny black with some gold ornate decorations on it. It sits on a black and gold pedestal. There is  a smaller throne in the room decorated in purple and gold.   It does not sit on a pedestal.  The room is decorated in tones of purple and blue with black accents.  This signifies death.  There are paintings of dolphin on the all.  Also to signify death.  The dolphins are typically gray.
# ###
#
# Category: Netherworld
# Setting: Lord's castle
# Description: This is the location in the netherworld where the Lord and controller lives.  It is in the center of the netherworld and is difficult to reach as it is built on high rocky cliffs.
# ###
#
# Category: Netherworld
# Setting: Reaper's lair
# Description: A room that gets very little light except for a dim candle on a pole. The walls are made of blackened stones. A wooden door with a heavy lock stands tall.
# ###
#
# Category: Netherworld
# Setting: Lower dungeon
# Description: The lower dungeon is set below the mail hall. It is dark, lit by only a few dim torches. Water is constantly dripping down the walls, giving it a dank and musty smell. There are manacles and cages set along the walls. In the middle of the room sits a table with manacles on all corners which are attached to a large rotating lever.
# ###
#
# Category: Netherworld
# Setting: Withered gardens
# Description: Dead trees and plants cluster in this garden, their branches thin and bone-like.  As they sway in the ghostly breeze, they look almost like skeletal hands, grasping for any living presence nearby to drain the life out of them.  There is a a dried up fountain made of cracked marble, and a bench that is made of rotting wood.  It looks as though it might turn into dust at the slightest touch.
# ###
#
# Category: Netherworld
# Setting: Devil's den
# Description: The Devil's Den is dark and fiery; no one dares to look at the blood covered walls. Skulls on stakes line the walls, with piles of bones scattered on the floor.
# ###
#
# Category: Netherworld
# Setting: The pit of despair
# Description: A sinking hole in the ground, roughly 15 feet in diameter, covered by the grabbing appendages of sinners who once walked in the land of the living. A cacophony of moans, screams and scratching bellows from the depths of the cavern. There is a pool of blood, tears and excrement at the bottom of the hole where limbs can be faintly seen trying to reach the surface but never able to.
# ###
#
# Category: Netherworld
# Setting: Dungeon
# Description: Dark and dreary, the dungeon hosts a portal for evil to access the netherworld. The moist dank smell casts doubt of goodness as you see the drab construct of jail cells lining the perimeter of the room.
# ###
#
# Category: Netherworld
# Setting: The dark kings throne room
# Description: Filled with skeletons and zombies and dead bodies, the throne room of the Dark King has literally no light.
# ###
#
# Category: Netherworld
# Setting: Whipping chamber
# Description: a stone wall with straps for tying up men and women to be punished for their immortal sins
# ###
#
# Category: Netherworld
# Setting: The devils castle
# Description: It is a castle that has burning flames that burn for eternity all around it. It is the tallest structure in all of the netherworld. It is dark and pitch black in some areas. It can be seen from miles away.
# ###
#
# Category: Netherworld
# Setting: Viewing room
# Description: The viewing room is where those who have passed on come to watch their family members in the living world one day per year. The room resembles an opera theater. There are seats throughout the room and boxes for those who were wealthy in life to sit in. There is a stage with a large magical dome on it for viewing.
# ###
#
# Category: Netherworld
# Setting: Lava lake
# Description: A vast lake of molten magma. The temperature is well above that which would kill most mortal beings. It is surrounded by black rock formed by cooled magma. The bubbling pit seems entirely devoid of life.
# ###
#
# Category: Supernatural
# Setting: Bridge in the forest
# Description: You are at a bridge. It is old and used very rarely. It is dim and foggy. The brigde is large and there is a small stream below it.
# ###
#
# Category: Supernatural
# Setting: The glade of mysteries
# Description: The leaves of the trees surrounding this glade glow unnaturally, as though lit from within.  There seems to be almost a presence to this place, a waiting watchful force.  Bits of music sound occasionally, tunes that seem familiar and yet quite alien, as though played by someone who had only heard the melody described to them, instead of hearing it themselves.  And yet all this pales in comparison to the pool found in the center.  The water gleams silver, seemingly absorbing and reflecting back the light of the trees around it tenfold.  Though there is a soft breeze that blows through the glade, there is not a ripple to be seen on the water's perfectly mirrored surface.
# ###
#
# Category: Supernatural
# Setting: Stonehenge
# Description: Technical and advanced, the enormous stones stand looking as if they are placed on top of each other by divine design. The green grass is a stark contrast to the gray stones hovering in the distance.
# ###
#
# Category: Supernatural
# Setting: Fighting arena inside tourney grounds
# Description: Filled with embroidered banners and filled with a crowd aching for entertainment, the fighting arena offers glory to all who enter. The arena itself is covered in orange dirt and surround by emblems and crests of all the knights who participate. There are weapon racks sprinkled alongside the edge of the arena.
# ###
#
# Category: Supernatural
# Setting: Astral plane
# Description: An area between worlds where the physics known to man become irrelevant. It is a space beyond time that is home to being spectral and inconceivable to those without the eyes to see them.
# ###
#
# Category: Supernatural
# Setting: Magic room
# Description: A room that once entered, cannot be escaped. The walls are all mirrors, and you can never again find the door.
# ###
#
# Category: Supernatural
# Setting: Goddess hollow
# Description: The Goddess Hollow is a place created to worship woodland spirits. It is a small, closet-like room in a hollowed out tree that has existed for hundreds of years. Within the hollow there are piles of sticks, flowers, and home-made items presented to the woodland spirits.
# ###
#
# Category: Supernatural
# Setting: Haunted basement
# Description: The basement is cold, damp, and dark. What little light coming in from the window is blotted out and dimmed by the spider webs sprawled across its surface. The shadows in the corners of the room appear nearly pitch black, and it almost feels as if something is looking back at you from within them.
# ###
#
# Category: Supernatural
# Setting: Ghost monk quarters
# Description: a simple room for an undead monk. There is an uncomfortable bed, no windows, a small table with a candle, some illustrations in a book, and not much else. There is a stool
# ###
#
# Category: Underwater aquapolis
# Setting: Research lab
# Description: The research lab is the main science hub of the aquapolis. Dozens of scientists are working on a myriad of different projects.
# ###
#
# Category: Underwater aquapolis
# Setting: The dungeon
# Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# ###
#
# Category: Underwater aquapolis
# Setting: Toad hollow
# Description: Toad Hollow is a filthy room within the Underwater Aquapolis. When you enter, you are greeted by the reek of scummy pond water. You enter Toad Hollow through a drainage pipe that you have to crawl through. Once inside Toad Hollow, you can stand up, but you still don't feel comfortable with your surroundings. As far as the eye can see there is muddy water in a circular basin with lily pads floating in it. On the pads, giant toads jump back and forth making gurgling, croaking sounds. As you wade deeper into Toad Hollow, the water comes up to your waist and you see the flash of a fin. There is legend that a creature lives in the center of Toad Hollow that is half human, half monster. Not even the strongest knight has been brave enough to examine it. The fin disappears back underwater but there is a red glint suggesting eyes are watching you. When you reach the other side of the basin, you crawl into another drainage pipe and feel relieved that you're out of this place.
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater marketplace
# Description: The marketplace is the main hub for the residents of the aquapolis. With high ceilings and bright, colorful flags at each market stand, the place seems to stretch on forever. Near the entrance, there is a young boy attempting to sell the latest news of the kingdom.
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater aquapolis
# Description: The underwater aquapolis is a massive and ornate city at the bottom of the ocean. The walls of the buildings are made or coral, pearl, and seashells. Schools of fish swim in and out of the circular holes in the walls that act as windows. The aquapolis is illuminated by florescent rocks and shells that line every building.
# ###
#
# Category: Underwater aquapolis
# Setting: Dry dock room
# Description: The room is located on the border wall of the aquapolis. There is one on the far north and far south side.
# ###
#
# Category: Underwater aquapolis
# Setting: Neptune's throne room
# Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# ###
#
# Category: Underwater aquapolis
# Setting: The lords treasury
# Description: Deep inside the volcanic cave that is the foundation of the aquapolis lies the treasury.  Some believe its existence is a myth, but others claim they have been there.  Those that claim they have seen it say you must dive out of the aquapolis' basement while holding your breath, through the cold deep water that is filled with deadly volcanic gas.  The treasury room itself is a dry cave filled with riches from the very infancy of the empire
# ###
#
# Category: Underwater aquapolis
# Setting: Geothermal valley
# Description: Deep and warm the geothermal valley boasts a reviving epicenter for all to migrate to. The warm bursts of heat send bubble around the perimeter of the valley reflecting colors of green and blue.
# ###
#
# Category: Underwater aquapolis
# Setting: The marketplace
# Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# ###
#
# Category: Underwater aquapolis
# Setting: Farmhouse
# Description: a small house on a seaweed plantation, small and rustic, really only the single room with a closet, maybe, a table and some chairs
# ###
#
# Category: Underwater aquapolis
# Setting: Tool shed
# Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# ###

# %% [markdown]
# # Fine-tune GPT3 with the OpenAI API
#
# Next, we'll perform fine-tuning with this data using OpenAI.

# %%
# %%capture
# !pip install --upgrade openai
# !pip install jsonlines

# %% [markdown]
# Once you've got access to the OpenAI API, you can find your OpenAI API key [here](https://beta.openai.com/account/api-keys).

# %%
import os
import openai

print('Enter OpenAI API key:')
openai.api_key = input()

os.environ['OPENAI_API_KEY']=openai.api_key

# %%
# !head fine_tuning_location_descriptions.jsonl
# Out:
# {"prompt": "Category: Forest\nSetting: Woodlands\n", "completion": "Description: The lush hunting grounds cover acres of land, tall trees and thickets of bushes sprawling across the land. Fields of open land are under the deep blue sky, showing the depth of the landscape. The grounds forest is thick but full of light, letting the multitude of wildlife be seen by the naked eye. The abundance of greenery makes it a prime location for hogs and oxen as they explore the land.\n###\n"}
# {"prompt": "Category: Forest\nSetting: Forbidden forest\n", "completion": "Description: The forbidden forest is a dark and very scary place. The trees are covered in spider web nets and huge spiders. The forest echoes sounds of witches' laughs and creepy crawly animals.  There is a brisk breeze that runs through the trees that will put chills down your spine.\n###\n"}
# {"prompt": "Category: Forest\nSetting: North forest\n", "completion": "Description: Filled with huge trees, the forest is home to many types of animals. Huge predators such as tigers and bears roam the grounds as do small animals like squirrels. Colorful birds fly among the trees. Wildflowers grow on the ground. Dappled sunlight streams through the huge canopy of trees.\n###\n"}
# {"prompt": "Category: Forest\nSetting: Ant hill\n", "completion": "Description: The ant hill is very large, over 5 feet high, and is wrapped around the base of a pine tree. The ants are huge compared to normal ants, and jut in and out of large holes in the ant hill. Bones of animals and even people can be seen sticking out of the red dirt ant hill.\n###\n"}
# {"prompt": "Category: Forest\nSetting: Unsettling forest area\n", "completion": "Description: The forest is actually very creepy even during the day. The trees are so tall that they block the sunlight. There is always fog in the forest which makes it very hard to see. There are a lot of mushrooms near the trees and none of them are edible\n###\n"}
# {"prompt": "Category: Forest\nSetting: A wooded magical village\n", "completion": "Description: The village lay hidden in a secret grotto that is set in a sort of valley between trees. The village is populated by child-like peoples who wear clothes made of various plant matter such as large leaves and vines. The homes are made of wood, and seemingly blend into the green dense backdrop.\n###\n"}
# {"prompt": "Category: Forest\nSetting: Entrance to the pine trees\n", "completion": "Description: Very tall and towering pine trees that create a dark canopy of shade. Long skinny trees sway in the sky from the soft breeze. Pine needles scatter the ground like plush carpet.\n###\n"}
# {"prompt": "Category: Forest\nSetting: Woods\n", "completion": "Description: The woods are vast. Everywhere you turn it all looks the same. There are scratches on the trees from lost travelers marking their path. There are sounds coming from everywhere and yet no where. There are faint yellow circles up in the trees and bushes, possibly eyes starting at you.\n###\n"}
# {"prompt": "Category: Forest\nSetting: Along the banks of a river in the forest\n", "completion": "Description: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.\n###\n"}
# {"prompt": "Category: Forest\nSetting: Mysterious forest outskirts\n", "completion": "Description: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.\n###\n"}

# %% [markdown]
# Next, we'll make the fine tuning API call via the command line.  Here the -m argument gives the model.  There are 4 sizes of GPT3 models.  They go in alphabetical order from smallest to largest.
# * Ada
# * Baddage
# * Currie
# * Davinci
#
# The models as the model sizes increase, so does their quality and their cost.  Davinci is the highest quality and highest cost model.  I recommend starting by fine-tuning smaller models to debug your code first so that you don't rack up costs.
#
# Fine-tuning curie costs about $0.50 for this data.

# %%
light_environment.keys()
# Out:
# dict_keys(['categories', 'rooms', 'neighbors', 'characters', 'objects'])

# %%
# !openai api fine_tunes.create -t fine_tuning_location_descriptions.jsonl -m curie
# Out:
# Found potentially duplicated files with name 'fine_tuning_location_descriptions.jsonl', purpose 'fine-tune' and size 196498 bytes
# file-isIVJnKirOczR5QKVQKYfHfg
# Enter file ID to reuse an already uploaded file, or an empty string to upload this file anyway:
# Upload progress: 100% 196k/196k [00:00<00:00, 262Mit/s]
# Uploaded file from fine_tuning_location_descriptions.jsonl: file-uTIbP7fRx8RADabfCSD3fE6n
# Created fine-tune: ft-967ExyrfGqnZ4zV29R61yVlt
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2022-01-28 18:13:47] Created fine-tune: ft-967ExyrfGqnZ4zV29R61yVlt
# [2022-01-28 18:13:57] Fine-tune costs $0.47
# [2022-01-28 18:13:57] Fine-tune enqueued. Queue number: 0
# [2022-01-28 18:14:01] Fine-tune started
# [2022-01-28 18:17:46] Completed epoch 1/4
# [2022-01-28 18:20:52] Completed epoch 2/4
# [2022-01-28 18:23:56] Completed epoch 3/4
# [2022-01-28 18:27:02] Completed epoch 4/4
# [2022-01-28 18:27:33] Uploaded model: curie:ft-cis-700-31-2022-01-28-18-27-32
# [2022-01-28 18:27:37] Uploaded result file: file-NET1pxGMdxmpl6HsjC3ldKOo
# [2022-01-28 18:27:37] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m curie:ft-cis-700-31-2022-01-28-18-27-32 -p <YOUR_PROMPT>

# %% [markdown]
# You should copy down the fine-tune numbers which look like this:
#
# ```
# Created fine-tune: ft-VzQpTwfnWAzDXNKgPTFtiZg2
#
# [2022-01-21 23:22:47] Uploaded model: curie:ft-ccb-lab-members-2022-01-21-23-22-46
# ```
#
# If you forget to write it down, you can list your fine-tuned runs and models this way. These model names aren't mneumonic, so it is probably a good idea to make a note on what your model's inputs and outputs are.

# %%
# !openai api fine_tunes.list
# Out:
# {
#   "data": [
#     {
#       "created_at": 1643171130,
#       "fine_tuned_model": "babbage:ft-cis-700-31-2022-01-26-04-28-54",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-gQz3VvxCdlXkPZXKfIKPb7Pz",
#       "model": "babbage",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 16255,
#           "created_at": 1643171337,
#           "filename": "compiled_results.csv",
#           "id": "file-fuqAemUsZ2CZG1VM5dCYYqeV",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 5827,
#           "created_at": 1643171129,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-pWTYKKeqHkaFr9hDuZkjLyMp",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643171340,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643172512,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-05-04-42",
#       "hyperparams": {
#         "batch_size": 2,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-DDgVlfYn0IZZPOUIjVZ8XYk4",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 86785,
#           "created_at": 1643173485,
#           "filename": "compiled_results.csv",
#           "id": "file-NMvKjM6la7txhc1W4sWVkohN",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 57828,
#           "created_at": 1643172511,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-ugiUt8ZjuN8MlaIcJtTfZwcF",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643173488,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643173906,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-05-26-35",
#       "hyperparams": {
#         "batch_size": 2,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-KSJE1P5Ikjg1km4OFf9lAZjG",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 86582,
#           "created_at": 1643174798,
#           "filename": "compiled_results.csv",
#           "id": "file-vYD1KkPfLBVMk37KSj8BZvqJ",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 60828,
#           "created_at": 1643173905,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-o1r3kRxbtUqNWdVVi2DAZRtL",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643174801,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643176732,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-06-01-14",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-3j5GRf6RWnXgV5AHRcm1LSyS",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 16337,
#           "created_at": 1643176877,
#           "filename": "compiled_results.csv",
#           "id": "file-MN9SERE1WFX7TrjRSYGHVBsP",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 7627,
#           "created_at": 1643176731,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-EwZKxIWuxr1DW7LH5FteIWx2",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643176880,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643177139,
#       "fine_tuned_model": "babbage:ft-cis-700-31-2022-01-26-06-08-48",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-SNh2deUhnPysWOGxKcnqOGEY",
#       "model": "babbage",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 16398,
#           "created_at": 1643177331,
#           "filename": "compiled_results.csv",
#           "id": "file-5Sihbwtx66UEo5qCvXP1Pv2H",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 7927,
#           "created_at": 1643177138,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-4DpApGW9BbmU1ldXU9wbPY1W",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643177333,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643177760,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-06-18-16",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-HlGs76zF0FY1kYQD0YUQiRQD",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 16191,
#           "created_at": 1643177899,
#           "filename": "compiled_results.csv",
#           "id": "file-vJkDTwjuKj94QQzinsJa8m5g",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 6827,
#           "created_at": 1643177759,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-VEdQvicrTPbFiPak43Qjtkfc",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643177902,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643177969,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-06-22-01",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-0VpJI4XoLDujiTzgUGPrAIEw",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 16432,
#           "created_at": 1643178123,
#           "filename": "compiled_results.csv",
#           "id": "file-S0Tvhx3sopBalz3tLxFVoBxQ",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 8127,
#           "created_at": 1643177969,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-lRjcs3oATP0n697BCxqeVCM9",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643178126,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643178449,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-06-29-46",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-DLMUWyYMBIDbjzj5jXj91kGe",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 16409,
#           "created_at": 1643178589,
#           "filename": "compiled_results.csv",
#           "id": "file-OJH3ncnkzQTbQLLigtbX9mXP",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 8327,
#           "created_at": 1643178448,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-d7xng0RpxtXwhLq7nZ3BG5nL",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643178592,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643178914,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-06-47-36",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-7ltQWjAB3DXhVhgYj3fZUeY6",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 16191,
#           "created_at": 1643179659,
#           "filename": "compiled_results.csv",
#           "id": "file-3L4JbGMjpU6tjRtyytVJm9oY",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 6827,
#           "created_at": 1643178914,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-JMUSxk0B0m2GAlOFf4AgLAAK",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643179662,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643212259,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-15-53-25",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-d6AzLg56mxNMjRdNSrAn3RXy",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 16357,
#           "created_at": 1643212408,
#           "filename": "compiled_results.csv",
#           "id": "file-SV7wXxdAuxYa0z519t6kMY30",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 7527,
#           "created_at": 1643212258,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-fVfiEyuhLM00nq7PQyzXBlsv",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643212412,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643212543,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-15-58-06",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-9UtFuZtmpebYixqu9TfT6ZxE",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 16378,
#           "created_at": 1643212689,
#           "filename": "compiled_results.csv",
#           "id": "file-SHkwgX5Y2GCXZNnALSIxDxAh",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 8127,
#           "created_at": 1643212542,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-tRRWDJBai2njIfP35WNvROvN",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643212693,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643212750,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-16-01-29",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-zDKMozyl1UprrtKFL8kYVVsx",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 16415,
#           "created_at": 1643212892,
#           "filename": "compiled_results.csv",
#           "id": "file-5TeU30bk5l3jLdM3hZe4mxQp",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 7827,
#           "created_at": 1643212749,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-8ZYQqRCBsi24n5d2MV40mNrQ",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643212896,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643213199,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-16-09-01",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-dlf55wNVS65SGwcNSvQz04vE",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 17238,
#           "created_at": 1643213344,
#           "filename": "compiled_results.csv",
#           "id": "file-ruhYucfv03qfhoHdZoPBQLtL",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 8327,
#           "created_at": 1643213199,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-L4Wi9kvxIWDnHbx6Oa9iUa0f",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643213348,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643213435,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-16-12-59",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-SWwLFrLquvdiJOdE34gVFPUg",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 17443,
#           "created_at": 1643213582,
#           "filename": "compiled_results.csv",
#           "id": "file-Adjrb3yipwwfGgPqKJMxDLtc",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 8327,
#           "created_at": 1643213434,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-Bi00NbjYK9sqeRt1AiIeo9xa",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643213585,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643213669,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-16-16-13",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-773BBFZY5V6hEIAA2wxFl9G8",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 8099,
#           "created_at": 1643213776,
#           "filename": "compiled_results.csv",
#           "id": "file-PvQ0CBne6bReLhw4My0vcWDR",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 4016,
#           "created_at": 1643213669,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-E5yADB0m73fRtasA1WFalj9j",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643213779,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643214102,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-16-24-06",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-1LBdYDtEHONzOJ3MXz7tq7Jx",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 17383,
#           "created_at": 1643214250,
#           "filename": "compiled_results.csv",
#           "id": "file-ghL2wB1RxA6GMPioMjLoDhoe",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 8127,
#           "created_at": 1643214102,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-7fWFCR7Qn2cyrEpkZL47UShv",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643214254,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643214806,
#       "fine_tuned_model": "curie:ft-cis-700-31-2022-01-26-16-46-55",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-Td2twtsH8zoob6cRLXsjBrM6",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 117763,
#           "created_at": 1643215619,
#           "filename": "compiled_results.csv",
#           "id": "file-4ZeLFjUfbnDBgp9euuazi7HY",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 196498,
#           "created_at": 1643214805,
#           "filename": "fine_tuning_location_descriptions.jsonl",
#           "id": "file-isIVJnKirOczR5QKVQKYfHfg",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643215622,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643214895,
#       "fine_tuned_model": "curie:ft-cis-700-31-2022-01-26-16-49-32",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-7L34tvHMaoR9Ty9eiEi1NXhr",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 10425,
#           "created_at": 1643215774,
#           "filename": "compiled_results.csv",
#           "id": "file-1T7MH73RgcxJPOU1KC78UW3X",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 17259,
#           "created_at": 1643214894,
#           "filename": "fine_tuning_location_descriptions.jsonl",
#           "id": "file-WlXspQxa2FIiuLRCaqr2EUWB",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643215778,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643214927,
#       "fine_tuned_model": null,
#       "hyperparams": {
#         "batch_size": null,
#         "learning_rate_multiplier": null,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-mDZRv6SWMrq0wFwbCCco6KqT",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [],
#       "status": "cancelled",
#       "training_files": [
#         {
#           "bytes": 17259,
#           "created_at": 1643214926,
#           "filename": "fine_tuning_location_descriptions.jsonl",
#           "id": "file-LGV4zrBZjIJf0DVpKw4rHU99",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643215354,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643215217,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-16-52-01",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-B7DChnejsO0Ad6FNNVNdim1n",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 17244,
#           "created_at": 1643215924,
#           "filename": "compiled_results.csv",
#           "id": "file-dEv1s2EPKxZ63htuccVa8ML3",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 6427,
#           "created_at": 1643215216,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-umjrCXI7809YZ9Xzmqa3Hc7H",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643215928,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643215554,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-16-56-59",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-oRwTxZ3korHXalaY2wRjOK3N",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 17244,
#           "created_at": 1643216222,
#           "filename": "compiled_results.csv",
#           "id": "file-okfReNIEMgmnNyjvUZAag9vg",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 6427,
#           "created_at": 1643215553,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-R3Q4oOrByNNKhkTN0schOUAT",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643216226,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643215813,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-16-54-23",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-hWqbYNCGqzgaX9u5vUuDMUeE",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 17276,
#           "created_at": 1643216066,
#           "filename": "compiled_results.csv",
#           "id": "file-A1kCtLPXLgYNMqTdDO7J605V",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 8127,
#           "created_at": 1643215812,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-bB59yIqFUwaCBHC2IqmpcN6V",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643216070,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643216182,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-16-58-11",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-cEIHglsWKjF5QWY5ARwqhaiv",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 1892,
#           "created_at": 1643216294,
#           "filename": "compiled_results.csv",
#           "id": "file-lI32Qvl6pcJA1nJMGxtJ7s19",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 742,
#           "created_at": 1643216181,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-3Mg08zrSWP4GvmXT4Z6Ru3OF",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643216297,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643216403,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-17-02-22",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-dn2a4lDhnMVGEEcpr1u8qdR0",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 17091,
#           "created_at": 1643216546,
#           "filename": "compiled_results.csv",
#           "id": "file-3y7KmU0CxeGXYGU6i74a0Er7",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 6427,
#           "created_at": 1643216402,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-IePiWEhuDY2peKpXsr8yZ83y",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643216549,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643216646,
#       "fine_tuned_model": "ada:ft-cis-700-31-2022-01-26-17-19-03",
#       "hyperparams": {
#         "batch_size": 2,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-mw7fNaHEkeFrRz1vA8zCGeWV",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 90653,
#           "created_at": 1643217546,
#           "filename": "compiled_results.csv",
#           "id": "file-FHFGSFyQPwCcmmdf9yaJIh0B",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 64828,
#           "created_at": 1643216645,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-IPJjeGsiSPm4EcApRHWQNNXl",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643217550,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643217977,
#       "fine_tuned_model": "davinci:ft-cis-700-31-2022-01-26-18-42-47",
#       "hyperparams": {
#         "batch_size": 2,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-rqPA2L4BqXSCIqngf1KyJuZw",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 91311,
#           "created_at": 1643222571,
#           "filename": "compiled_results.csv",
#           "id": "file-oFyp63oRITyFblmvB1fN88S0",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 64828,
#           "created_at": 1643217976,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-AMluLVTVVDXoAoFyp5GGLBCy",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643222575,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643393626,
#       "fine_tuned_model": "curie:ft-cis-700-31-2022-01-28-18-27-32",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-967ExyrfGqnZ4zV29R61yVlt",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-F69R2DHlJEWY5pRMNnAC0oYV",
#       "result_files": [
#         {
#           "bytes": 117653,
#           "created_at": 1643394455,
#           "filename": "compiled_results.csv",
#           "id": "file-NET1pxGMdxmpl6HsjC3ldKOo",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 196498,
#           "created_at": 1643393625,
#           "filename": "fine_tuning_location_descriptions.jsonl",
#           "id": "file-uTIbP7fRx8RADabfCSD3fE6n",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643394458,
#       "validation_files": []
#     }
#   ],
#   "object": "list"
# }

# %% [markdown]
# You can run your fine tuned model in the OpenAI Playground.  After the model is finished finetuning you'll find it in the Engine dropdown menu.
#
# You'll need to give the inputs that we used as the "prompt" in our training data.  In this case we gave it a `Category:` and a `Location:` name.  You can also add the `Description:` part of the completion if you want. You should also set the stop sequence to be `###`. For example, we could type this input into the playground:
#
# ```
# Category: Dark Forest
# Location: Winter's Glade
# Description:
# ```
# If you press the "Generate" then your fine tuned model will output something like:
#
# > The forest at night is not a place one would willingly set foot in. It is cold and dark and seems to go on forever. Trees loom over you, blocking out the light of the moon and stars. The only sound is the occasional howl of a wolf and the occasional splashing of water.
#
# If you don't like the description, you can press the "Regerate" button to get other outputs like:
#
# > The winter's glade is a dark and eerie place. It is home to many animals, but little else. The trees are barren and the ground is covered in snow.
#
# Or
#
# > The dark forest is a place where not even a ray of light can pierce the tangled web of branches overhead. Needles from vast numbers of trees protrude at awkward angles, their branches thin and frail, more like twigs than the strong trunks they resemble. Between the branches, a darkness deeper than night reigns. It is from this darkness that the trees themselves appear as ghosts, for the branches do not embrace the earth so much as merely touch it. The tips of the branches move slightly with every breath taken by the trees, and the dark forest seems to breathe along with them.
#
# Or
#
# > The forest has now turned white.  The trees are barren and dead, their branches thin and broken.  There's a light dusting of snow on the ground, and it looks as if the forest is trying to erase all traces of life from the earth.

# %% [markdown]
# You can press the "Code" button to get a snippet of code that you can adapt into your own Python programs.
#
# ```
# import os
# import openai
#
# openai.api_key = os.getenv("OPENAI_API_KEY")
#
# response = openai.Completion.create(
#   model="curie:ft-ccb-lab-members-2022-01-21-23-22-46",
#   prompt="Category: Dark Forest\nLocation: Winter's Glade\nDescription:",
#   temperature=0.7,
#   max_tokens=64,
#   top_p=1,
#   frequency_penalty=0,
#   presence_penalty=0,
#   stop=["###"]
# )
# ```
#
# Here's an example of how to write a function using the code that the OpenAI API provides.

# %%
def get_location_description(category, location_name, finetuned_model):
  response = openai.Completion.create(
      model=finetuned_model,
      prompt="Category: {category}\nSetting: {location}\nDescription:".format(
          category=category.capitalize(),
          location=location_name.capitalize()
      ),
      temperature=0.7,
      max_tokens=64,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0,
      stop=["###"]
      )
  return response['choices'][0]['text']

# Replace with your model's name
finetuned_model = "curie:ft-cis-700-31-2022-01-28-18-27-32"
category = "Campus"
location_name = "Winter's UPenn"

descripton = get_location_description(category, location_name, finetuned_model)
print(descripton)
# Out:
#  The sky is overcast and murky. The wind blows snow in drifts everywhere. The ground is covered in a white blanket that seems to go on for miles. This is Winter's upenn. The temperature is well below freezing.

# %% [markdown]
# # TODO: Fine-Tune Additional Models for Text Adventure Games
#
# In this assignment, we'll ask you to fine-tune models to perform the following tasks:
# 1. Describe a location (I've given you this code.  You can adapt it for other models)
# - inputs: category, location name
# - output: location description
# 2. List the items that are at a location
# - inputs: category, location name, location description, number of items
# - output: list of item names
# 3. Describe an item
# - inputs: category, location name, location description, item name
# - output: item description
# 5. List connections from the current location
# - inputs: category, location name, location description, and optionally a partial list of existing connections (direction, location name) tuples
# - output: a list of (direction, location name) tuples
# 4. Get an item's properties
# - inputs: item name, item description, property (e.g. gettable)
# - output: True or False if the item has that property

# %%
# get all items in one specific location
def get_items(room_id, rooms_by_id, light_environment):
  """
  This generates a prompt and a completion which can be used to fine-tune OpenAI.
  This version just gnnerates 
  """
  prompt = ""
  completion = ""
  prompt += "Category: {category}\n".format(category=rooms_by_id[room_id]['category'].capitalize())
  prompt += "Setting: {setting}\n".format(setting=rooms_by_id[room_id]['setting'].capitalize())
  prompt += "Description: {description}\n".format(description=rooms_by_id[room_id]['description'])
  in_objects=rooms_by_id[room_id]['in_objects']
  objects_array=[]
  for obj in in_objects:
    objects_array.append(light_environment["objects"][str(obj)]["name"])
  completion += "Items: {items}\n".format(items=objects_array)
  completion += "###\n"

  return prompt, completion


def create_items_finetuning_data(filename='fine_tuning_location_items.jsonl'):
  fine_tuning_data = []
  for category in categories:
    rooms = rooms_by_category[category]
    for room_id in rooms:
      data = {}
      prompt, completion = get_items(room_id, rooms_by_id, light_environment)
      data['prompt'] = prompt
      data['completion'] = completion
      print(prompt, end="")
      print(completion)
      fine_tuning_data.append(data)

  with open(filename, 'w') as out:
    for data in fine_tuning_data:
        out.write(json.dumps(data))
        out.write('\n')

create_items_finetuning_data()
# Out:
# Category: Forest
# Setting: Woodlands
# Description: The lush hunting grounds cover acres of land, tall trees and thickets of bushes sprawling across the land. Fields of open land are under the deep blue sky, showing the depth of the landscape. The grounds forest is thick but full of light, letting the multitude of wildlife be seen by the naked eye. The abundance of greenery makes it a prime location for hogs and oxen as they explore the land.
# Items: []
# ###
#
# Category: Forest
# Setting: Forbidden forest
# Description: The forbidden forest is a dark and very scary place. The trees are covered in spider web nets and huge spiders. The forest echoes sounds of witches' laughs and creepy crawly animals.  There is a brisk breeze that runs through the trees that will put chills down your spine.
# Items: []
# ###
#
# Category: Forest
# Setting: North forest
# Description: Filled with huge trees, the forest is home to many types of animals. Huge predators such as tigers and bears roam the grounds as do small animals like squirrels. Colorful birds fly among the trees. Wildflowers grow on the ground. Dappled sunlight streams through the huge canopy of trees.
# Items: []
# ###
#
# Category: Forest
# Setting: Ant hill
# Description: The ant hill is very large, over 5 feet high, and is wrapped around the base of a pine tree. The ants are huge compared to normal ants, and jut in and out of large holes in the ant hill. Bones of animals and even people can be seen sticking out of the red dirt ant hill.
# Items: []
# ###
#
# Category: Forest
# Setting: Unsettling forest area
# Description: The forest is actually very creepy even during the day. The trees are so tall that they block the sunlight. There is always fog in the forest which makes it very hard to see. There are a lot of mushrooms near the trees and none of them are edible
# Items: []
# ###
#
# Category: Forest
# Setting: A wooded magical village
# Description: The village lay hidden in a secret grotto that is set in a sort of valley between trees. The village is populated by child-like peoples who wear clothes made of various plant matter such as large leaves and vines. The homes are made of wood, and seemingly blend into the green dense backdrop.
# Items: ['clothes', 'plant matter', 'large leaves', 'vines', 'homes', 'clothes made of various plant matter such as large leaves and vines']
# ###
#
# Category: Forest
# Setting: Entrance to the pine trees
# Description: Very tall and towering pine trees that create a dark canopy of shade. Long skinny trees sway in the sky from the soft breeze. Pine needles scatter the ground like plush carpet.
# Items: ['towering pine trees', 'Long skinny trees', 'Pine needles', 'needles']
# ###
#
# Category: Forest
# Setting: Woods
# Description: The woods are vast. Everywhere you turn it all looks the same. There are scratches on the trees from lost travelers marking their path. There are sounds coming from everywhere and yet no where. There are faint yellow circles up in the trees and bushes, possibly eyes starting at you.
# Items: []
# ###
#
# Category: Forest
# Setting: Along the banks of a river in the forest
# Description: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.
# Items: ['river', 'fish', 'insects', 'grass', 'river', 'riverbank']
# ###
#
# Category: Forest
# Setting: Mysterious forest outskirts
# Description: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.
# Items: ['trees', 'food']
# ###
#
# Category: Forest
# Setting: Riverbed
# Description: With clear air and the sound of gurgling water near it, the river bed is silty and muddy. The river rushes by the land as more and more dirt separates from the land. The land of the riverbed slick with mud and filled with bugs and worms/
# Items: ['clear air', 'gurgling water', 'river', 'the land', 'dirt', 'mud', 'water', 'dirt', 'river', 'mud', 'worms', 'fish']
# ###
#
# Category: Forest
# Setting: South forest
# Description: The forest is lined with tall trees but has a long walkway for travelers. I the middle of the forest is a long river surrounded by tall grass with clear blue waters and lots of colorful fish.
# Items: []
# ###
#
# Category: Forest
# Setting: The brush den
# Description: The entryway to the brush den is made of arched bushes and various plants, as is the ceiling and walls. The inside is furnished with seats made of plant roots that have grown together, and a table made of wood adorned with flowers and wooden cups and plates. A small vine dangles with a glowing floor from the middle of the ceiling that lights the room dimly. Three small beds lay in one corner of the room made of interlaced grass and leaves.
# Items: ['arched bushes', 'various plants', 'seats', 'flowers', 'wooden cups', 'plates', 'beds', 'arched bushes', 'various plants', 'ceiling', 'walls', 'seats made of plant roots', 'table', 'beds', 'small vine']
# ###
#
# Category: Forest
# Setting: Firewood forest
# Description: The forest has many trees. The majority of the trees are green however a few are orange and red. The forest is huge and seems to never end.
# Items: ['The forest has many trees.', 'wood is gathered to make fire', 'new trees are built once a year']
# ###
#
# Category: Forest
# Setting: Picnic area
# Description: In this picnic area, there is a wide clearing with some cut down tree stumps made for people to sit and enjoy their lunch.  There's also a small pond nearby where people can feed fish and watch turtles sunbathe.
# Items: []
# ###
#
# Category: Forest
# Setting: Fairy forest
# Description: The fairy forest is full of brightly colored flowers that grow up to 30 feet tall.  There are also ornate birds that live here.  When you whistle, a fairy will come to you and tweak your nose.  They don't like a lot of nose so it irritates them enough for them to come out of their homes made from watermelon skins.
# Items: ['brightly colored flowers that grow up to 30 feet tall', 'homes made from watermelon skins']
# ###
#
# Category: Forest
# Setting: A room hidden in the dense canopy
# Description: Its a large room with types of beings you have never seen before. There is a counter and a person who greets people suprise when you arrive because you are not one of them. The room has an unfamiliar feel to it. with doors leading to walkways, other buildings, an entire city
# Items: []
# ###
#
# Category: Forest
# Setting: Forest entrance
# Description: The path quickly narrows and darkens upon entering the forest.  Dense branches overhead block all but a few stray rays of sunshine.  Fallen leaves just beginning to rot blanket the forest floor, and every footstep kicks up a rich, loamy scent as fresh ground is unearthed.
# Items: []
# ###
#
# Category: Forest
# Setting: Flower garden
# Description: This clearing is in reveal a wide circle of trees. Proud oaks stand close enough that only the smallest of fauna can squeeze through, protecting the garden within from curious deer and hungry rabbits. Flowers of every hue and shade crowd the soft lawn of grass, soaking up what light they can through the shadows cast by the branches above. Purple, yellow, red, blue - even green blossoms bob in the breeze, their scents mixing to create a heady perfume. Vines and creepers climb up the tree trunks, dripping with grapes and berries.
# Items: []
# ###
#
# Category: Forest
# Setting: The clearing
# Description: the clearing is surrounded by old pine trees where knights used to practice swinging their swords. There are haystacks where they take wenches and pay them a sickle.
# Items: ['the clearing', 'old pine trees', 'swords', 'haystacks', 'sickle', 'river', 'trees']
# ###
#
# Category: Forest
# Setting: The stream
# Description: The stream is always going. The water moves quickly in some places and slowly in other places. There is a dry spot on each side of the water. In some areas you will see animals drinking the water. There are also fish swimming around in the deeper parts of the stream.
# Items: ['The water', 'rainfall', 'The water in the sky', 'higher elevations', 'water']
# ###
#
# Category: Forest
# Setting: Pine tree graveyard
# Description: Once known as a forest of solitude, the entrance to the pine trees is now a bleak and dreary graveyard.  Dead grass and moss fill the ground along with crawling critters that mark fear in the mind among the he who venture here.  Tombstones so old many of the names are no longer eligible.  Dense fog surrounds the area, thick tree tops blotting out the sunlight, and an eerie silence fills the air.  Cold it feels, the air, but the ground is soft and warm.  Sound can not enter, no escape this dwelling.
# Items: []
# ###
#
# Category: Forest
# Setting: Pond
# Description: A small area with a body of water in the center along with turtles, frogs, and other wildlife that live here.  Surrounding this pone are a dense set of trees along with some rocks here and there.
# Items: ['frogs', 'wildlife', 'water', 'trees', 'rocks']
# ###
#
# Category: Shore
# Setting: Enchanted light house
# Description: Slightly rusted and corroded from the crashing waves, elegant and tall. each window and opening is lined with a bronze trim.  Some gears can be seen turning along the side, rotating a middle section of the light house.
# Items: ['window', 'gears']
# ###
#
# Category: Shore
# Setting: A battleship
# Description: It is a glamorous wooden ship.  It glistens like there are diamonds encrusted on the hull.  There are ornate railings on the stairs as it is a massive boat.  There is even a sea monster on the bow, complete with jeweled eyes and gold hair.
# Items: ['ornate railings on the stairs', 'sea monster on the bow', 'hull', 'ornate railings', 'stairs', 'sea monster', 'jeweled eyes', 'gold hair']
# ###
#
# Category: Shore
# Setting: King's quarters
# Description: The room is large. The largest of all the throne rooms. The carvings on the wall are ornate and historical. The room is clearly built for royalty. The bed is covered in designed covers. It is truly a sight to see.
# Items: ['carvings', 'bed', 'designed covers.']
# ###
#
# Category: Shore
# Setting: Fishing pier
# Description: A spindly, long fishing pier that sits right outside the village. Barnacles cover its pilings in vast numbers. Many villagers can be seen fishing atop of it. Birds and pelicans squawk and fly above it.
# Items: ['Barnacles', 'pilings', 'peasants', 'pelicans']
# ###
#
# Category: Shore
# Setting: Large cliffs
# Description: Towering cliffs of gray granite line the coast. A few meters of sand lie between the ocean and the base of the cliffs.
# Items: []
# ###
#
# Category: Shore
# Setting: The beach
# Description: Sand that is white as snow. the water is as clear as a crystal. down the shore is some cliffs
# Items: ['Sand that is white as snow', 'water is as clear as a crystal']
# ###
#
# Category: Shore
# Setting: Old docks
# Description: The shore near the docks. There is fog except on rare occasions. More dangerous than most people would like. You never know what dangers luck from creatures leaving and entering the waters.
# Items: []
# ###
#
# Category: Shore
# Setting: Turquoise shore
# Description: A beautiful turquoise color water by the shore. It is filled with many gems and gold.
# Items: ['turquoise color water', 'gold', 'mermaids', 'shiny things', 'many gems', 'gold', 'water']
# ###
#
# Category: Shore
# Setting: Pier walkway
# Description: On the seashore facing the pier, seagulls squawk as they swirl overhead. The smell of salt fills the air, and the gentle, dull roar of the waves lapping the beach is omnipresent. A gentle breeze blows, and the chatter of the villagers fishing drifts down to the shoreline from the pier.
# Items: []
# ###
#
# Category: Shore
# Setting: Coast
# Description: The coast seems to stretch on for miles in either direction.  The ocean itself has receded some and the tide has not yet rolled in.  The water laps half-heartedly at the sand and the glistening shades of seashells dot the wet sand.  All around the sand gleams a shade of white.
# Items: ['water', 'sand', 'glistening shades of seashells']
# ###
#
# Category: Shore
# Setting: Throne room
# Description: ornate and luxurious, the throne room gleams with gold and precious jewels. Priceless painting of past kings line the sides. underneath a vaulted ceiling regal a red carpet connect the throne room entrance to the golden throne itself.
# Items: ['gold', 'precious jewels', 'priceless painting', 'red carpet', 'golden throne', 'priceless painting of past kings', 'vaulted ceiling', 'red carpet', 'golden throne']
# ###
#
# Category: Shore
# Setting: Beach house
# Description: A marvelous beach house that sits upon the fine white sand of the beach. It looks mighty expensive, as the house has solid gold walls. A gigantic and lavish marble pier extends into the ocean out in front of the house.
# Items: ['A gigantic and lavish marble pier', 'the ocean', 'fine white sand', 'the beach', 'beach', 'sand', 'walls', 'pier', 'ocean']
# ###
#
# Category: Shore
# Setting: Lighthouse
# Description: The lighthouse is an off-white color, towering fifty feet over the shore. The light from the building extends out for miles past the shoreline.
# Items: ['lighthouse', 'ships']
# ###
#
# Category: Shore
# Setting: Beach house
# Description: the beach house is falling apart due to the storms, it's door is hanging and it's humid inside. There is no floor, just sand, and a hole to serve as the outhouse.
# Items: ['beach house', 'door', 'the beach house', "it's door", 'sand', 'a hole']
# ###
#
# Category: Countryside
# Setting: The forest
# Description: The forest has many trees. It has other plants too. There are animals and many livings things. The forest is very much full of life. When you look at it you might only see plants that are green and different shades of brown but there are many other living things in there too.
# Items: ['trees', 'plants', 'trees', 'plants']
# ###
#
# Category: Countryside
# Setting: Peasant's cottage
# Description: The peasant's cottage is a fairly simple wood building with a straw thatched roof.  Inside, you have a fireplace and large pot for cooking, a long wooden dinner table, and some hay filled beds lying on the floor.  There are two chests lying inside with personal belongings such as clothes and family heirlooms.
# Items: []
# ###
#
# Category: Countryside
# Setting: Meadow
# Description: Large clear outdoor meadow. Flowers of blue and white appearing in bunches here and there. The grass glows with a green light. Not much can be said about its appearance, however there is a mystical allure associated with the place as if a meadow for spirits instead of livestock.
# Items: ['Flowers', 'grass', 'meadow']
# ###
#
# Category: Countryside
# Setting: Valley of doom
# Description: The Valley of Doom is overrun by dead trees and grasses.  Eerie looking animals peer at you through the brushes.  It is a dark and wicked place.
# Items: []
# ###
#
# Category: Countryside
# Setting: A cabin
# Description: Plain, pretty basic wooden cabin.  In a field of wildflowers, there is also a pen for the chickens, a clothes line.
# Items: ['Plain, pretty basic wooden cabin', 'wildflowers', 'a pen for the chickens', 'a clothes line', 'wildflowers', 'pen', 'clothes line']
# ###
#
# Category: Countryside
# Setting: Nearby road
# Description: The road cuts through the countryside. It is a dirt road, with a fence lining the eastern side and a grassy meadow to the west.
# Items: []
# ###
#
# Category: Countryside
# Setting: Countryside
# Description: The countryside is quite nice, it's not filled with a lot of people but with travelers here and there. Some in small groups some on their own. They are hosting a campfire where everyone has some to sit and is telling stories about their adventures. Someone is showing local children how to wield some weapons. Another is offering lodge, and stable for travelers and their animals.
# Items: []
# ###
#
# Category: Countryside
# Setting: Meadow
# Description: This meadow is composed of green, luscious, rolling hills. Flowers dot the expanse. In the evening, one may stand from the hills of this meadow and see the sun set beneath the horizon off in the distance.
# Items: ['Flowers', 'green, luscious, rolling hills', 'Flowers']
# ###
#
# Category: Countryside
# Setting: Main gate
# Description: The main gate is tall and strong enough to protect the mansion from invaders, and has large wooden doors reinforced by planks and steel sheets. There are two towers on either side of the gate for the town's watchmen to use as their post.
# Items: []
# ###
#
# Category: Countryside
# Setting: Lush meadow in the country side
# Description: Green large trees surround the meadow that if filled with beautiful seasonal flowers. A deer is grazing in the far end of the field. A small dirt country road gentle crooks past on the outside of the road.
# Items: ['Green large trees', 'beautiful seasonal flowers', 'small dirt country road']
# ###
#
# Category: Countryside
# Setting: Cottage
# Description: The small cottage was white with two, shuttered windows. It was in the unique shape of a circle and was built of plaster. Smoke billowed from the chimney.
# Items: ['shuttered windows', 'chimney', 'shuttered windows', 'chimney']
# ###
#
# Category: Countryside
# Setting: Hillside mansion
# Description: I sweeping villa that rests on the grand hills. Everyone can see how grand it is when they approach from the country road. A tall, wrought-iron fence surround its grounds, which extends for miles.
# Items: ['fence']
# ###
#
# Category: Countryside
# Setting: Flower field
# Description: The flower field contains acres of wild growing flowers that are a bright pink when they are in bloom. There are woods surrounding it, but no trees in the field, only flowers. There are paths that work their way through the field.
# Items: []
# ###
#
# Category: Countryside
# Setting: Maidens cottage
# Description: Free standing in the vast countryside, with gentle rolling hills and lush green grass and vegetation sits the cottage. There are a couple of Oak trees close to the cottage as the only tall trees around for miles. Colorful Dandelions, perennials, and daisies grow wildly and freely along the hills.
# Items: ['gentle rolling hills', 'couple of Oak trees', 'Colorful Dandelions', 'herd some sheep', 'grasslands around the cottage']
# ###
#
# Category: Countryside
# Setting: Path to the manor
# Description: The outside of the manor is rather imposing with a large stone building and two immense guardian sculptures on the outside depicting mythical beasts. There are also small gardens to the left and right.  The main path itself is a cobbled one that only beckons visitors if they are worthy enough.
# Items: []
# ###
#
# Category: Countryside
# Setting: Chicken pen
# Description: The chicken pen has wire cages situated on three different levels, with hay at the bottom for the chicken's to sit in. There lie small holes in the cages for the eggs to fall through and be easily harvested by the farmers. The old wooden walls of the chicken pen are beginning to deteriorate and show signs of age.
# Items: []
# ###
#
# Category: Countryside
# Setting: Pig pen
# Description: A filthy pen where tons of squalling pigs rut and throw a ruckus, Their snorts and farts can be heard from any passerby miles before getting to the pen. The pig pen is a few feet from Farmer Bob's cottage. The pigs never sleep and are always eating and playing in the mud.
# Items: ['mud']
# ###
#
# Category: Countryside
# Setting: Hillside manor
# Description: A quaint manor that sits in the rolling hills. It is surrounded by a small stone fence and looks quite inviting to passersby. It looks like any other home that a well off business man would own.
# Items: ['quaint manor', 'rolling hills', 'small stone fence', 'home', 'bookshop']
# ###
#
# Category: Countryside
# Setting: Horse field
# Description: The horse field includes a huge plains for horses to ride. The fields are yellow and green. The place smells of musk and horse.
# Items: ['horses']
# ###
#
# Category: Countryside
# Setting: The small dirt road
# Description: This small dirt road is flanked by a lush green forest on each side with birds chirping and the occasional deer running about.  Sometimes, you can find broken down wooden wagons left behind from ambushes carried out by bandits.
# Items: []
# ###
#
# Category: Port
# Setting: The docks
# Description: The docks are a rough place with a lot of rough group of individuals who hang out there.  It is where the ships port and deport, only few know what really goes on there.
# Items: ['ships', 'ships', 'product']
# ###
#
# Category: Port
# Setting: Boat house
# Description: A small house type establishment that serves as a hang out for people about to board the boats.  There is nautical themed decor everywhere.  Life Buoys, mounted fish, replica boats.  It's all wood inside with a bar as well.  A lot of creaky looking wood too, probably weathered a good bit as the house is old itself.
# Items: ['nautical themed decor', 'Life Buoys', 'mounted fish', 'replica boats', 'a bar']
# ###
#
# Category: Port
# Setting: Fishing store
# Description: This store is a small one room stone building with wares laid about on tables.  One can see fishing poles, wooden buckets with dirt and bait inside, along with some mounted trophies.
# Items: []
# ###
#
# Category: Port
# Setting: Wharf
# Description: The waves lash gently against the wooden posts, the water here has always been calm and passive, it seems to represent the people of this small town. The fishermen here are not boisterous, they are quiet, at least when it comes to sound. They'll talk your ear off if you let them, they have lots of stories to tell. The pier here is long, it extends at least forty feet into the ocean, many ships are anchored to it, many people traverse down it buying and selling their local catches.
# Items: []
# ###
#
# Category: Port
# Setting: Pirate ship
# Description: A majestic, shimmering, black pirate ship sits upon the water. Its numerous cannons give it a menacing look. Tons of pirates hop upon its decks in a furious jig. The lone captain plods around in his cabin, plotting on where to seize his treasure next.
# Items: ['cabin', 'cannons']
# ###
#
# Category: Port
# Setting: Port skyline
# Description: The local port sits an a majestic inlet of the ocean. The countless docks are constantly bustling with new arrivals and departures. People of all kinds come here for business or leisure. On the shore sits a skyline of many buildings packed with residents going about their day. The smell of salt and seafood fills the air.
# Items: []
# ###
#
# Category: Port
# Setting: Port tavern
# Description: The port tavern is the shadiest of all the shady bars in the city. Every night, on its grimy stools at the wooden bar, you can find some of the slimiest sailors in the world. The walls are of peeling blue paint and are always dripping with condensation. Women of ill-repute line one wall, old men on the verge of passing out line another. The floor is littered with trash, barnacles, and bodily fluids. Tending the bar is a small, round man with a bushy mustache.
# Items: ['grimy stools', 'wooden bar', 'barnacles', 'bodily fluids', 'grimy stools at the wooden bar']
# ###
#
# Category: Port
# Setting: Warehouses
# Description: The warehouses are the largest structures in the port, rising well above the adjoining buildings. Constructed from virgin timber, the beams overhead support lofts that are filled to capacity with boxes, crates, and barrels full of goods from all over the world. Carefully checking each parcel that crosses the doorway, the warehouse manager knows exactly where everything belongs inside.
# Items: []
# ###
#
# Category: Port
# Setting: Dock
# Description: There are creaky wooden walkways with empty sections where boats can rest.  There are a few buildings surrounding this area that sell supplies to sailors.
# Items: ['wooden walkways', 'boats']
# ###
#
# Category: Port
# Setting: Loading dock
# Description: The loading dock is filled with life and movement. Many trucks back up into the
# Items: ['pirates', 'cargo']
# ###
#
# Category: Port
# Setting: Fish market
# Description: The port is filled with many different small shops that sell fishes caught throughout the day. It is incredibly loud and busy with many customers and fisherman walking around and haggling for a good price on the fishes. There are tons of boxes sitting on the floors everywhere filled with ice, fish, and the fishermen's belongings.
# Items: []
# ###
#
# Category: Port
# Setting: Marketplace
# Description: Merchants call out their wares and try desperately to get the attention of the wealthier passerby. People from all over the world hustle to and fro, some keenly eyeing the many tapestries, spices, tools and foods, others openly staring in wonder. Still others hurry along, heads down and avoiding eye contact. Colors, smells and sounds assault the senses. The cries of the gulls can hardly be deciphered from the chatter of the crowds, the ringing of the blacksmith's hammer, the bells of the nearby shipyard, and the hollers of the merchants.
# Items: ['tapestries', 'spices', 'tools', 'food', "blacksmith's hammer"]
# ###
#
# Category: Port
# Setting: Supply store
# Description: With so many ships docked at the port, sailor from all the ships crowd the bazaar. The supply store is filled with buyers today. The inside is plain and unadorned. Sturdy shelves hold common supplies. Along the walls are the larger items for sale.
# Items: []
# ###
#
# Category: Port
# Setting: Royal shipyard
# Description: A massive shipyard with different Five dry docks. each dry dock has several wooden cranes and rope works. The dry docks are made of stone and the water gate is all harden wood.
# Items: ['dry docks are made of stone', 'wooden cranes', 'rope works', 'water gate is all harden wood', 'wooden cranes', 'rope', 'water gate']
# ###
#
# Category: Port
# Setting: Crew berthing
# Description: The main quarters for the crew of the vessel. Its dirty, smelly and not a place where anyone but a pirate would want to stay. There are bunks stacked on bunks the place is cramped and no one goes there for any reason besides sleeping.
# Items: []
# ###
#
# Category: Port
# Setting: Ferry terminal
# Description: A huge terminal with a lot of traffic. The Ferry Terminal has a warm and positive vibe that welcomes all travelers across the land. It has an open space with a lot of illumination during the night.
# Items: []
# ###
#
# Category: Port
# Setting: Large galleon
# Description: The deck of this rather large ship is strong and freshly swapped with tar. Its mast reaches far into the sky like gleaming pillar of hope and freedom. Its sturdy ship made for long voyages with thick planks and strong rails.
# Items: ['deck', 'mast', 'mast', 'tar']
# ###
#
# Category: Port
# Setting: Captain's cabin
# Description: The captain's cabin is a complete mess. There are multiple maps on the wall, pinned over one another, each with messy writing scrawled over it and multiple X marks in random places. Papers overflow off the desk and across the floor in waves, impeding the captain as he paces, muttering angrily. The bed is messy and unmade, giving the impression that the captain has spent the night tossing and turning. Random objects have been thrown about the room.
# Items: []
# ###
#
# Category: Port
# Setting: Fishmonger's stall
# Description: A small booth near the edge of the port, it's protected by a piece of old, sun-bleached sailcloth. Baskets of freshly-caught fish, bivalves, and eels sit in the shade in stained wooden troughs of water. A small, aggressive-looking dog is chained to one table, presumably to keep cats away. The stall is redolent with the aroma of fish.
# Items: ['Baskets of freshly-caught fish', 'a piece of old, sun-bleached sailcloth', 'old, sun-bleached sailcloth', 'stained wooden troughs', 'table']
# ###
#
# Category: Port
# Setting: Quay
# Description: During the day, the quay is bustling with typical activity of a port: burly longshoremen carry crates and roll barrels away from ships for storage and sailors who still have their sea-legs saunter past on their way to drink and more adventures. By night, the quay is teeming with unsavory characters: men who are hardly men any more after losing their way through drink and gambling hunker amongst coils of rope stiffened by the salt water while rats scramble from box to box gnawing their way into the goods contained inside.
# Items: []
# ###
#
# Category: Port
# Setting: Dock at the port
# Description: This dock has seen better days.  It is wobbly and broken in areas.  There are holes through to the ocean below if you are not careful.  It is covered with every means of trash.
# Items: ['dock']
# ###
#
# Category: Port
# Setting: The village of tamerak
# Description: A thriving sea port filled with merchants, foods, women, and gold.  Hundreds of boats fill the shores, fisherman pushing out to sea and pulling into dock.  Seagulls hover silently above the merchants selling fish.  Pirates can be seen causing trouble with the locals.  Brothels and bars are in abundance, as well as the smell of fish.
# Items: []
# ###
#
# Category: Swamp
# Setting: Murky water
# Description: The water is murky and dark. There are unknown dangers lurking in it, such as alligators and poisonous snakes. Plants and trees hide more dangerous animals. It is cold.
# Items: ['water', 'plants', 'alligators', 'poisonous snakes']
# ###
#
# Category: Swamp
# Setting: Haunted swamp
# Description: A misty, foggy area with the swamp. It is dirty and smelly.
# Items: ['many ghosts', 'swamp']
# ###
#
# Category: Swamp
# Setting: Boathouse
# Description: The boathouse is a very small building with peeling paint. It is made out of wood, with one half planted in the water on stilts. Inside, there are boats floating in the water. There are hinged doors which can be opened to allow boats to come in and out. There are some ropes and other tools a boater may need stored in the boathouse.
# Items: ['boats floating', 'ropes and other tools']
# ###
#
# Category: Swamp
# Setting: Darkest part of the swamp
# Description: The light doesn't pierce the heavy overhanging trees in this near pitch black area of the swamp.  The water is extremely murky and there are occasional fins poking up from the water belonging to some kind of creature.  The air is thick and heavy and insects constantly buzz about.
# Items: []
# ###
#
# Category: Swamp
# Setting: Soldiers camp
# Description: The camp is hidden away in a light forest of trees and brush that might be hard to find if there had not been a symbol on the trees leading up to it. You can feel the anxiety of the soldiers here, as this camp is not well fortified by any conventional means, but instead is supposed to be hidden and camouflaged to throw off anyone that might pursue. The camp is nothing more than a fire and some barracks. Nothing fancy to see.
# Items: []
# ###
#
# Category: Swamp
# Setting: Witch's house
# Description: Old and worn by the time that has passed and the environment where it was built, the wood rotted and worn by the swamp. It should have sunk years ago into the swamp but somehow it remains standing despite the ever sinking earth around it.
# Items: ['building', 'swamp', 'wood', 'earth']
# ###
#
# Category: Swamp
# Setting: Troll's bridge
# Description: Muddy and murky waters lie under a bridge that seems to go nowhere. It is made of cobblestone and just as long as it is wide. Beneath it live a hideous troll that makes people pay to cross.
# Items: ['waters']
# ###
#
# Category: Swamp
# Setting: A military outpost at the heart of the swamp
# Description: Moist, and murky the bog remained. As you reach the outpost that description doesn't change seeing the bog gobbers swimming through the thick water, and fermenting goblins perched atop the outpost's walls.
# Items: ['walls', 'thick water']
# ###
#
# Category: Swamp
# Setting: Bank
# Description: This is a grassy area that surrounds much of the swamp.  It's a plain field with some trees nearby along with some rocks.
# Items: ['trees', 'rocks', 'swamp', 'field', 'trees', 'rocks']
# ###
#
# Category: Swamp
# Setting: Bog
# Description: Frogs croak in the reeds that surround the bog. The water is very murky and underneath the surface tadpoles dart around. There are minimal places to stand to stay dry.
# Items: ['reeds', 'reeds', 'bog', 'water']
# ###
#
# Category: Swamp
# Setting: Quicksand pit
# Description: A large, gurgling pit of quicksand. Many adventurers and poor critters lie at the bottom of the pit. The pit is surrounded by an extensive swampland and is shielded by the many trees and shrubs that surround it.
# Items: ['trees', 'shrubs', 'trees', 'shrubs']
# ###
#
# Category: Lake
# Setting: The lagoon
# Description: The Lagoon is a dark and mysterious place during the night hours.  A lot of moss and lily pads surround the shore.  The water is very murky.
# Items: ['Lagoon', 'moss', 'lily pads']
# ###
#
# Category: Lake
# Setting: Lake
# Description: The beautiful lake glistens in the sun as water can be seen in all directions. you can see several feet beneath the water because it is so clear.
# Items: ['water']
# ###
#
# Category: Lake
# Setting: Northern shore
# Description: The lake gives way to a slightly sandy and rocky shore. It is dotted with small shrubs and a few trees, but mostly it is a fairly open expanse. It is covered in places by a green short grass. The lake level falls away swiftly from the beach going from a few feet to well over ten feet in a short span.
# Items: ['lake', 'small shrubs', 'trees', 'green short grass', 'clothes', 'small alter', 'small shrubs', 'trees', 'green short grass', 'small alter']
# ###
#
# Category: Lake
# Setting: Clean water lake
# Description: The lake is crystal clear, lined with trees, to the far back of the lake there's a small formation of rocks almost like a small waterfall allowing water to flow into the lake. It's quite beautiful, the sun bathing the surrounding area in a warmth so comforting you could easily fall asleep on the shore. There's an old wooden bath, for its age it seems to look like almost new, and rarely used. There are no animals nearby except for birds softly chirping in the trees.
# Items: []
# ###
#
# Category: Lake
# Setting: Dock
# Description: The wood used to make the dock is of highest quality, commissioned from trees that stand towering in the local forests. Despite time having passed it has been taken care of to the point where even a hint of warping from the water beneath will have a plank torn and replaced within a night.
# Items: []
# ###
#
# Category: Lake
# Setting: Brim canal
# Description: Slow flowing branching from the large lake, is the brim canal where dozens and dozens of brim fish call it home. The edges are lined with irregular rocks and lush green vegetation. Tall pine trees overlook the canal and lake making it a peaceful place to just go sick and watch the brim swim by.
# Items: ['dozens and dozens of brim fish', 'irregular rocks', 'lush green vegetation', 'Tall pine trees', 'some clothes']
# ###
#
# Category: Lake
# Setting: Fishing shack
# Description: The fishing shack is a small wooden structure that is crudely built and is surrounded by boats. The wood flooring around the shack is well weathered and often used.
# Items: ['small wooden structure', 'boats', 'wood flooring']
# ###
#
# Category: Lake
# Setting: Lakeside house
# Description: Its white and vibrant, certainly a location for some lord, It has 3 floors, and fine gardening surround the house. Its open and breezy this place is calm and peaceful.
# Items: ['floors']
# ###
#
# Category: Lake
# Setting: The swimming hole
# Description: The swimming hole is calm and clear.  The sun sparkles off the ripples that form on the surface of the water.  Fish occasionally jump from the water and splash back in.
# Items: []
# ###
#
# Category: Lake
# Setting: Fishing dock
# Description: Folks call the area a Lake, but it's more like a pond.  Small and unimportant looking, yet peaceful.  The dock is no prize winner either.  Narrow in width, boards broken with several down right missing all together!  No tree nearby, no canopy, nothing to shade oneself on a hot day while fishing.  The watering hole may look small in size, but it deceives the eyes.  The water is as deep as the heavens.  No man knows what lurks beyond the light in this Lake.
# Items: []
# ###
#
# Category: Lake
# Setting: Drinking water lake
# Description: Surrounded by skittering chipmunks and chirping crickets, the drinking lake teems with life. Flora and fauna both thrive near the pristine waters. Tall thick plant life surrounds the lake, with strong roots and stems protruding from the nutrient rich soil. The lake water shimmers in the sun, so clear and clean that one can see the rock lake floor many feet below.
# Items: []
# ###
#
# Category: Lake
# Setting: Island
# Description: This island is located in the center of a lake. It is smaller than a ship and covered in moss.
# Items: ['moss']
# ###
#
# Category: Lake
# Setting: Launching point
# Description: The Launching point features a number of large wooden planks sitting at a downward slope going straight into the water.  On each side of the launching point there sits a large, ornate bronze figure of a light house that is used to tether the ships to the dock and keep them from casting away while the sailors prepare to board the ship. The launching point is very narrow, with large stone braces on either side of the dock.
# Items: []
# ###
#
# Category: Graveyard
# Setting: Main street
# Description: main street is bleak and outdated. it wears the atmosphere of the cemetery based on association. it is dark even in sunlight and has a unique odor
# Items: []
# ###
#
# Category: Graveyard
# Setting: Abandoned workers shed
# Description: Moss now grows across what was once a red painted wooden shed, standing in the area just outside the graveyard. The wood shed is splintering, and there is evidence that termites have eaten away at the walls as holes poke through the shed. Inside the shed there lies leaves and plants that have been dragged in their by the wild animals that at one point called the abandoned shed their home.
# Items: []
# ###
#
# Category: Graveyard
# Setting: A cursed grave
# Description: The sun never seems to shine on this grave.  The letters on the tombstone have long since faded, and many stories are told about whose bones lay buried in the dirt.  Until recently, it was overgrown with grass and weeds.  Someone had come and cleared the weeds, and the dirt looked as if it had been turned over.
# Items: ['dirt', 'bones']
# ###
#
# Category: Graveyard
# Setting: An unfinished mausoleum
# Description: Two-and-a-half walls of the finest, whitest stone stand here, weathered by the passing of countless seasons. There is no roof, nor sign that there ever was one. All indications are that the work was abruptly abandoned. There is no door, nor markings on the walls. Nor is there any indication that any coffin has ever lain here... yet.
# Items: ['walls of the finest, whitest stone']
# ###
#
# Category: Graveyard
# Setting: Graveyard
# Description: The dark and gloomy graveyard has fog all the time and has a large amount of graves everywhere you step. There are whispers and shadows that appear from the darkness and there is always a light drizzle that seems to moisten the place.
# Items: ['graves']
# ###
#
# Category: Graveyard
# Setting: Main graveyard
# Description: This is an ominous place that a thick fog envelops.  There are rows of primitive gravestones and crosses along with some angelic statues for the more wealthy.  You can hear sobs in the distance as a funeral ceremony is underway.
# Items: []
# ###
#
# Category: Graveyard
# Setting: Dead tree
# Description: The dead tree is many, many decades old. It lies on its side, and is rotted through and through. It is blackened on its top. It is humongous. It would have been very, very tall once upon a time. It smells dank. It cannot be moved.
# Items: []
# ###
#
# Category: Graveyard
# Setting: Old crypt
# Description: Broken stones and a iron gate closing the entrance with a name placard that the name is worn off.
# Items: ['stones', 'gate', 'placard', 'stones', 'iron gate', 'name placard']
# ###
#
# Category: Graveyard
# Setting: The fountain
# Description: the fountain is the only thing you can hear in the graveyard. It's eerily quiet, not even a bird chirping. The fountain is teen feet high, and it is dry as a desert. It makes the graveyard more eerie than any other one.
# Items: ['fountain', 'weeds', 'grass', 'The fountain']
# ###
#
# Category: Graveyard
# Setting: Reception area
# Description: The building itself is ordinary in appearance and is somewhat foreboding.  It is surrounding by a dense fog and high grass.  Sometimes, one can hear whispers in the wind.
# Items: ['The building', 'dense fog', 'high grass', 'the wind', 'high grass', 'graveyard']
# ###
#
# Category: Graveyard
# Setting: Cemetery
# Description: Dim and low lit. The aura from this cemetery emits sadness and pain perpetually. You can feel and sense the eerie nature of the graveyard crawl up your spine. There seems to be a slight fog slowly making its way across the open parts of the cemetery.
# Items: ['a slight fog']
# ###
#
# Category: Graveyard
# Setting: Tombstones of the kings
# Description: The tombstones of the kings are the most notable part of the graveyard. These tombstones are erected from fine marble and have piles of gold and riches lying next to them. A small metal fence surrounds this section of the graveyard, and cuts it off from the common folk.
# Items: ['tombstones', 'piles of gold and riches', 'A small metal fence']
# ###
#
# Category: Abandoned
# Setting: An abandoned castle on an ocean cliff side
# Description: The castle is located at the top of an erosive cliff face of a vast ocean. An entire wing of the castle appear to have collapsed into the ocean due to the erosion of the cliff face, perhaps the reason why the castle now lay abandoned.
# Items: ['castle', 'cliff', 'ocean']
# ###
#
# Category: Abandoned
# Setting: Weathered shack
# Description: A weathered shack with a roof made of old broken tiles sits in the middle of the forest. The wood is starting to split and the shack appears as if it will crumble at any moment.
# Items: ['old broken tiles', 'wood', 'shack']
# ###
#
# Category: Abandoned
# Setting: A lonely island
# Description: the island only has one coconut tree and waves crashing and appearing missing wooden boat parts. The pirates are nowhere to be seen.
# Items: ['a coconut tree', 'skeletons', 'coconut tree', 'wooden boat parts', 'skeletons']
# ###
#
# Category: Abandoned
# Setting: Abandoned mine entrance
# Description: The abandoned mine is located in a field with a few trees. It is unable to be seen from far away. The closer you get the more you  notice the ground caving in around the hole. When you peer down into the mine, you see crumbling walls and concrete and a hole so deep you can't see where it ends.
# Items: []
# ###
#
# Category: Abandoned
# Setting: Gold mine
# Description: The entrance is very unstable, with parts falling to the ground. As you enter, the walls have been crudely chipped away to make the path to the old mine. There is trash from the previous miners scattered on the dirt ground. Rocks are all around the area, where one would stumble as they go inside. It used to be a very productive gold mine, now falling to bits. There are broken lanterns, with shattered glass.
# Items: ['Rocks', 'broken lanterns', 'path to the old mine', 'broken lanterns']
# ###
#
# Category: Abandoned
# Setting: Abandoned mine
# Description: It's dark, cold, and musty. There is old machinery lying around, rusting, and discarded tools lie on the ground. Cobwebs are everywhere. The rock walls are damp, and a trickle of water can be heard coming from somewhere off in the dark.
# Items: ['old machinery', 'Cobwebs', 'rock walls', 'old machinery lying around, rusting', 'Cobwebs are everywhere']
# ###
#
# Category: Abandoned
# Setting: The forsaken castle
# Description: Old and creepy, the castle has been abandoned for centuries now. It is broken and destroyed.
# Items: []
# ###
#
# Category: Abandoned
# Setting: Land beyond the wasteland
# Description: Not a man in sight nor an animal to hear. This land is completely barren and hot, unfit for any agricultural activity. It has been left abandoned so much so that the King has not even had time give it a name, so people simply refer to is as "Abandoned"
# Items: []
# ###
#
# Category: Abandoned
# Setting: Ruined house
# Description: A dilapidated wooden structure with a caved in roof and debris everywhere.  Even the trees outside the house are falling apart.  There's waist high grass leading to the house along with a dirt path.
# Items: ['debris', 'debris', 'trees']
# ###
#
# Category: Abandoned
# Setting: Collapsed west wing
# Description: The rocks have all but fallen into the ocean.  There is moss and other plant life climbing the remaining rocks, making it a very moist and gloomy environment.  There are some small left-behind pieces of what appear to have been some furniture, and possibly a cradle.
# Items: []
# ###
#
# Category: Cave
# Setting: Secret tunnel
# Description: Your senses are met with the dank moisture of a secret tunnel. The stony walls are full of lichen and cave moss. Stalactites and stalagmites pepper the small channel, which bleeds in a pinpoint light from a far off point. The chill air of the King's forest whistles through the tunnel interior.
# Items: []
# ###
#
# Category: Cave
# Setting: Cave
# Description: This cave is big but has no lights. It is made from stone and has a small pool of water in the back. The floor is made from dirt.
# Items: ['a small pool of water', 'dirt', 'the village', 'stone', 'small pool of water', 'floor', 'dirt']
# ###
#
# Category: Cave
# Setting: Bat room
# Description: It is cold, dark and filled with bats. it is humid and there are some paddles on the ground.
# Items: ['paddles']
# ###
#
# Category: Cave
# Setting: Cave exit
# Description: The large cave is covered along the walls with bright torches.  A large hole has been carved in the ceiling of the cave, right above the ladder that descends into the underground cave.  On good bright days, sunlight directly surround the hole with the gold ornate ladder descending into the underground part of the cave.  On the walls of the cave the torches illuminate many ornate drawings and paintings mainly dealing with the history of Kings of the realm.
# Items: []
# ###
#
# Category: Cave
# Setting: Entrance
# Description: The entrance to his cave is covered in hanging moss with shrubs on either side of the entrance.  The path to this cave is a small dirt one with low grass on the floor.
# Items: ['moss', 'shrubs', 'dirt', 'grass']
# ###
#
# Category: Cave
# Setting: Bandit lair
# Description: The outside of the cave looks normal. Inside goes for about 10 feet til' you reach the front of the Bandit lair. Inside is a barracks and dining hall with beds and a big table with chairs around it.
# Items: ['beds', 'big table', 'chairs']
# ###
#
# Category: Cave
# Setting: Underground chamber
# Description: This location is very gloomy, damp and magical. Has a lot of geodes and various types of crystals.
# Items: ['crystals', 'mystical lions']
# ###
#
# Category: Cave
# Setting: Underground cavern
# Description: The underground cavern is covered in precious metals and gems. In the wall, rubies, emeralds and sapphires sparkle. There is gold and silver, shining brightly. It is cool in the underground cavern.
# Items: ['precious metals', 'rubies', 'sapphires', 'rubies', 'sapphires', 'gold', 'silver']
# ###
#
# Category: Cave
# Setting: The troll's lair
# Description: Covered with rotting meat from nearby wildlife, the Troll's lair reeks of death.  If the stench alone wasn't enough to scare off an unfortunate travelers who stumbled upon it, the bones of unlucky spelunkers would be.  The Troll places his spoils near the numerous stalagmites on the damp cave wall, his red eyes patiently scanning the dark cave interior for anything that may disturb his isolation.
# Items: ['rotting meat', 'bones', 'stalagmites', 'rotting meat', 'bones of unlucky spelunkers', 'stalagmites']
# ###
#
# Category: Cave
# Setting: Underwater cave
# Description: The underwater cave is dark and rocky. Inside the cave fish and tadpoles have taken over. The water is cold, no light gets in. Once inside, a rocky outcrop allows swimmers to come up for air.
# Items: []
# ###
#
# Category: Cave
# Setting: The underground river
# Description: The river is small and winding and hard to see because there are no lights within its' location. The river has many colorful rocks and gems.
# ...
# Items: ['frames', 'lantern', 'morsel', 'table']
# ###
#
# Category: Magical realm
# Setting: The cabin of an ogre
# Description: The wooden walls of the cabin are crudely adorned with a green, suspicious ooze. A dusty rug lays on the cold wooden floor of the cabin, dimly lit with a lantern situated in a corner in front of a large cobweb.
# Items: ['dusty rug', 'lantern']
# ###
#
# Category: Magical realm
# Setting: Swamp
# Description: The swamp is glowing with wonder and color.  There are parts that range from dark red to bright yellow.  People often visit here to speak with the gods and claim it can be both harmful to those it dislikes and healing to those who it deems worthy.
# Items: []
# ###
#
# Category: Magical realm
# Setting: Secret magician's workshop
# Description: This is the hidden workshop of the most powerful wizard in the land.  There are ornate tapestries on the walls depicting wizards using their powers and potions in battle.
# Items: ['ornate tapestries']
# ###
#
# Category: Magical realm
# Setting: The fountain of youth
# Description: The water here bubbles softly, cascading down the golden framework of the fountain.  The water is clear as crystal, and shimmers softly with a faint glow that doesn't seem to quite reflect the light around it.  The fountain itself is made of elaborately filigrees of gold and silver that twist and curve to show the sparkle of the water best, and it breathtaking to behold. While the fountain's beauty is what first draws the eye, a careful glace down at the earth around it reveals a frightening sight.  Skeletons, some clad in ancient armor from kingdoms long turned to dust, others worn down so that even what clothing they had has long since disintegrated, litter the earth.  Beautiful flowers grow up from them, partially obscuring whatever carnage caused these people to perish.
# Items: ['water', 'fountain', 'water', 'flower', 'ancient armor']
# ###
#
# Category: Netherworld
# Setting: Torture chanber
# Description: This room is very grim and evil. There are many torturing devices strewn about. There is also blood all over the walls. The smell is putrid and relentless.
# Items: ['room', 'devices', 'walls']
# ###
#
# Category: Netherworld
# Setting: Cavern
# Description: a lonely and isolated place, a cavernous hole in the side of a craggy mountain that leads to a network of underground tunnels.
# Items: ['hole', 'underground tunnels', 'souls']
# ###
#
# Category: Netherworld
# Setting: The thrones of death
# Description: The main part of this room room would be the throne.  It is a shiny black with some gold ornate decorations on it. It sits on a black and gold pedestal. There is  a smaller throne in the room decorated in purple and gold.   It does not sit on a pedestal.  The room is decorated in tones of purple and blue with black accents.  This signifies death.  There are paintings of dolphin on the all.  Also to signify death.  The dolphins are typically gray.
# Items: ['throne', 'pedestal', 'paintings']
# ###
#
# Category: Netherworld
# Setting: Lord's castle
# Description: This is the location in the netherworld where the Lord and controller lives.  It is in the center of the netherworld and is difficult to reach as it is built on high rocky cliffs.
# Items: ['rocky cliffs']
# ###
#
# Category: Netherworld
# Setting: Reaper's lair
# Description: A room that gets very little light except for a dim candle on a pole. The walls are made of blackened stones. A wooden door with a heavy lock stands tall.
# Items: ['wooden door', 'heavy lock']
# ###
#
# Category: Netherworld
# Setting: Lower dungeon
# Description: The lower dungeon is set below the mail hall. It is dark, lit by only a few dim torches. Water is constantly dripping down the walls, giving it a dank and musty smell. There are manacles and cages set along the walls. In the middle of the room sits a table with manacles on all corners which are attached to a large rotating lever.
# Items: ['torches', 'manacles', 'cages', 'walls', 'table', 'lever']
# ###
#
# Category: Netherworld
# Setting: Withered gardens
# Description: Dead trees and plants cluster in this garden, their branches thin and bone-like.  As they sway in the ghostly breeze, they look almost like skeletal hands, grasping for any living presence nearby to drain the life out of them.  There is a a dried up fountain made of cracked marble, and a bench that is made of rotting wood.  It looks as though it might turn into dust at the slightest touch.
# Items: ['trees', 'plants', 'garden', 'branches', 'fountain', 'marble', 'bench']
# ###
#
# Category: Netherworld
# Setting: Devil's den
# Description: The Devil's Den is dark and fiery; no one dares to look at the blood covered walls. Skulls on stakes line the walls, with piles of bones scattered on the floor.
# Items: ['skulls on stakes', 'piles of bones', 'souls']
# ###
#
# Category: Netherworld
# Setting: The pit of despair
# Description: A sinking hole in the ground, roughly 15 feet in diameter, covered by the grabbing appendages of sinners who once walked in the land of the living. A cacophony of moans, screams and scratching bellows from the depths of the cavern. There is a pool of blood, tears and excrement at the bottom of the hole where limbs can be faintly seen trying to reach the surface but never able to.
# Items: []
# ###
#
# Category: Netherworld
# Setting: Dungeon
# Description: Dark and dreary, the dungeon hosts a portal for evil to access the netherworld. The moist dank smell casts doubt of goodness as you see the drab construct of jail cells lining the perimeter of the room.
# Items: ['portal for evil to access', 'jail cells', 'secrets of evil']
# ###
#
# Category: Netherworld
# Setting: The dark kings throne room
# Description: Filled with skeletons and zombies and dead bodies, the throne room of the Dark King has literally no light.
# Items: ['skeleton', 'zombies', 'dead bodies']
# ###
#
# Category: Netherworld
# Setting: Whipping chamber
# Description: a stone wall with straps for tying up men and women to be punished for their immortal sins
# Items: ['stone', 'straps']
# ###
#
# Category: Netherworld
# Setting: The devils castle
# Description: It is a castle that has burning flames that burn for eternity all around it. It is the tallest structure in all of the netherworld. It is dark and pitch black in some areas. It can be seen from miles away.
# Items: ['castle', 'flame', 'structure', 'ground']
# ###
#
# Category: Netherworld
# Setting: Viewing room
# Description: The viewing room is where those who have passed on come to watch their family members in the living world one day per year. The room resembles an opera theater. There are seats throughout the room and boxes for those who were wealthy in life to sit in. There is a stage with a large magical dome on it for viewing.
# Items: ['room', 'seats', 'boxes', 'stage', 'dome', 'ball']
# ###
#
# Category: Netherworld
# Setting: Lava lake
# Description: A vast lake of molten magma. The temperature is well above that which would kill most mortal beings. It is surrounded by black rock formed by cooled magma. The bubbling pit seems entirely devoid of life.
# Items: ['molten magma', 'black rock']
# ###
#
# Category: Supernatural
# Setting: Bridge in the forest
# Description: You are at a bridge. It is old and used very rarely. It is dim and foggy. The brigde is large and there is a small stream below it.
# Items: ['bridge', 'stream', 'road', 'forest']
# ###
#
# Category: Supernatural
# Setting: The glade of mysteries
# Description: The leaves of the trees surrounding this glade glow unnaturally, as though lit from within.  There seems to be almost a presence to this place, a waiting watchful force.  Bits of music sound occasionally, tunes that seem familiar and yet quite alien, as though played by someone who had only heard the melody described to them, instead of hearing it themselves.  And yet all this pales in comparison to the pool found in the center.  The water gleams silver, seemingly absorbing and reflecting back the light of the trees around it tenfold.  Though there is a soft breeze that blows through the glade, there is not a ripple to be seen on the water's perfectly mirrored surface.
# Items: ['leaves', 'trees', 'glade', 'pool']
# ###
#
# Category: Supernatural
# Setting: Stonehenge
# Description: Technical and advanced, the enormous stones stand looking as if they are placed on top of each other by divine design. The green grass is a stark contrast to the gray stones hovering in the distance.
# Items: ['green grass', 'gray stones']
# ###
#
# Category: Supernatural
# Setting: Fighting arena inside tourney grounds
# Description: Filled with embroidered banners and filled with a crowd aching for entertainment, the fighting arena offers glory to all who enter. The arena itself is covered in orange dirt and surround by emblems and crests of all the knights who participate. There are weapon racks sprinkled alongside the edge of the arena.
# Items: ['banners', 'arena', 'dirt', 'emblems', 'crests', 'weapon racks']
# ###
#
# Category: Supernatural
# Setting: Astral plane
# Description: An area between worlds where the physics known to man become irrelevant. It is a space beyond time that is home to being spectral and inconceivable to those without the eyes to see them.
# Items: ['astral plane', 'abode']
# ###
#
# Category: Supernatural
# Setting: Magic room
# Description: A room that once entered, cannot be escaped. The walls are all mirrors, and you can never again find the door.
# Items: ['walls', 'door']
# ###
#
# Category: Supernatural
# Setting: Goddess hollow
# Description: The Goddess Hollow is a place created to worship woodland spirits. It is a small, closet-like room in a hollowed out tree that has existed for hundreds of years. Within the hollow there are piles of sticks, flowers, and home-made items presented to the woodland spirits.
# Items: ['hollowed out tree', 'piles of sticks, flowers, and home-made items', 'gifts']
# ###
#
# Category: Supernatural
# Setting: Haunted basement
# Description: The basement is cold, damp, and dark. What little light coming in from the window is blotted out and dimmed by the spider webs sprawled across its surface. The shadows in the corners of the room appear nearly pitch black, and it almost feels as if something is looking back at you from within them.
# Items: ['window', 'web', 'concrete', 'documents', 'journal', 'house']
# ###
#
# Category: Supernatural
# Setting: Ghost monk quarters
# Description: a simple room for an undead monk. There is an uncomfortable bed, no windows, a small table with a candle, some illustrations in a book, and not much else. There is a stool
# Items: ['uncomfortable bed', 'small table with a candle', 'some illustrations in a book', 'stool']
# ###
#
# Category: Underwater aquapolis
# Setting: Research lab
# Description: The research lab is the main science hub of the aquapolis. Dozens of scientists are working on a myriad of different projects.
# Items: []
# ###
#
# Category: Underwater aquapolis
# Setting: The dungeon
# Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Items: ['flame', 'walls', 'rot', 'gangrene', 'death', 'decay', 'moldy', 'iron maiden', 'spike', 'dried blood']
# ###
#
# Category: Underwater aquapolis
# Setting: Toad hollow
# Description: Toad Hollow is a filthy room within the Underwater Aquapolis. When you enter, you are greeted by the reek of scummy pond water. You enter Toad Hollow through a drainage pipe that you have to crawl through. Once inside Toad Hollow, you can stand up, but you still don't feel comfortable with your surroundings. As far as the eye can see there is muddy water in a circular basin with lily pads floating in it. On the pads, giant toads jump back and forth making gurgling, croaking sounds. As you wade deeper into Toad Hollow, the water comes up to your waist and you see the flash of a fin. There is legend that a creature lives in the center of Toad Hollow that is half human, half monster. Not even the strongest knight has been brave enough to examine it. The fin disappears back underwater but there is a red glint suggesting eyes are watching you. When you reach the other side of the basin, you crawl into another drainage pipe and feel relieved that you're out of this place.
# Items: ['pads', 'drainage pipe']
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater marketplace
# Description: The marketplace is the main hub for the residents of the aquapolis. With high ceilings and bright, colorful flags at each market stand, the place seems to stretch on forever. Near the entrance, there is a young boy attempting to sell the latest news of the kingdom.
# Items: ['news of the kingdom', 'colorful flags', 'market stand']
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater aquapolis
# Description: The underwater aquapolis is a massive and ornate city at the bottom of the ocean. The walls of the buildings are made or coral, pearl, and seashells. Schools of fish swim in and out of the circular holes in the walls that act as windows. The aquapolis is illuminated by florescent rocks and shells that line every building.
# Items: ['coral, pearl, and seashells', 'florescent rocks and shells', 'beautiful and priceless items']
# ###
#
# Category: Underwater aquapolis
# Setting: Dry dock room
# Description: The room is located on the border wall of the aquapolis. There is one on the far north and far south side.
# Items: ['dry dock', 'door']
# ###
#
# Category: Underwater aquapolis
# Setting: Neptune's throne room
# Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# Items: ['painted walls as blue as the sea itself', 'tables constructed of beautiful coral', 'decorative shells', 'ceiling']
# ###
#
# Category: Underwater aquapolis
# Setting: The lords treasury
# Description: Deep inside the volcanic cave that is the foundation of the aquapolis lies the treasury.  Some believe its existence is a myth, but others claim they have been there.  Those that claim they have seen it say you must dive out of the aquapolis' basement while holding your breath, through the cold deep water that is filled with deadly volcanic gas.  The treasury room itself is a dry cave filled with riches from the very infancy of the empire
# Items: ['riches from the very infancy of the empire']
# ###
#
# Category: Underwater aquapolis
# Setting: Geothermal valley
# Description: Deep and warm the geothermal valley boasts a reviving epicenter for all to migrate to. The warm bursts of heat send bubble around the perimeter of the valley reflecting colors of green and blue.
# Items: []
# ###
#
# Category: Underwater aquapolis
# Setting: The marketplace
# Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# Items: ['wares', 'stalls', 'colorful dyes', 'water']
# ###
#
# Category: Underwater aquapolis
# Setting: Farmhouse
# Description: a small house on a seaweed plantation, small and rustic, really only the single room with a closet, maybe, a table and some chairs
# Items: ['table', 'chair']
# ###
#
# Category: Underwater aquapolis
# Setting: Tool shed
# Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Items: ['shed', 'tools', 'hooks', 'hoe', 'shovel', 'seaweed', 'shack']
# ###

# %%
# !head fine_tuning_location_items.jsonl
# Out:
# {"prompt": "Category: Forest\nSetting: Woodlands\nDescription: The lush hunting grounds cover acres of land, tall trees and thickets of bushes sprawling across the land. Fields of open land are under the deep blue sky, showing the depth of the landscape. The grounds forest is thick but full of light, letting the multitude of wildlife be seen by the naked eye. The abundance of greenery makes it a prime location for hogs and oxen as they explore the land.\n", "completion": "Items: []\n###\n"}
# {"prompt": "Category: Forest\nSetting: Forbidden forest\nDescription: The forbidden forest is a dark and very scary place. The trees are covered in spider web nets and huge spiders. The forest echoes sounds of witches' laughs and creepy crawly animals.  There is a brisk breeze that runs through the trees that will put chills down your spine.\n", "completion": "Items: []\n###\n"}
# {"prompt": "Category: Forest\nSetting: North forest\nDescription: Filled with huge trees, the forest is home to many types of animals. Huge predators such as tigers and bears roam the grounds as do small animals like squirrels. Colorful birds fly among the trees. Wildflowers grow on the ground. Dappled sunlight streams through the huge canopy of trees.\n", "completion": "Items: []\n###\n"}
# {"prompt": "Category: Forest\nSetting: Ant hill\nDescription: The ant hill is very large, over 5 feet high, and is wrapped around the base of a pine tree. The ants are huge compared to normal ants, and jut in and out of large holes in the ant hill. Bones of animals and even people can be seen sticking out of the red dirt ant hill.\n", "completion": "Items: []\n###\n"}
# {"prompt": "Category: Forest\nSetting: Unsettling forest area\nDescription: The forest is actually very creepy even during the day. The trees are so tall that they block the sunlight. There is always fog in the forest which makes it very hard to see. There are a lot of mushrooms near the trees and none of them are edible\n", "completion": "Items: []\n###\n"}
# {"prompt": "Category: Forest\nSetting: A wooded magical village\nDescription: The village lay hidden in a secret grotto that is set in a sort of valley between trees. The village is populated by child-like peoples who wear clothes made of various plant matter such as large leaves and vines. The homes are made of wood, and seemingly blend into the green dense backdrop.\n", "completion": "Items: ['clothes', 'plant matter', 'large leaves', 'vines', 'homes', 'clothes made of various plant matter such as large leaves and vines']\n###\n"}
# {"prompt": "Category: Forest\nSetting: Entrance to the pine trees\nDescription: Very tall and towering pine trees that create a dark canopy of shade. Long skinny trees sway in the sky from the soft breeze. Pine needles scatter the ground like plush carpet.\n", "completion": "Items: ['towering pine trees', 'Long skinny trees', 'Pine needles', 'needles']\n###\n"}
# {"prompt": "Category: Forest\nSetting: Woods\nDescription: The woods are vast. Everywhere you turn it all looks the same. There are scratches on the trees from lost travelers marking their path. There are sounds coming from everywhere and yet no where. There are faint yellow circles up in the trees and bushes, possibly eyes starting at you.\n", "completion": "Items: []\n###\n"}
# {"prompt": "Category: Forest\nSetting: Along the banks of a river in the forest\nDescription: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.\n", "completion": "Items: ['river', 'fish', 'insects', 'grass', 'river', 'riverbank']\n###\n"}
# {"prompt": "Category: Forest\nSetting: Mysterious forest outskirts\nDescription: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.\n", "completion": "Items: ['trees', 'food']\n###\n"}

# %%
# !openai api fine_tunes.create -t fine_tuning_location_items.jsonl -m curie
# Out:
# Upload progress: 100% 224k/224k [00:00<00:00, 393Mit/s]
# Uploaded file from fine_tuning_location_items.jsonl: file-eNHOBuLarPn5uvkKswfljQjy
# Created fine-tune: ft-uBmnY7J7B3LoJoH2IXYcEoU3
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2022-01-30 18:20:43] Created fine-tune: ft-uBmnY7J7B3LoJoH2IXYcEoU3
# [2022-01-30 18:20:49] Fine-tune costs $0.57
# [2022-01-30 18:20:49] Fine-tune enqueued. Queue number: 0
# [2022-01-30 18:20:52] Fine-tune started
# [2022-01-30 18:24:40] Completed epoch 1/4
# [2022-01-30 18:27:47] Completed epoch 2/4
# [2022-01-30 18:30:52] Completed epoch 3/4
# [2022-01-30 18:33:58] Completed epoch 4/4
# [2022-01-30 18:34:25] Uploaded model: curie:ft-cis-700-31-2022-01-30-18-34-23
# [2022-01-30 18:34:28] Uploaded result file: file-PvCoPAuwbMzyExTCmCZkt39J
# [2022-01-30 18:34:28] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m curie:ft-cis-700-31-2022-01-30-18-34-23 -p <YOUR_PROMPT>

# %%
def get_items_at_location(category, location_name, location_description, finetuned_model):
  response = openai.Completion.create(
      model=finetuned_model,
      prompt="Category: {category}\nSetting: {location}\nDescroption: {description}\nItems:".format(
          category=category.capitalize(),
          location=location_name.capitalize(),
          description=location_description.capitalize()
      ),
      temperature=0.7,
      max_tokens=64,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0,
      stop=["###"]
      )
  string_result=response['choices'][0]['text'].replace("[","").replace("]","").replace("'","").strip()
  array=string_result.split(", ")
  return array

# Replace with your model's name
finetuned_model = "curie:ft-cis-700-31-2022-01-30-18-34-23"
category = "Underwater aquapolis"
location_name = "Neptune's throne room"
location_description = "A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves."

items = get_items_at_location(category, location_name, location_description, finetuned_model)
print(items)
# Out:
# ['painted walls as blue as the sea itself', 'tables constructed of beautiful coral', 'decorative shells', 'ceiling']

# %%
# get single item description in one specific location
def get_single_item_description(room_id, rooms_by_id, light_environment, item_name, item_description):
  """
  This generates a prompt and a completion which can be used to fine-tune OpenAI.
  This version just gnnerates 
  """
  prompt = ""
  completion = ""
  prompt += "Category: {category}\n".format(category=rooms_by_id[room_id]['category'].capitalize())
  prompt += "Setting: {setting}\n".format(setting=rooms_by_id[room_id]['setting'].capitalize())
  prompt += "Description: {description}\n".format(description=rooms_by_id[room_id]['description'])
  prompt += "Item: {item_name}\n".format(item_name=item_name)
  completion += "Item_Description: {item_description}\n".format(item_description=item_description)
  completion += "###\n"

  return prompt, completion


def create_item_description_finetuning_data(filename='fine_tuning_single_item_description.jsonl'):
  fine_tuning_data = []
  for category in categories:
    rooms = rooms_by_category[category]
    for room_id in rooms:
      items=rooms_by_id[room_id]['ex_objects']
      for item_id in items:
        data = {}
        item=light_environment["objects"][str(item_id)]
        item_name=item["name"]
        item_description=item["descriptions"]
        prompt, completion = get_single_item_description(room_id, rooms_by_id, light_environment, item_name, item_description)
        data['prompt'] = prompt
        data['completion'] = completion
        print(prompt, end="")
        print(completion)
        fine_tuning_data.append(data)

  with open(filename, 'w') as out:
    for data in fine_tuning_data:
        out.write(json.dumps(data))
        out.write('\n')

create_item_description_finetuning_data()
# Out:
# Streaming output truncated to the last 5000 lines.
# ###
#
# Category: Inside castle
# Setting: Dining hall
# Description: The dining hall is a grandiose room with enormously tall ceilings. Their is one long wooden dining table, with two huge chairs on each end, and normal benches on the sides. The walls of the room are decorated with huge elegant tapestries depicting memories and moments of the kingdom. Their is a stage for performers, and there are many windows that offer spectacular views of the beautiful castle grounds.
# Item: Mugs
# Item_Description: ['The engravings on the mugs detail the ancient battles of heroes.', 'This mug would be perfect for having a hot drink. It is glassy so you can see right through it.']
# ###
#
# Category: Inside castle
# Setting: Banquet hall
# Description: Cherry wood walls with paintings of historic kings and queens outlined in gold. A very long cherry wood colored table with chairs on all sides. Candle pieces are on the table about a couple feet apart with five candle sticks on each that are lit.
# Item: serving dishes
# Item_Description: ['The dish is made of a fine porcelain, patterned with roses and swords.   A gold inlay around the rim adds a touch of majesty to an otherwise commonplace item.']
# ###
#
# Category: Inside castle
# Setting: Banquet hall
# Description: Cherry wood walls with paintings of historic kings and queens outlined in gold. A very long cherry wood colored table with chairs on all sides. Candle pieces are on the table about a couple feet apart with five candle sticks on each that are lit.
# Item: rugs
# Item_Description: ['The rug is the color of blueberries and has dust rubbed into it.', 'The rug is finely woven, rich in color, and depicts geometric patterns and shapes.', 'The rug has been well maintained and has beautiful swirling patterns on it']
# ###
#
# Category: Inside castle
# Setting: Banquet hall
# Description: Cherry wood walls with paintings of historic kings and queens outlined in gold. A very long cherry wood colored table with chairs on all sides. Candle pieces are on the table about a couple feet apart with five candle sticks on each that are lit.
# Item: goblets
# Item_Description: ["Who would drink out of this golden goblet? It has a whole in it and it's so dirty"]
# ###
#
# Category: Inside castle
# Setting: Banquet hall
# Description: Cherry wood walls with paintings of historic kings and queens outlined in gold. A very long cherry wood colored table with chairs on all sides. Candle pieces are on the table about a couple feet apart with five candle sticks on each that are lit.
# Item: carpets
# Item_Description: ['A decorative tapestry placed on the floor. Stylized and decorative.']
# ###
#
# Category: Inside castle
# Setting: Banquet hall
# Description: Cherry wood walls with paintings of historic kings and queens outlined in gold. A very long cherry wood colored table with chairs on all sides. Candle pieces are on the table about a couple feet apart with five candle sticks on each that are lit.
# Item: tapestries
# Item_Description: ['The tapestry is beautiful and ornate, with threads of green and gold weaving their way across a black background.  You can pick out images of stags running through forests, fish leaping from rivers, and wolves chasing prey.', 'The tapestry is thin and made of inferior threads. The colors are dull.']
# ###
#
# Category: Inside castle
# Setting: Banquet hall
# Description: The banquet hall is like something you've never seen before.  It has gold encrusted tables and chairs, complete with embroidered tapestries and covers all over the floors.  The silverware is even made of diamonds as are all of the plates.  The ceilings are high wooden beams that glisten.
# Item: a very long table with ornately carved legs
# Item_Description: ['The long table had carved legs that were very much over decorated.']
# ###
#
# Category: Inside castle
# Setting: Banquet hall
# Description: The banquet hall is like something you've never seen before.  It has gold encrusted tables and chairs, complete with embroidered tapestries and covers all over the floors.  The silverware is even made of diamonds as are all of the plates.  The ceilings are high wooden beams that glisten.
# Item: chairs whose legs match the table legs
# Item_Description: ['The chair has intricately carved legs that look to be four ladies holding the chair up.  The wood gleams warmly as it has been carefully polished with beeswax.']
# ###
#
# Category: Inside castle
# Setting: Banquet hall
# Description: The banquet hall is like something you've never seen before.  It has gold encrusted tables and chairs, complete with embroidered tapestries and covers all over the floors.  The silverware is even made of diamonds as are all of the plates.  The ceilings are high wooden beams that glisten.
# Item: an ornate throne
# Item_Description: ['With its torn seat and dusty surface, it is clear that no body sat upon it for some time.']
# ###
#
# Category: Inside castle
# Setting: Banquet hall
# Description: The banquet hall is like something you've never seen before.  It has gold encrusted tables and chairs, complete with embroidered tapestries and covers all over the floors.  The silverware is even made of diamonds as are all of the plates.  The ceilings are high wooden beams that glisten.
# Item: flowers
# Item_Description: ['These flowers grow tall behind the castle. They are medicinal and used in teas for the Kind and Queen.', 'The flower smells like fresh lavender and has beautiful colors.', 'The flower is majestic, a royal blue with a bright green stem.', 'The flower is delicate and the petals are brightly colored.', 'the flower is dry and withered.', 'The flower is fresh and fragrant.  It has several vibrant petals.']
# ###
#
# Category: Inside castle
# Setting: Banquet hall
# Description: The banquet hall is like something you've never seen before.  It has gold encrusted tables and chairs, complete with embroidered tapestries and covers all over the floors.  The silverware is even made of diamonds as are all of the plates.  The ceilings are high wooden beams that glisten.
# Item: vases
# Item_Description: ['The vase is simple in both shape and coloring.  It appears to be clay with a simple clear glaze.', 'The vase is beautiful.  It looks like it would break easily.']
# ###
#
# Category: Inside castle
# Setting: Armory
# Description: This is a plain room with many pieces of armor and equipment lying about.  They are seen on tables or stored in heavy trunks.  There's racks of plain clothing worn before putting on armor.
# Item: polishing cloths
# Item_Description: ['The polishing cloth is covered in dark polish.  It is tattered and frayed as though it has been used for several years.']
# ###
#
# Category: Inside castle
# Setting: Armory
# Description: This is a plain room with many pieces of armor and equipment lying about.  They are seen on tables or stored in heavy trunks.  There's racks of plain clothing worn before putting on armor.
# Item: clothes brushes
# Item_Description: ['The cloth was clean and bright in all its colors, stealing it comes to mind.']
# ###
#
# Category: Inside castle
# Setting: Castle
# Description: This castle is made from red brick. The walls are all painted purple and have gold trim. There is a big chandelier that lights up the main room of the castle.
# Item: knights armor
# Item_Description: ['The armor is made of thin, lightweight metal and is covered in dents and stains from many battles.']
# ###
#
# Category: Inside castle
# Setting: Castle
# Description: This castle is made from red brick. The walls are all painted purple and have gold trim. There is a big chandelier that lights up the main room of the castle.
# Item: Kings sword
# Item_Description: ["The king's sword is magnificent and ornate, with impressive metalwork around the hilt."]
# ###
#
# Category: Inside castle
# Setting: Castle
# Description: This castle is made from red brick. The walls are all painted purple and have gold trim. There is a big chandelier that lights up the main room of the castle.
# Item: an armor set
# Item_Description: ['The armor set is heavy and made of iron.  It will protect a body from harm.']
# ###
#
# Category: Inside castle
# Setting: Privy room
# Description: It's dark and only lit by a candle stuck in a small candle holder in each wall. For what it is the room is large with plenty of room. It has a small wooden table off to the left. There's a small window behind overlooking the court yard.
# Item: parchment
# Item_Description: ['The parchment is crisp with age around the edges and covered in a thin layer of dust.']
# ###
#
# Category: Inside castle
# Setting: Privy room
# Description: It's dark and only lit by a candle stuck in a small candle holder in each wall. For what it is the room is large with plenty of room. It has a small wooden table off to the left. There's a small window behind overlooking the court yard.
# Item: ink pot
# Item_Description: ['The ink pot is small and dark.  Dark ink is seen on the outer edge of the opening.']
# ###
#
# Category: Inside castle
# Setting: Privy room
# Description: It's dark and only lit by a candle stuck in a small candle holder in each wall. For what it is the room is large with plenty of room. It has a small wooden table off to the left. There's a small window behind overlooking the court yard.
# Item: quills
# Item_Description: ['The quill is old and worn, it looks like it fell long ago and has lost its color.']
# ###
#
# Category: Inside castle
# Setting: Privy room
# Description: It's dark and only lit by a candle stuck in a small candle holder in each wall. For what it is the room is large with plenty of room. It has a small wooden table off to the left. There's a small window behind overlooking the court yard.
# Item: mirror
# Item_Description: ['The magic mirror reflects the true personality of each person who gazed into it. Its gold gilded frame is ornate and hand-carved.', 'The mirror is reflecting the entire wall']
# ###
#
# Category: Inside castle
# Setting: Privy room
# Description: It's dark and only lit by a candle stuck in a small candle holder in each wall. For what it is the room is large with plenty of room. It has a small wooden table off to the left. There's a small window behind overlooking the court yard.
# Item: pot
# Item_Description: ['The pot is old and cracked, with rust covering the outside.']
# ###
#
# Category: Inside castle
# Setting: Library
# Description: A fairly plain looking room compared to the rest of the castle.  In here are many musty shelves of books along with some scientific and writing instruments.
# Item: a table
# Item_Description: ['The table is large and made of wood.']
# ###
#
# Category: Inside castle
# Setting: Library
# Description: A fairly plain looking room compared to the rest of the castle.  In here are many musty shelves of books along with some scientific and writing instruments.
# Item: chairs
# Item_Description: ['The chair is made out of sturdy wood. It is plain but well-built.', 'The wooden chair is beginning to crack and come apart.', 'The chair is worn with age, its seat and back rounded smooth from use.  It creaks as if it carries rheumatism in its glued points of contact.', 'The castle chairs were large and ornate, perfect for a king.', 'The chair is simple, with a straight back and solid seat.']
# ###
#
# Category: Inside castle
# Setting: Library
# Description: A fairly plain looking room compared to the rest of the castle.  In here are many musty shelves of books along with some scientific and writing instruments.
# Item: Candles
# Item_Description: ['The candle is tall and made of white wax.  The wax drips down as it burns.']
# ###
#
# Category: Inside castle
# Setting: Library
# Description: A fairly plain looking room compared to the rest of the castle.  In here are many musty shelves of books along with some scientific and writing instruments.
# Item: writing paper
# Item_Description: ["The writing paper's thin parchment is showing signs of wear, turning yellow on the corners."]
# ###
#
# Category: Inside castle
# Setting: Library
# Description: A fairly plain looking room compared to the rest of the castle.  In here are many musty shelves of books along with some scientific and writing instruments.
# Item: desk
# Item_Description: ['The desk is made of sturdy oak but is very low to the floor.']
# ###
#
# Category: Inside castle
# Setting: Chapel of the eight
# Description: Made entirely out of gold and with precious jewels all around. Sculptures and many symbols with a red carpet goes from the entrance up until the end of the chapel.
# Item: tapestries
# Item_Description: ['The tapestry is beautiful and ornate, with threads of green and gold weaving their way across a black background.  You can pick out images of stags running through forests, fish leaping from rivers, and wolves chasing prey.', 'The tapestry is thin and made of inferior threads. The colors are dull.']
# ###
#
# Category: Inside castle
# Setting: Chapel of the eight
# Description: Made entirely out of gold and with precious jewels all around. Sculptures and many symbols with a red carpet goes from the entrance up until the end of the chapel.
# Item: candles
# Item_Description: ["Trails of wax running down the candle's sides seem to hint that it's used quite often.", 'The candle is burning, with its wax running down the side.', 'The candles light dwindles as the wick continues to shorten, you doubt the light from it would last much longer.', 'The candles have an overwhelming scent.', 'The beeswax candle cast a soft halo of light around the flame.', 'The candle burns brightly and gives off a sweet scent.']
# ###
#
# Category: Inside castle
# Setting: Library
# Description: The library is a humongous cavernous room full of floor to ceiling shelves. Each shelf is stocked full of every type of book imaginable, most in impeccable condition. Near all of the shelves, there are types of reading nooks with benches or chaises for people to relax and read. There are some tables and chairs for study in one half of the room. There is a large fireplace in the center and some comfortable lounge chairs arranged around it for socializing. On the sparse wall space there are tapestries. Some small end tables hold huge vases of pink flowers.
# Item: windows
# Item_Description: ['An egress to the outside of a building. Mostly used for looking through or letting fresh air in.', 'Examining the window closer, it has different shards each one of a different color and texture.', 'The window is divided into four panes with little strips of wood, and there are handprints smudged on the glass.']
# ###
#
# Category: Inside castle
# Setting: Library
# Description: The library is a humongous cavernous room full of floor to ceiling shelves. Each shelf is stocked full of every type of book imaginable, most in impeccable condition. Near all of the shelves, there are types of reading nooks with benches or chaises for people to relax and read. There are some tables and chairs for study in one half of the room. There is a large fireplace in the center and some comfortable lounge chairs arranged around it for socializing. On the sparse wall space there are tapestries. Some small end tables hold huge vases of pink flowers.
# Item: doors
# Item_Description: ['The door has a gaping hole in it where something struck it hard.', 'The door is tall and foreboding. Its large circular handles seem to have been made for giants.']
# ###
#
# Category: Inside castle
# Setting: Library
# Description: The library is a humongous cavernous room full of floor to ceiling shelves. Each shelf is stocked full of every type of book imaginable, most in impeccable condition. Near all of the shelves, there are types of reading nooks with benches or chaises for people to relax and read. There are some tables and chairs for study in one half of the room. There is a large fireplace in the center and some comfortable lounge chairs arranged around it for socializing. On the sparse wall space there are tapestries. Some small end tables hold huge vases of pink flowers.
# Item: wood floors
# Item_Description: ['A floor made from timber. Glossy and well maintained.']
# ###
#
# Category: Inside castle
# Setting: Library
# Description: The library is a humongous cavernous room full of floor to ceiling shelves. Each shelf is stocked full of every type of book imaginable, most in impeccable condition. Near all of the shelves, there are types of reading nooks with benches or chaises for people to relax and read. There are some tables and chairs for study in one half of the room. There is a large fireplace in the center and some comfortable lounge chairs arranged around it for socializing. On the sparse wall space there are tapestries. Some small end tables hold huge vases of pink flowers.
# Item: rugs
# Item_Description: ['The rug is the color of blueberries and has dust rubbed into it.', 'The rug is finely woven, rich in color, and depicts geometric patterns and shapes.', 'The rug has been well maintained and has beautiful swirling patterns on it']
# ###
#
# Category: Inside castle
# Setting: Kitchen
# Description: The medieval kitchen smells of roast and pig. The finest cuisine often includes a variety of beautiful colors and a selection of deceased animals.
# Item: wine
# Item_Description: ['A coarse, woody drink, young and unrefined.  Purple in color and cheap to buy']
# ###
#
# Category: Inside castle
# Setting: Kitchen
# Description: The medieval kitchen smells of roast and pig. The finest cuisine often includes a variety of beautiful colors and a selection of deceased animals.
# Item: grape juice
# Item_Description: ['The juice of the grape is sweet to drink.', 'The grape juice is so sweet it is hard to drink.']
# ###
#
# Category: Inside castle
# Setting: Kings bedroom
# Description: There is a large bed against the wall with wooden headboard and posts holding up a fancy roof over the bed.  There is a large tapestry  across from the bed depicting a map of the kingdom.  On the floor is a large bear rug.  The walls are decorated with gold and jewels.  There are 2 large wooden doors.  One leads to a hallway, the other leads to a bathroom.  There is a large wardrobe that is painted red and gold.
# Item: elegant paintings
# Item_Description: ['The painting appears to be of a religious leader. His features are very realistic.']
# ###
#
# Category: Inside castle
# Setting: Kings bedroom
# Description: There is a large bed against the wall with wooden headboard and posts holding up a fancy roof over the bed.  There is a large tapestry  across from the bed depicting a map of the kingdom.  On the floor is a large bear rug.  The walls are decorated with gold and jewels.  There are 2 large wooden doors.  One leads to a hallway, the other leads to a bathroom.  There is a large wardrobe that is painted red and gold.
# Item: decorative swords
# Item_Description: ["The decorative sword has gemstones in the handle and isn't particularly sharp."]
# ###
#
# Category: Inside castle
# Setting: Kings bedroom
# Description: There is a large bed against the wall with wooden headboard and posts holding up a fancy roof over the bed.  There is a large tapestry  across from the bed depicting a map of the kingdom.  On the floor is a large bear rug.  The walls are decorated with gold and jewels.  There are 2 large wooden doors.  One leads to a hallway, the other leads to a bathroom.  There is a large wardrobe that is painted red and gold.
# Item: decorative shields
# Item_Description: ['The shield had many dents and scratches, the sides were lined with blood.', "This elaborately decorative shield symbolizes the Kingdom's morals."]
# ###
#
# Category: Inside castle
# Setting: Kings bedroom
# Description: There is a large bed against the wall with wooden headboard and posts holding up a fancy roof over the bed.  There is a large tapestry  across from the bed depicting a map of the kingdom.  On the floor is a large bear rug.  The walls are decorated with gold and jewels.  There are 2 large wooden doors.  One leads to a hallway, the other leads to a bathroom.  There is a large wardrobe that is painted red and gold.
# Item: a large table with an ordinate cushion for the king's crown
# Item_Description: ['The crown is made of solid gold, adorned with the finest gems you have ever laid your eyes on.']
# ###
#
# Category: Inside castle
# Setting: Castle maids' room
# Description: Inside the maids room is dark and grey.  It is much different from the rest of the Castle which has grand walls and floors and paintings from famous painters around the wall.  The maid holds many secrets in this room.  One which is a secret door that holds paintings she should not have.
# Item: brushes
# Item_Description: ['Upon close inspection, the brush is dainty and carved with roses.']
# ###
#
# Category: Inside castle
# Setting: Castle maids' room
# Description: Inside the maids room is dark and grey.  It is much different from the rest of the Castle which has grand walls and floors and paintings from famous painters around the wall.  The maid holds many secrets in this room.  One which is a secret door that holds paintings she should not have.
# Item: tape
# Item_Description: ['The tape is rudimentary but does the job well of holding the bandage in place. You can see a sticky resin on one side of the material.']
# ###
#
# Category: Inside castle
# Setting: Grand ballroom
# Description: There is a large marbled floor with ornate inlay-ed floor decorations.  The ceiling is tall and also ornately decorated with beautiful plaster decorations that touches by gold lining.  The space is high and well lit with many windows but has a dark musky smell.
# Item: Flags
# Item_Description: ['The flag flaps in the wind. The streaming ends a tattered reminder.']
# ###
#
# Category: Inside castle
# Setting: Kings bed room
# Description: The walls are tall and stone. They are coated with colorful tapestries showing the kings of years past. A large stone fireplace across from the bed that is large enough to keep the king warm even on the coldest nights. A double thick wooden door with a large lock on each side of the room.
# Item: floor to ceiling mirror
# Item_Description: ['The tall mirror stretches from the floor to the ceiling, clearly displaying your reflection.']
# ###
#
# Category: Inside castle
# Setting: Kings bed room
# Description: The walls are tall and stone. They are coated with colorful tapestries showing the kings of years past. A large stone fireplace across from the bed that is large enough to keep the king warm even on the coldest nights. A double thick wooden door with a large lock on each side of the room.
# Item: heavy blanket
# Item_Description: ['The heavy blanket is incredibly comfortable.']
# ###
#
# Category: Inside castle
# Setting: Great armory
# Description: The Great Armory is a long room filled too to bottom with shelves and racks of weapons of every sort. Swords of every length, weight and style, likes longer than a man is tall, Morning Star maces, longbows, horse bows, crossbows, axes...they're all there.
# Item: shields
# Item_Description: ['The shield is heavy and large.  It has the crest of the king on it.']
# ###
#
# Category: Inside castle
# Setting: Great armory
# Description: The Great Armory is a long room filled too to bottom with shelves and racks of weapons of every sort. Swords of every length, weight and style, likes longer than a man is tall, Morning Star maces, longbows, horse bows, crossbows, axes...they're all there.
# Item: keys
# Item_Description: ['The key is old and tarnished. It is very small in size.']
# ###
#
# Category: Inside castle
# Setting: Great armory
# Description: The Great Armory is a long room filled too to bottom with shelves and racks of weapons of every sort. Swords of every length, weight and style, likes longer than a man is tall, Morning Star maces, longbows, horse bows, crossbows, axes...they're all there.
# Item: chains
# Item_Description: ['You see the chain is cut in half, one link broken down the middle with complete precision.', 'The chains placed on the prisoners are necassary.', "The chain is coiled on itself and caked with rust.  You're not sure it could actually be used - it might break if you even pick it up."]
# ###
#
# Category: Inside castle
# Setting: The show room inside the castle
# Description: The Show Room Inside the Castle is meant to impress as well as cause fear to whomever enters the room.  The Duke who lives here is a hunter and keeps his captures here.  Some of the thinks preserved and shown on his wall are shocking.  The preserved eyes stare back and let you know the Duke knows no mercy, be careful what you say in this room.  The floor is white like ivory and the walls are also white, but the ceiling is painted and tells a story of the Duke's conquest.
# Item: animal heads
# Item_Description: ['This animal head looks back at you with mournful eyes.']
# ###
#
# Category: Inside castle
# Setting: The show room inside the castle
# Description: The Show Room Inside the Castle is meant to impress as well as cause fear to whomever enters the room.  The Duke who lives here is a hunter and keeps his captures here.  Some of the thinks preserved and shown on his wall are shocking.  The preserved eyes stare back and let you know the Duke knows no mercy, be careful what you say in this room.  The floor is white like ivory and the walls are also white, but the ceiling is painted and tells a story of the Duke's conquest.
# Item: bear rug
# Item_Description: ['The bear rug lies in the weapon room, with sharp teeth and giant paws.']
# ###
#
# Category: Inside castle
# Setting: The show room inside the castle
# Description: The Show Room Inside the Castle is meant to impress as well as cause fear to whomever enters the room.  The Duke who lives here is a hunter and keeps his captures here.  Some of the thinks preserved and shown on his wall are shocking.  The preserved eyes stare back and let you know the Duke knows no mercy, be careful what you say in this room.  The floor is white like ivory and the walls are also white, but the ceiling is painted and tells a story of the Duke's conquest.
# Item: hunting rifles
# Item_Description: ['The rifle is long, its stock barrel and grip has nicks on it from use.']
# ###
#
# Category: Inside castle
# Setting: The show room inside the castle
# Description: The Show Room Inside the Castle is meant to impress as well as cause fear to whomever enters the room.  The Duke who lives here is a hunter and keeps his captures here.  Some of the thinks preserved and shown on his wall are shocking.  The preserved eyes stare back and let you know the Duke knows no mercy, be careful what you say in this room.  The floor is white like ivory and the walls are also white, but the ceiling is painted and tells a story of the Duke's conquest.
# Item: bow and arrows
# Item_Description: ['A bow an arrow. Made from fine materials. Mostly used for hunting and protection.']
# ###
#
# Category: Inside castle
# Setting: The show room inside the castle
# Description: The Show Room Inside the Castle is meant to impress as well as cause fear to whomever enters the room.  The Duke who lives here is a hunter and keeps his captures here.  Some of the thinks preserved and shown on his wall are shocking.  The preserved eyes stare back and let you know the Duke knows no mercy, be careful what you say in this room.  The floor is white like ivory and the walls are also white, but the ceiling is painted and tells a story of the Duke's conquest.
# Item: traps
# Item_Description: ['the trap has several strings.']
# ###
#
# Category: Inside castle
# Setting: The show room inside the castle
# Description: The Show Room Inside the Castle is meant to impress as well as cause fear to whomever enters the room.  The Duke who lives here is a hunter and keeps his captures here.  Some of the thinks preserved and shown on his wall are shocking.  The preserved eyes stare back and let you know the Duke knows no mercy, be careful what you say in this room.  The floor is white like ivory and the walls are also white, but the ceiling is painted and tells a story of the Duke's conquest.
# Item: skinning knives
# Item_Description: ['The skinning knife has a thick dark brown coat of blood on it, and the handle is made of fine black leather.']
# ###
#
# Category: Outside castle
# Setting: Archery zone
# Description: The archery zone is spacious and always bright with light. The field is green and the targets are bright red.
# Item: A quiver
# Item_Description: ['The quiver contains a mess of arrows, its leather frame stretched from years of use.']
# ###
#
# Category: Outside castle
# Setting: Archery zone
# Description: The archery zone is spacious and always bright with light. The field is green and the targets are bright red.
# Item: A bow
# Item_Description: ['The bow appears to be made of a dark brown wood, its string is taught and straight, and it is about as long as your arm.']
# ###
#
# Category: Outside castle
# Setting: Horse stables
# Description: It is dull to look at. The stable has hay laying everywhere, grey stones making the walls, and large heavy wooden beams hold up the ceiling. So, everything is brown or grey or other shades that bore. There are sections for horses made of wood but looks rickety.
# Item: tools
# Item_Description: ['The tool had been used to cause much harm', 'The tool is rusted with dull edges.']
# ###
#
# Category: Outside castle
# Setting: Horse stables
# Description: It is dull to look at. The stable has hay laying everywhere, grey stones making the walls, and large heavy wooden beams hold up the ceiling. So, everything is brown or grey or other shades that bore. There are sections for horses made of wood but looks rickety.
# Item: hay
# Item_Description: ['the hay is dry and nutritious for the animals.', 'Forking hay is a hard task that requires much stamina.']
# ###
#
# Category: Outside castle
# Setting: Horse stables
# Description: It is dull to look at. The stable has hay laying everywhere, grey stones making the walls, and large heavy wooden beams hold up the ceiling. So, everything is brown or grey or other shades that bore. There are sections for horses made of wood but looks rickety.
# Item: horse tack
# Item_Description: ['The horse tack is made of hardened leather and molded iron. It is designed perfectly to fit a horse.']
# ###
#
# Category: Outside castle
# Setting: Horse stables
# Description: It is dull to look at. The stable has hay laying everywhere, grey stones making the walls, and large heavy wooden beams hold up the ceiling. So, everything is brown or grey or other shades that bore. There are sections for horses made of wood but looks rickety.
# Item: hay shovels
# Item_Description: ["the hay shovel is new but heavily used. there are remnants of matter other than hay, indicaitng the owner's have gottent their money's worth", 'The shovel was rusty with bits of hay lingering on it.']
# ###
#
# Category: Outside castle
# Setting: Horse stables
# Description: It is dull to look at. The stable has hay laying everywhere, grey stones making the walls, and large heavy wooden beams hold up the ceiling. So, everything is brown or grey or other shades that bore. There are sections for horses made of wood but looks rickety.
# Item: water troughs
# Item_Description: ['The wooden trough is broken from holding the heavy water and grass']
# ###
#
# Category: Outside castle
# Setting: Entrance to castle
# Description: This entrance has seen better days.  The stones are a bit askew, and have lots of mosses growing on them.  But there is also a magical quality about this entrance.  It is not something you see, but rather feel.  And every now and then you can catch a shimmer out of the corner of your eye.
# Item: flowers
# Item_Description: ['These flowers grow tall behind the castle. They are medicinal and used in teas for the Kind and Queen.', 'The flower smells like fresh lavender and has beautiful colors.', 'The flower is majestic, a royal blue with a bright green stem.', 'The flower is delicate and the petals are brightly colored.', 'the flower is dry and withered.', 'The flower is fresh and fragrant.  It has several vibrant petals.']
# ###
#
# Category: Outside castle
# Setting: Entrance to castle
# Description: This entrance has seen better days.  The stones are a bit askew, and have lots of mosses growing on them.  But there is also a magical quality about this entrance.  It is not something you see, but rather feel.  And every now and then you can catch a shimmer out of the corner of your eye.
# Item: trees
# Item_Description: ['The trees are monsterously large.', "The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it.", 'The tree is split at the base and appears to be ready to fall.', 'The tree is small and twisted.  It looks like it has been pummeled by the wind for decades.', 'The tree is bare and very tall. It has many branches and a brown trunk.', 'The tree has a large hole in one side, and a few branches have been cut off.', 'The tree may have only just planted its roots, but it is already towering above everything else.', 'This tree stands tall, proudly displaying its green foliage.', 'The tree appears ancient. Its gnarled branches reach out into the sky in all directions.']
# ###
#
# Category: Outside castle
# Setting: Entrance to castle
# Description: This entrance has seen better days.  The stones are a bit askew, and have lots of mosses growing on them.  But there is also a magical quality about this entrance.  It is not something you see, but rather feel.  And every now and then you can catch a shimmer out of the corner of your eye.
# Item: plants
# Item_Description: ['The plant is wilted, trampled by marching soldiers.', 'The plant is small and very green. It has tiny holes in the leaves.', 'The plant has a green stalk , large yellow petals with a white center, and droops over under the flowers weight.']
# ###
#
# Category: Outside castle
# Setting: Entrance to castle
# Description: This entrance has seen better days.  The stones are a bit askew, and have lots of mosses growing on them.  But there is also a magical quality about this entrance.  It is not something you see, but rather feel.  And every now and then you can catch a shimmer out of the corner of your eye.
# Item: tapestries
# Item_Description: ['The tapestry is beautiful and ornate, with threads of green and gold weaving their way across a black background.  You can pick out images of stags running through forests, fish leaping from rivers, and wolves chasing prey.', 'The tapestry is thin and made of inferior threads. The colors are dull.']
# ###
#
# Category: Outside castle
# Setting: Stable
# Description: It's constructed from old mossy stone from the nearby river. The horse's stalls inside are wooden. There is hay scattered across a dirt floor. Along the walls there are rustic tools, such as rakes, pitch forks and tools created by the blacksmith. The grain for the horses is stored in clay pottery. Regal and majestic Thoroughbred horses occupy the stables.
# Item: Bits for the horses
# Item_Description: ['The horse bit is old and worn.']
# ###
#
# Category: Outside castle
# Setting: Stable
# Description: It's constructed from old mossy stone from the nearby river. The horse's stalls inside are wooden. There is hay scattered across a dirt floor. Along the walls there are rustic tools, such as rakes, pitch forks and tools created by the blacksmith. The grain for the horses is stored in clay pottery. Regal and majestic Thoroughbred horses occupy the stables.
# Item: Blankets for the stable workers who sleep there
# Item_Description: ['The blanket is dirty and stained, and has a musty smell to it.']
# ###
#
# Category: Outside castle
# Setting: Outside castle
# Description: The outside castle is beautifully decorated with priceless gems and artifacts. The stone used is ancient and antique with a shiny gloss of silver. The gardens outside the castle are a beautiful green and have the most delightful flowers.
# Item: The drawbridge to the castle.
# Item_Description: ['The drawbridge is made of wood and metal.  It is large and wide.']
# ###
#
# Category: Outside castle
# Setting: The barracks
# Description: Run down and smelly, the barracks houses a dozen of the king's guardsmen.  It's made of wooden slats nailed together somewhat hastily, and the brisk air from the outside whistles through some small cracks between the panels.  There are six beds in an open sleeping quarter, with a wooden chest at the end of the bed where the guardsmen store their personal belongings.
# Item: guards armor
# Item_Description: ['The palace guards wear heavy metal guards armor to protect them from outside attacks.']
# ###
#
# Category: Outside castle
# Setting: The barracks
# Description: Run down and smelly, the barracks houses a dozen of the king's guardsmen.  It's made of wooden slats nailed together somewhat hastily, and the brisk air from the outside whistles through some small cracks between the panels.  There are six beds in an open sleeping quarter, with a wooden chest at the end of the bed where the guardsmen store their personal belongings.
# Item: guards weapons
# Item_Description: ['The weapon looks menacing and sharp.']
# ###
#
# Category: Outside castle
# Setting: The barracks
# Description: Run down and smelly, the barracks houses a dozen of the king's guardsmen.  It's made of wooden slats nailed together somewhat hastily, and the brisk air from the outside whistles through some small cracks between the panels.  There are six beds in an open sleeping quarter, with a wooden chest at the end of the bed where the guardsmen store their personal belongings.
# Item: guards toilet basin
# Item_Description: ['You see a rancid toilet basin. Its stench fills the air.']
# ###
#
# Category: Outside castle
# Setting: The barracks
# Description: Run down and smelly, the barracks houses a dozen of the king's guardsmen.  It's made of wooden slats nailed together somewhat hastily, and the brisk air from the outside whistles through some small cracks between the panels.  There are six beds in an open sleeping quarter, with a wooden chest at the end of the bed where the guardsmen store their personal belongings.
# Item: a jug of water
# Item_Description: ['The water is clear and cool to the taste.']
# ###
#
# Category: Outside castle
# Setting: Royal stables
# Description: The royal stables hold all of the horses of the noble people living in the castle. They are very well constructed, consisting of expert mason work and fixtures of some sort of heavy, forest-scented wood. Each horse has a large stall, lined with fresh hay replenished by stable hands daily. On the walls of stable, there are tools used to care for and groom the horses, hung on hooks. The stables are lit by lanterns hung throughout the stables.
# Item: pail
# Item_Description: ['The pail is old and beginning to rust in places.']
# ###
#
# Category: Outside castle
# Setting: Royal stables
# Description: The royal stables hold all of the horses of the noble people living in the castle. They are very well constructed, consisting of expert mason work and fixtures of some sort of heavy, forest-scented wood. Each horse has a large stall, lined with fresh hay replenished by stable hands daily. On the walls of stable, there are tools used to care for and groom the horses, hung on hooks. The stables are lit by lanterns hung throughout the stables.
# Item: wheat
# Item_Description: ['A grain used for various baking needs and can be used to make beverages.']
# ###
#
# Category: Outside castle
# Setting: Royal stables
# Description: The royal stables hold all of the horses of the noble people living in the castle. They are very well constructed, consisting of expert mason work and fixtures of some sort of heavy, forest-scented wood. Each horse has a large stall, lined with fresh hay replenished by stable hands daily. On the walls of stable, there are tools used to care for and groom the horses, hung on hooks. The stables are lit by lanterns hung throughout the stables.
# Item: water buckets
# Item_Description: ['The water bucket is made of wood and sealed with metal.']
# ###
#
# Category: Outside castle
# Setting: Beyond the wall
# Description: This is the area beyond the Inner Castle. It consist of large green land, that sprawl all the way to the horizon, with a line of six luxury houses in the middle. It is home to some of the Kings immediate aides, such as War Officer, Military Commander, and Agricultural Advisor.
# Item: horses
# Item_Description: ['Spending its time galloping around, the horse looks majestic.']
# ###
#
# Category: Outside castle
# Setting: Beyond the wall
# Description: This is the area beyond the Inner Castle. It consist of large green land, that sprawl all the way to the horizon, with a line of six luxury houses in the middle. It is home to some of the Kings immediate aides, such as War Officer, Military Commander, and Agricultural Advisor.
# Item: gates
# Item_Description: ['for many the gates of Hades look like the gates to a garden in which to forget all of their troubles.']
# ###
#
# Category: Outside castle
# Setting: Beyond the wall
# Description: This is the area beyond the Inner Castle. It consist of large green land, that sprawl all the way to the horizon, with a line of six luxury houses in the middle. It is home to some of the Kings immediate aides, such as War Officer, Military Commander, and Agricultural Advisor.
# Item: trees
# Item_Description: ['The trees are monsterously large.', "The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it.", 'The tree is split at the base and appears to be ready to fall.', 'The tree is small and twisted.  It looks like it has been pummeled by the wind for decades.', 'The tree is bare and very tall. It has many branches and a brown trunk.', 'The tree has a large hole in one side, and a few branches have been cut off.', 'The tree may have only just planted its roots, but it is already towering above everything else.', 'This tree stands tall, proudly displaying its green foliage.', 'The tree appears ancient. Its gnarled branches reach out into the sky in all directions.']
# ###
#
# Category: Outside castle
# Setting: Beyond the wall
# Description: This is the area beyond the Inner Castle. It consist of large green land, that sprawl all the way to the horizon, with a line of six luxury houses in the middle. It is home to some of the Kings immediate aides, such as War Officer, Military Commander, and Agricultural Advisor.
# Item: a well
# Item_Description: ["the wishing well is dry, which doesn't give one the best sense of having their wishes granted."]
# ###
#
# Category: Inside church
# Setting: Inside church
# Description: Small wooden crucifix decorations, wooden benches, small and dim windows, wooden walls, vases on small pillars, plants near church entrance
# Item: empty coin bag
# Item_Description: ['The coin bag is devoid of anything of value. You knew this before even looking, but still held a small amount of hope that your fortunes has changed.']
# ###
#
# Category: Inside church
# Setting: Inside church
# Description: Small wooden crucifix decorations, wooden benches, small and dim windows, wooden walls, vases on small pillars, plants near church entrance
# Item: old bible
# Item_Description: ["The Old Bible's page corners are tattered and folded from years of bookmarking by a pious devout, and the cover's gold letters have begun to fade."]
# ###
#
# Category: Inside church
# Setting: Inside church
# Description: Small wooden crucifix decorations, wooden benches, small and dim windows, wooden walls, vases on small pillars, plants near church entrance
# Item: candles
# Item_Description: ["Trails of wax running down the candle's sides seem to hint that it's used quite often.", 'The candle is burning, with its wax running down the side.', 'The candles light dwindles as the wick continues to shorten, you doubt the light from it would last much longer.', 'The candles have an overwhelming scent.', 'The beeswax candle cast a soft halo of light around the flame.', 'The candle burns brightly and gives off a sweet scent.']
# ###
#
# Category: Inside church
# Setting: Inside church
# Description: Small wooden crucifix decorations, wooden benches, small and dim windows, wooden walls, vases on small pillars, plants near church entrance
# Item: stained glass
# Item_Description: ['The stained glass towers above, and it presents vibrant colors of biblical stories when the sunlight shows through it.']
# ###
#
# Category: Inside church
# Setting: Inside church
# Description: Small wooden crucifix decorations, wooden benches, small and dim windows, wooden walls, vases on small pillars, plants near church entrance
# Item: pews
# Item_Description: ['The pew is made of wood and is very long.']
# ###
#
# Category: Inside church
# Setting: Church altar
# Description: An ornate altar studded with many jewels. A chalice and a golden plate rest upon a white cloth. It is 5 feet high and 20 feet wide. The high priest stands before it while giving a sermon to his followers.
# Item: wooden bench
# Item_Description: ['Looking at the bench, it looks newly built, and it seems like getting made from Redwood tree, which makes it durable.']
# ###
#
# Category: Inside church
# Setting: Church altar
# Description: An ornate altar studded with many jewels. A chalice and a golden plate rest upon a white cloth. It is 5 feet high and 20 feet wide. The high priest stands before it while giving a sermon to his followers.
# Item: hymnal
# Item_Description: ['The hymnal is a heavy, leather-bound volume. Its pages are filled with stoic songs.']
# ###
#
# Category: Inside church
# Setting: Study room
# Description: A plain room with shelves of religious text are stored.  There are tables and chairs situated around the room available for use.  There are some trunks with books stored.
# Item: feather fountain pen
# Item_Description: ['The feather fountain pen appears to  have never been used before as it is so clean and shiny.']
# ###
#
# Category: Inside church
# Setting: Study room
# Description: A plain room with shelves of religious text are stored.  There are tables and chairs situated around the room available for use.  There are some trunks with books stored.
# Item: ink jar
# Item_Description: ['The ink in the jar swirls darkly, the glass glimmering in the light.']
# ###
#
# Category: Inside church
# Setting: Study room
# Description: A plain room with shelves of religious text are stored.  There are tables and chairs situated around the room available for use.  There are some trunks with books stored.
# Item: quill
# Item_Description: ['The quill looks to be made of a goose feather, and sharped to create the finest of flourishes.  There still looks to be some ink staining the tip of it.']
# ###
#
# Category: Inside church
# Setting: Study room
# Description: A plain room with shelves of religious text are stored.  There are tables and chairs situated around the room available for use.  There are some trunks with books stored.
# Item: ink pot
# Item_Description: ['The ink pot is small and dark.  Dark ink is seen on the outer edge of the opening.']
# ###
#
# Category: Inside church
# Setting: A small church
# Description: It's a very humble abode - any smaller and you could mistake it for someone's home.  In the front room is a small altar for prayer and offerings.  The two rooms to the sides are places where the priest and a traveler can rest.
# Item: bed
# Item_Description: ['The bed looks very comfortable, if only you rest in it.', 'The bed looks comfortable and big, it is tall.', 'The bed is unkempt, with the sheets falling off of it on either side.']
# ###
#
# Category: Inside church
# Setting: A small church
# Description: It's a very humble abode - any smaller and you could mistake it for someone's home.  In the front room is a small altar for prayer and offerings.  The two rooms to the sides are places where the priest and a traveler can rest.
# Item: signs
# Item_Description: ['The old wooden sign, tattered and tilted to one side, presents a stark warning to travelers -- "Beware."']
# ###
#
# Category: Inside church
# Setting: A small church
# Description: It's a very humble abode - any smaller and you could mistake it for someone's home.  In the front room is a small altar for prayer and offerings.  The two rooms to the sides are places where the priest and a traveler can rest.
# Item: blankets
# Item_Description: ['The blankets that are given to the soldiers to camp on the battlefields have been made by a group of very capable craftsmen.']
# ###
#
# Category: Inside church
# Setting: A small church
# ...
# Item: drinks
# Item_Description: ['The drink fizzes and seems discolored. It does, however, smell delightful.']
# ###
#
# Category: Supernatural
# Setting: Astral plane
# Description: An area between worlds where the physics known to man become irrelevant. It is a space beyond time that is home to being spectral and inconceivable to those without the eyes to see them.
# Item: stars
# Item_Description: ['These hand-crafted throwing stars are sharp enough to cut with.']
# ###
#
# Category: Supernatural
# Setting: Astral plane
# Description: An area between worlds where the physics known to man become irrelevant. It is a space beyond time that is home to being spectral and inconceivable to those without the eyes to see them.
# Item: glitter
# Item_Description: ['This was very fine looking glitter, almost like powder but it was more sparkly than anything I have ever seen, it seemed to have a magical aura about it.']
# ###
#
# Category: Supernatural
# Setting: Magic room
# Description: A room that once entered, cannot be escaped. The walls are all mirrors, and you can never again find the door.
# Item: picture
# Item_Description: ['The ornate picture hung on a wall, dusty with cobwebs,']
# ###
#
# Category: Supernatural
# Setting: Magic room
# Description: A room that once entered, cannot be escaped. The walls are all mirrors, and you can never again find the door.
# Item: wedding ring
# Item_Description: ['The ring is quite curiously crafted, probably as a unique item for a bride or groom.']
# ###
#
# Category: Supernatural
# Setting: Goddess hollow
# Description: The Goddess Hollow is a place created to worship woodland spirits. It is a small, closet-like room in a hollowed out tree that has existed for hundreds of years. Within the hollow there are piles of sticks, flowers, and home-made items presented to the woodland spirits.
# Item: lantern
# Item_Description: ['The old lantern featured twisted black iron and broken glass panes.']
# ###
#
# Category: Supernatural
# Setting: Goddess hollow
# Description: The Goddess Hollow is a place created to worship woodland spirits. It is a small, closet-like room in a hollowed out tree that has existed for hundreds of years. Within the hollow there are piles of sticks, flowers, and home-made items presented to the woodland spirits.
# Item: pine cones
# Item_Description: ['The pine cone is covered in grass and smells of the outdoors']
# ###
#
# Category: Supernatural
# Setting: Haunted basement
# Description: The basement is cold, damp, and dark. What little light coming in from the window is blotted out and dimmed by the spider webs sprawled across its surface. The shadows in the corners of the room appear nearly pitch black, and it almost feels as if something is looking back at you from within them.
# Item: bed
# Item_Description: ['The bed is made of crudely hewn oak logs with bits of bark still attached here and there.']
# ###
#
# Category: Supernatural
# Setting: Haunted basement
# Description: The basement is cold, damp, and dark. What little light coming in from the window is blotted out and dimmed by the spider webs sprawled across its surface. The shadows in the corners of the room appear nearly pitch black, and it almost feels as if something is looking back at you from within them.
# Item: blood stains
# Item_Description: ['The blood stain looks substantially large and fresh.']
# ###
#
# Category: Supernatural
# Setting: Ghost monk quarters
# Description: a simple room for an undead monk. There is an uncomfortable bed, no windows, a small table with a candle, some illustrations in a book, and not much else. There is a stool
# Item: spider
# Item_Description: ['The tiny spider flaunts bright, iridescent colors notably blue, green and purple.']
# ###
#
# Category: Supernatural
# Setting: Ghost monk quarters
# Description: a simple room for an undead monk. There is an uncomfortable bed, no windows, a small table with a candle, some illustrations in a book, and not much else. There is a stool
# Item: cob webs
# Item_Description: ['Only a spider of enormous proportion could have made a web this big. Best not to linger.']
# ###
#
# Category: Underwater aquapolis
# Setting: Research lab
# Description: The research lab is the main science hub of the aquapolis. Dozens of scientists are working on a myriad of different projects.
# Item: book
# Item_Description: ['And chosen people is the tittle of the book within the book']
# ###
#
# Category: Underwater aquapolis
# Setting: Research lab
# Description: The research lab is the main science hub of the aquapolis. Dozens of scientists are working on a myriad of different projects.
# Item: pick
# Item_Description: ['A thin, metal tool for picking locks. Not the wisest thing to be carrying around, but it sure can be one of the handiest!']
# ###
#
# Category: Underwater aquapolis
# Setting: The dungeon
# Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Item: chain
# Item_Description: ['The chain is old and has rust covering it']
# ###
#
# Category: Underwater aquapolis
# Setting: The dungeon
# Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Item: whip
# Item_Description: ['The whip is long and braided with shards of glass, and chunks of wood woven into it.  What a cruel punishment awaits the receiver of these lashes.']
# ###
#
# Category: Underwater aquapolis
# Setting: Toad hollow
# Description: Toad Hollow is a filthy room within the Underwater Aquapolis. When you enter, you are greeted by the reek of scummy pond water. You enter Toad Hollow through a drainage pipe that you have to crawl through. Once inside Toad Hollow, you can stand up, but you still don't feel comfortable with your surroundings. As far as the eye can see there is muddy water in a circular basin with lily pads floating in it. On the pads, giant toads jump back and forth making gurgling, croaking sounds. As you wade deeper into Toad Hollow, the water comes up to your waist and you see the flash of a fin. There is legend that a creature lives in the center of Toad Hollow that is half human, half monster. Not even the strongest knight has been brave enough to examine it. The fin disappears back underwater but there is a red glint suggesting eyes are watching you. When you reach the other side of the basin, you crawl into another drainage pipe and feel relieved that you're out of this place.
# Item: relic armor
# Item_Description: ['The armor is covered in blood and pierced through the middle']
# ###
#
# Category: Underwater aquapolis
# Setting: Toad hollow
# Description: Toad Hollow is a filthy room within the Underwater Aquapolis. When you enter, you are greeted by the reek of scummy pond water. You enter Toad Hollow through a drainage pipe that you have to crawl through. Once inside Toad Hollow, you can stand up, but you still don't feel comfortable with your surroundings. As far as the eye can see there is muddy water in a circular basin with lily pads floating in it. On the pads, giant toads jump back and forth making gurgling, croaking sounds. As you wade deeper into Toad Hollow, the water comes up to your waist and you see the flash of a fin. There is legend that a creature lives in the center of Toad Hollow that is half human, half monster. Not even the strongest knight has been brave enough to examine it. The fin disappears back underwater but there is a red glint suggesting eyes are watching you. When you reach the other side of the basin, you crawl into another drainage pipe and feel relieved that you're out of this place.
# Item: old sword
# Item_Description: ['The sword was old and worn, it had chips on the tip, rust was starting to form where the handle meets the blade but it could still be wielded without problem.']
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater marketplace
# Description: The marketplace is the main hub for the residents of the aquapolis. With high ceilings and bright, colorful flags at each market stand, the place seems to stretch on forever. Near the entrance, there is a young boy attempting to sell the latest news of the kingdom.
# Item: fish
# Item_Description: ['The market cart contained wet, shimmering fish, available for sale.']
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater marketplace
# Description: The marketplace is the main hub for the residents of the aquapolis. With high ceilings and bright, colorful flags at each market stand, the place seems to stretch on forever. Near the entrance, there is a young boy attempting to sell the latest news of the kingdom.
# Item: advertisements
# Item_Description: ['The advertisement is tearing apart and raggedy by the woods.']
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater aquapolis
# Description: The underwater aquapolis is a massive and ornate city at the bottom of the ocean. The walls of the buildings are made or coral, pearl, and seashells. Schools of fish swim in and out of the circular holes in the walls that act as windows. The aquapolis is illuminated by florescent rocks and shells that line every building.
# Item: trident
# Item_Description: ['This trident is very beautiful but deadly']
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater aquapolis
# Description: The underwater aquapolis is a massive and ornate city at the bottom of the ocean. The walls of the buildings are made or coral, pearl, and seashells. Schools of fish swim in and out of the circular holes in the walls that act as windows. The aquapolis is illuminated by florescent rocks and shells that line every building.
# Item: sand
# Item_Description: ['The sand is scratchy, and piled in heaps.']
# ###
#
# Category: Underwater aquapolis
# Setting: Dry dock room
# Description: The room is located on the border wall of the aquapolis. There is one on the far north and far south side.
# Item: rock
# Item_Description: ['The rock is large, dull, and ovular.']
# ###
#
# Category: Underwater aquapolis
# Setting: Dry dock room
# Description: The room is located on the border wall of the aquapolis. There is one on the far north and far south side.
# Item: scuba gear
# Item_Description: ['The scuba gear is covered in moss and appears to have been left behind by an explorer']
# ###
#
# Category: Underwater aquapolis
# Setting: Neptune's throne room
# Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# Item: trident
# Item_Description: ['This trident is very beautiful but deadly']
# ###
#
# Category: Underwater aquapolis
# Setting: Neptune's throne room
# Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# Item: king's crown
# Item_Description: ['The glittering crown has impossibly many precious jewels befit for only a king.']
# ###
#
# Category: Underwater aquapolis
# Setting: The lords treasury
# Description: Deep inside the volcanic cave that is the foundation of the aquapolis lies the treasury.  Some believe its existence is a myth, but others claim they have been there.  Those that claim they have seen it say you must dive out of the aquapolis' basement while holding your breath, through the cold deep water that is filled with deadly volcanic gas.  The treasury room itself is a dry cave filled with riches from the very infancy of the empire
# Item: golden crown
# Item_Description: ['The crown is gold and smaller than you would expect for a king.']
# ###
#
# Category: Underwater aquapolis
# Setting: The lords treasury
# Description: Deep inside the volcanic cave that is the foundation of the aquapolis lies the treasury.  Some believe its existence is a myth, but others claim they have been there.  Those that claim they have seen it say you must dive out of the aquapolis' basement while holding your breath, through the cold deep water that is filled with deadly volcanic gas.  The treasury room itself is a dry cave filled with riches from the very infancy of the empire
# Item: ash
# Item_Description: ['The ash is darkly and fine, spread across the lands.']
# ###
#
# Category: Underwater aquapolis
# Setting: Geothermal valley
# Description: Deep and warm the geothermal valley boasts a reviving epicenter for all to migrate to. The warm bursts of heat send bubble around the perimeter of the valley reflecting colors of green and blue.
# Item: precious stones
# Item_Description: ['The stone is cut into a diamond shape and shines a bright blue color.']
# ###
#
# Category: Underwater aquapolis
# Setting: Geothermal valley
# Description: Deep and warm the geothermal valley boasts a reviving epicenter for all to migrate to. The warm bursts of heat send bubble around the perimeter of the valley reflecting colors of green and blue.
# Item: body of water
# Item_Description: ['The body of water must be maintained in high level during summer']
# ###
#
# Category: Underwater aquapolis
# Setting: The marketplace
# Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# Item: mysterious tent
# Item_Description: ['This mysterious tent has a peculiarly soft glow surrounding it.']
# ###
#
# Category: Underwater aquapolis
# Setting: The marketplace
# Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# Item: mystical booth
# Item_Description: ['They were forbidden from entering the mystical booth in the demolished church.']
# ###
#
# Category: Underwater aquapolis
# Setting: Farmhouse
# Description: a small house on a seaweed plantation, small and rustic, really only the single room with a closet, maybe, a table and some chairs
# Item: pitchfork
# Item_Description: ['The pitchfork made for a great tool of defense.']
# ###
#
# Category: Underwater aquapolis
# Setting: Farmhouse
# Description: a small house on a seaweed plantation, small and rustic, really only the single room with a closet, maybe, a table and some chairs
# Item: shovel
# Item_Description: ['The shovel is dirt-encrusted and grimy.']
# ###
#
# Category: Underwater aquapolis
# Setting: Tool shed
# Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Item: seeds
# Item_Description: ['The tiny seed is almost a reddish brown and perfectly round in shape, almost as if man made.']
# ###
#
# Category: Underwater aquapolis
# Setting: Tool shed
# Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Item: barrels
# Item_Description: ['The barrel fills to the top and sparkles with clear liquid.']
# ###

# %%
# !head fine_tuning_single_item_description.jsonl
# Out:
# {"prompt": "Category: Forest\nSetting: Mysterious forest outskirts\nDescription: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.\nItem: rope bridge\n", "completion": "Item_Description: ['The ancient rope bridge appears fragile and rickety, swaying to and fro in the wind.  The bridge floor is made of planks of rotting wood which, if stepped through, would abruptly pull the victim down to an unsuspecting death.']\n###\n"}
# {"prompt": "Category: Forest\nSetting: Mysterious forest outskirts\nDescription: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.\nItem: babbling brook\n", "completion": "Item_Description: ['The babbling brook flows gently over rocks. This brook supplies my horses and crops with water.']\n###\n"}
# {"prompt": "Category: Forest\nSetting: Fairy forest\nDescription: The fairy forest is full of brightly colored flowers that grow up to 30 feet tall.  There are also ornate birds that live here.  When you whistle, a fairy will come to you and tweak your nose.  They don't like a lot of nose so it irritates them enough for them to come out of their homes made from watermelon skins.\nItem: trees\n", "completion": "Item_Description: ['The trees are monsterously large.', \"The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it.\", 'The tree is split at the base and appears to be ready to fall.', 'The tree is small and twisted.  It looks like it has been pummeled by the wind for decades.', 'The tree is bare and very tall. It has many branches and a brown trunk.', 'The tree has a large hole in one side, and a few branches have been cut off.', 'The tree may have only just planted its roots, but it is already towering above everything else.', 'This tree stands tall, proudly displaying its green foliage.', 'The tree appears ancient. Its gnarled branches reach out into the sky in all directions.']\n###\n"}
# {"prompt": "Category: Forest\nSetting: Fairy forest\nDescription: The fairy forest is full of brightly colored flowers that grow up to 30 feet tall.  There are also ornate birds that live here.  When you whistle, a fairy will come to you and tweak your nose.  They don't like a lot of nose so it irritates them enough for them to come out of their homes made from watermelon skins.\nItem: mushrooms\n", "completion": "Item_Description: ['the mushroom is sweet and eaten by many']\n###\n"}
# {"prompt": "Category: Forest\nSetting: Pond\nDescription: A small area with a body of water in the center along with turtles, frogs, and other wildlife that live here.  Surrounding this pone are a dense set of trees along with some rocks here and there.\nItem: dog\n", "completion": "Item_Description: [\"The dog is long and slender, its legs about the length of its body. It's chest is broad and its brown coat is shiny and smooth.\"]\n###\n"}
# {"prompt": "Category: Forest\nSetting: Pond\nDescription: A small area with a body of water in the center along with turtles, frogs, and other wildlife that live here.  Surrounding this pone are a dense set of trees along with some rocks here and there.\nItem: cougar\n", "completion": "Item_Description: ['Pick a fight with a lion before you pick a fight with a cougar, it is much more dangerous.']\n###\n"}
# {"prompt": "Category: Forest\nSetting: Pond\nDescription: A small area with a body of water in the center along with turtles, frogs, and other wildlife that live here.  Surrounding this pone are a dense set of trees along with some rocks here and there.\nItem: flowers\n", "completion": "Item_Description: ['These flowers grow tall behind the castle. They are medicinal and used in teas for the Kind and Queen.', 'The flower smells like fresh lavender and has beautiful colors.', 'The flower is majestic, a royal blue with a bright green stem.', 'The flower is delicate and the petals are brightly colored.', 'the flower is dry and withered.', 'The flower is fresh and fragrant.  It has several vibrant petals.']\n###\n"}
# {"prompt": "Category: Forest\nSetting: Pond\nDescription: A small area with a body of water in the center along with turtles, frogs, and other wildlife that live here.  Surrounding this pone are a dense set of trees along with some rocks here and there.\nItem: bushes\n", "completion": "Item_Description: ['This lush bush has an assortment of birds, nesting in it.']\n###\n"}
# {"prompt": "Category: Forest\nSetting: Pond\nDescription: A small area with a body of water in the center along with turtles, frogs, and other wildlife that live here.  Surrounding this pone are a dense set of trees along with some rocks here and there.\nItem: reeds\n", "completion": "Item_Description: ['the reed swayed in the wind']\n###\n"}
# {"prompt": "Category: Forest\nSetting: Pond\nDescription: A small area with a body of water in the center along with turtles, frogs, and other wildlife that live here.  Surrounding this pone are a dense set of trees along with some rocks here and there.\nItem: lilypad\n", "completion": "Item_Description: [\"Right now, this lily pad is only the size of a child's fist. Soon, however, it will grow to be several feet wide.\"]\n###\n"}

# %%
# !openai api fine_tunes.create -t fine_tuning_single_item_description.jsonl -m curie
# Out:
# Upload progress: 100% 579k/579k [00:00<00:00, 1.02Git/s]
# Uploaded file from fine_tuning_single_item_description.jsonl: file-KSNKlhvImmU2LwypaxiSO9mp
# Created fine-tune: ft-ETW5qUKhlW3c2xltWH8DQJPZ
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2022-01-29 01:46:52] Created fine-tune: ft-ETW5qUKhlW3c2xltWH8DQJPZ
# [2022-01-29 01:47:03] Fine-tune costs $1.49
# [2022-01-29 01:47:03] Fine-tune enqueued. Queue number: 0
# [2022-01-29 01:47:06] Fine-tune started
#
# Stream interrupted (client disconnected).
# To resume the stream, run:
#
#   openai api fine_tunes.follow -i ft-ETW5qUKhlW3c2xltWH8DQJPZ

# %%
# !openai api fine_tunes.follow -i ft-ETW5qUKhlW3c2xltWH8DQJPZ
# Out:
# [2022-01-29 01:46:52] Created fine-tune: ft-ETW5qUKhlW3c2xltWH8DQJPZ
# [2022-01-29 01:47:03] Fine-tune costs $1.49
# [2022-01-29 01:47:03] Fine-tune enqueued. Queue number: 0
# [2022-01-29 01:47:06] Fine-tune started
# [2022-01-29 01:53:58] Completed epoch 1/4
# [2022-01-29 02:00:06] Completed epoch 2/4
# [2022-01-29 02:06:16] Completed epoch 3/4
# [2022-01-29 02:12:24] Completed epoch 4/4
# [2022-01-29 02:12:55] Uploaded model: curie:ft-cis-700-31-2022-01-29-02-12-53
# [2022-01-29 02:12:58] Uploaded result file: file-6bFHX4MjCbZfgI9MkIvegkNM
# [2022-01-29 02:12:59] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m curie:ft-cis-700-31-2022-01-29-02-12-53 -p <YOUR_PROMPT>

# %%
def get_item_description(category, item_name, finetuned_model, location_name="", location_description=""):
  response = openai.Completion.create(
      model=finetuned_model,
      prompt="Category: {category}\nSetting: {location}\nDescription: {description}\nItem: {item_name}\nItem_Description:".format(
          category=category.capitalize(),
          location=location_name.capitalize(),
          description=location_description.capitalize(),
          item_name=item_name.capitalize()
      ),
      temperature=0.7,
      max_tokens=64,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0,
      stop=["###"]
      )
  return response['choices'][0]['text']

# Replace with your model's name
finetuned_model = "curie:ft-cis-700-31-2022-01-29-02-12-53"
category = "Underwater aquapolis"
location_name = "Neptune's throne room"
location_description = "A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves."
item_name = "king's crown"


item_description = get_item_description(category, item_name, finetuned_model, location_name="", location_description="")
print(item_description)
# Out:
#  ['The crown is magnificent, made of solid gold and diamond encrusted.']

# %%
light_environment['neighbors']
# room_names_to_id
# Out:
# {'1': {'connection': 'down the hill',
#   'destination': 'creek',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 1},
#  '10': {'connection': 'other docks',
#   'destination': 'Boats',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 9},
#  '1005': {'connection': 'walking',
#   'destination': 'Weapon Closet',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 596},
#  '1007': {'connection': 'Atlantic Ocean.',
#   'destination': 'An abandoned castle on an ocean cliff side',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 634},
#  '1011': {'connection': '{}',
#   'destination': 'Church Entryway',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 662},
#  '1015': {'connection': 'taking a rocky path',
#   'destination': 'the bone pit',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 567},
#  '1016': {'connection': 'following the horse trail',
#   'destination': "the horse's stables",
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 568},
#  '1017': {'connection': 'taking a short walk south',
#   'destination': "King's chambers",
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 569},
#  '1018': {'connection': 'opening the stone door',
#   'destination': 'Adjacent to the Guest Castle',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 570},
#  '102': {'connection': 'Going through the wooden doorway',
#   'destination': 'Dining Hall',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 59},
#  '1020': {'connection': 'taking the stairs',
#   'destination': 'Tower',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 572},
#  '1023': {'connection': 'following the long stone wall by the grassy path',
#   'destination': 'Moat',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 575},
#  '1024': {'connection': 'exiting the tower and crossing the bridge',
#   'destination': 'Town',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 576},
#  '1026': {'connection': 'going through the doors to the palace',
#   'destination': 'Dining Hall',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 578},
#  '1027': {'connection': 'walking through the storm cellar',
#   'destination': 'Dining Hall',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 691},
#  '1028': {'connection': 'entering the great door',
#   'destination': 'The Hall of the Goddess',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 580},
#  '1029': {'connection': 'going up the staircase',
#   'destination': "The King's Quarters",
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 581},
#  '103': {'connection': 'Passing through the short hall',
#   'destination': 'Castle Exit',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 59},
#  '1030': {'connection': 'walking through the tower gates',
#   'destination': 'Southernmost Tower Entryway',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 582},
#  '1031': {'connection': 'Walking up the path to the north is the boathouse',
#   'destination': 'Boat House',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 583},
#  '1034': {'connection': 'going through the front door of the office',
#   'destination': "Clergyman's office",
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 586},
#  '1035': {'connection': 'exiting the hidden door',
#   'destination': 'Beside temple entrance',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 587},
#  '1037': {'connection': 'descending the staircase',
#   'destination': 'castle kitchen',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 589},
#  '1038': {'connection': 'walking up the wet stone stairs and through the gate',
#   'destination': 'Torture room',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 590},
#  '1039': {'connection': 'exiting from the north and following Driftwood Trail',
#   'destination': 'Tombstones of the Kings',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 591},
#  '104': {'connection': 'opening and going through the stone door',
#   'destination': 'chamber entrance',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 60},
#  '1040': {'connection': 'fighting the urges to remain here forever',
#   'destination': 'Entrance to the Pine trees',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 666},
#  '1042': {'connection': 'walking down the stairs on the east side of the personal room',
#   'destination': 'Main hallway',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 594},
#  '1044': {'connection': 'slipping through the old, wooden door',
#   'destination': 'Weapon Closet',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 596},
#  '1047': {'connection': 'Following her gaze east and passing through the archway',
#   'destination': 'The Ball Room',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 599},
#  '1048': {'connection': 'heading east to the closest building',
#   'destination': 'Tavern of Browntavia',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 600},
#  '1049': {'connection': 'taking the stone pathway.',
#   'destination': 'Temple gardens',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 601},
#  '105': {'connection': 'opening stone door',
#   'destination': 'chamber exit',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 60},
#  '1050': {'connection': 'traveling the road south',
#   'destination': 'Cemetery',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 702},
#  '1051': {'connection': 'taking the stairs.',
#   'destination': 'Bell Tower',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 603},
#  '1052': {'connection': 'passing through the moon carved door',
#   'destination': 'Knights Quarters',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 604},
#  '1053': {'connection': 'hopping over the fence',
#   'destination': 'Meadow',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 605},
#  '1054': {'connection': 'descending the spiral staircase',
#   'destination': 'The Inside Temple',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 665},
#  '1055': {'connection': 'climbing out of the tub',
#   'destination': 'Bathroom',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 607},
#  '1056': {'connection': 'following the footpath',
#   'destination': 'Outside tower',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 608},
#  '1057': {'connection': 'following the corridor',
#   'destination': 'Torture Room',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 672},
#  '1058': {'connection': 'following dirt path',
#   'destination': 'Barn',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 610},
#  '106': {'connection': 'the draw bridge',
#   'destination': 'Castle entrance',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 61},
#  '1060': {'connection': 'following the footpath',
#   'destination': 'Top side tower overlooking view',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 612},
#  '1061': {'connection': 'descending the ladder',
#   'destination': 'beside tower entrance',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 613},
#  '1063': {'connection': 'taking the stairs out of the basement',
#   'destination': "Castle Maids' Room",
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 682},
#  '1064': {'connection': 'entering the dirt path in between two gnarled oak trees.',
#   'destination': 'path in forest',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 616},
#  '1065': {'connection': 'walking up the aisle to the altar',
#   'destination': 'Next to an altar',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 685},
#  '1066': {'connection': 'passing through the rusty gate',
#   'destination': 'outside of the church',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 660},
#  '1067': {'connection': 'Walking through the large, double door.',
#   'destination': 'Barn',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 620},
#  '1068': {'connection': 'walking up the steps to the pier',
#   'destination': 'Fishing Pier',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 621},
#  '1069': {'connection': 'descending down the spiral staircase',
#   'destination': 'Nave',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 622},
#  '107': {'connection': 'walking alongside the fortress walls',
#   'destination': 'Tower 2',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 61},
#  '1070': {'connection': 'stepping through the wardrobe at one end of the tunnel',
#   'destination': 'Popes dormitory',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 623},
#  '1072': {'connection': 'going west through the foyer.',
#   'destination': 'Temple foyer',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 625},
#  '1073': {'connection': 'Walking the path and entering the door',
#   'destination': 'Enchanted light house',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 626},
#  '1074': {'connection': 'Taking the path east',
#   'destination': 'Courtyard',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 627},
#  '1075': {'connection': 'returning down the path',
#   'destination': 'firewood forest',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 628},
#  '1077': {'connection': 'a walkway',
#   'destination': 'Training Fields',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 630},
#  '1078': {'connection': 'a small doorway in the corner',
#   'destination': 'Dining Hall',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 631},
#  '1079': {'connection': 'a metal door leading to a short set of stairs',
#   'destination': 'The armory',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 632},
#  '108': {'connection': 'walking carefully between fallen headstones',
#   'destination': 'Fresh Grave',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 62},
#  '1081': {'connection': 'walking through the stone corridors',
#   'destination': 'An abandoned castle on an ocean cliff side',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 634},
#  '1082': {'connection': 'opening the gate',
#   'destination': 'Tower Sewers',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 654},
#  '1083': {'connection': 'opening the side entrance',
#   'destination': 'Sanctuary',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 636},
#  '1084': {'connection': 'following the line of giant ants to the riverbed',
#   'destination': 'Riverbed',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 637},
#  '1085': {'connection': 'walking up the stairs',
#   'destination': 'Outside Temple',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 639},
#  '1086': {'connection': 'taking the grand staircase',
#   'destination': 'Master Bedroom',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 640},
#  '1087': {'connection': 'Sliding the wooden panel down.',
#   'destination': 'Storage room',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 641},
#  '109': {'connection': 'following a dirt trail behind the mausoleum',
#   'destination': 'Dead Tree',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 62},
#  '1090': {'connection': 'taking any of the stairways upwards',
#   'destination': 'Alchemists Lab',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 648},
#  '1091': {'connection': 'taking the pathway',
#   'destination': 'Boathouse',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 645},
#  '1092': {'connection': 'passing through the obscured brick opening',
#   'destination': 'Dungeon',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 646},
#  '1093': {'connection': 'Ducking through the underground tunnel North of the flower garden.',
#   'destination': 'The Brush Den',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 647},
#  '1094': {'connection': 'taking the stairway up',
#   'destination': 'Alchemists Lab',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 648},
#  '1095': {'connection': 'Opening the heavy double doors at the south end.',
#   'destination': 'Great Armory',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 649},
#  '1096': {'connection': 'By passing the fence',
#   'destination': 'the farmer hill',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 650},
#  '1097': {'connection': 'going down the stairs',
#   'destination': 'Kings bedroom',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 696},
#  '1098': {'connection': 'walking through the door in the hallway',
#   'destination': 'The grand dining room',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 684},
#  '1099': {'connection': 'passing through the arch on the west end',
#   'destination': 'Tower Sewers',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 654},
#  '11': {'connection': 'walk down the stream',
#   'destination': 'The swimming hole',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 11},
#  '110': {'connection': 'riding the horse trail',
#   'destination': 'hay field',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 63},
#  '1101': {'connection': 'moving around rocks and mud',
#   'destination': 'Bog',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 656},
#  '1102': {'connection': 'taking the stairs',
#   'destination': 'Kings bedroom',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 657},
#  '1103': {'connection': 'walking into the door from the keep',
#   'destination': 'A spiral staircase',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 658},
#  '1105': {'connection': 'Walking through the broken door',
#   'destination': 'Outside Church',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 660},
#  '1106': {'connection': 'taking the western path',
#   'destination': 'graveyard reception area',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 661},
#  '1107': {'connection': 'walking up the stairs',
#   'destination': 'Church Entryway',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 662},
#  '1108': {'connection': 'Walking through the gates and going inside',
#   'destination': 'Cottage safe-room',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 663},
#  '1109': {'connection': 'walking the side path',
#   'destination': 'Stable',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 664},
#  '111': {'connection': 'following the edge of the trees',
#   'destination': 'edge of the forest',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 63},
#  '1110': {'connection': 'following the statues on the north road',
#   'destination': 'The Inside Temple',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 665},
#  '1111': {'connection': 'Southern trail',
#   'destination': 'Entrance to the Pine trees',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 666},
#  '1112': {'connection': 'wading through water',
#   'destination': "Troll's bridge",
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 667},
#  '1113': {'connection': 'Climbing down',
#   'destination': 'Rectory',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 669},
#  '1114': {'connection': 'walking straight down the Main Hallway and exiting at the end of the hall.',
#   'destination': 'The garden courtyard',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 670},
#  '1115': {'connection': 'entering the abandoned mine',
#   'destination': 'Abandoned Mine',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 671},
#  '1116': {'connection': 'Crouching down and crawling along a tiny passageway.',
#   'destination': 'Torture Room',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 672},
#  '1117': {'connection': 'using the wooden stairs',
#   'destination': 'the jail room',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 674},
#  '1118': {'connection': 'opening the door',
#   'destination': 'the throne',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 675},
#  '112': {'connection': 'going through the doorway',
#   'destination': 'Dining room',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 64},
#  '1120': {'connection': 'narrow doorway',
#   'destination': 'stained glass room',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 677},
#  '1121': {'connection': 'going through the golden door',
#   'destination': 'The confession Box',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 678},
#  '1122': {'connection': 'following the stream',
#   'destination': 'weathered shack',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 679},
#  '1124': {'connection': 'taking the pathway back up',
#   'destination': 'Courtyard',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 681},
#  '1125': {'connection': 'Going up the stairs at the front of the basement',
#   'destination': "Castle Maids' Room",
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 682},
#  '1127': {'connection': 'going inside the main entrance',
#   'destination': 'Confessional',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 686},
#  '1129': {'connection': 'walking up the nearby path',
#   'destination': 'In Front of a Stone Tower',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 689},
#  '113': {'connection': 'ascending the staircase',
#   'destination': 'Sleeping quarters',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 64},
#  '1131': {'connection': 'descending the staircase',
#   'destination': 'Dining Hall',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 691},
#  '1132': {'connection': 'Walking the sidewalk and following it behind the church until you get to the wooden gate.',
#   'destination': 'Graveyard',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 692},
#  '1133': {'connection': 'descending the ladder',
#   'destination': 'Underground Cavern',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 693},
#  '1134': {'connection': 'following the exterior castle wall',
#   'destination': 'The Barracks',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 694},
#  '1135': {'connection': 'approaching the drawbridge',
#   'destination': 'The opening to the drawbridge of the castle',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 695},
#  '1136': {'connection': 'walking through the nearby hallway',
#   'destination': 'Nursery',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 696},
#  '1137': {'connection': 'going through a tunnel',
#   'destination': 'The Sacred Temple',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 697},
#  '1142': {'connection': 'following the cobblestone path',
#   'destination': 'Cemetery',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 702},
#  '1143': {'connection': 'going next door',
#   'destination': 'cloud city music shop',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 703},
#  '1144': {'connection': 'going inside a few yards to the back',
#   'destination': 'bathroom',
#   'direction': 'inside',
#   'inverse_id': None,
#   'room_id': 703},
#  '1145': {'connection': 'leaving the music store',
#   'destination': 'cloud tavern',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 704},
#  '1146': {'connection': 'traveling to the room in the back',
#   'destination': 'storage room',
#   'direction': 'inside',
#   'inverse_id': None,
#   'room_id': 704},
#  '1157': {'connection': 'Walking around the swamp to the other side to go to the forest',
#   'destination': 'Forest',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 710},
#  '1158': {'connection': 'Behind you there is a town not far down the path',
#   'destination': 'Path',
#   'direction': 'south',
#   'inverse_id': None,
#   'room_id': 710},
#  '1159': {'connection': 'going out the golden door, and heading to your right.',
#   'destination': 'Unicorn Fields',
#   'direction': 'south',
#   'inverse_id': None,
#   'room_id': 711},
#  '116': {'connection': 'Using the drawbridge',
#   'destination': 'Castle entrance',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 66},
#  '1160': {'connection': 'flying through the door in the ceiling.',
#   'destination': 'Faery Bath',
#   'direction': 'inside',
#   'inverse_id': None,
#   'room_id': 711},
#  '1161': {'connection': 'Following the light',
#   'destination': 'Cave Entrance',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 712},
#  '1162': {'connection': 'Climbing down farther into the cave.',
#   'destination': 'Small pond inside the cave',
#   'direction': 'down',
#   'inverse_id': None,
#   'room_id': 712},
#  '1163': {'connection': 'climbing down a ladder',
#   'destination': 'tunnels',
#   'direction': 'down',
#   'inverse_id': None,
#   'room_id': 713},
#  '1164': {'connection': 'walking out of the tunnel',
#   'destination': 'the planes of the underworld',
#   'direction': 'west',
#   'inverse_id': None,
#   'room_id': 713},
#  '1165': {'connection': 'Opening the front door and walking aoutside',
#   'destination': 'Graveyard',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 714},
#  '1166': {'connection': 'Walking to the south side fo the room',
#   'destination': 'Closet',
#   'direction': 'south',
#   'inverse_id': None,
#   'room_id': 714},
#  '1167': {'connection': 'Following the river of fire',
#   'destination': 'Fountain of Youth',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 715},
#  '1168': {'connection': 'opening a door that goes under the castle.',
#   'destination': 'Graveyard',
#   'direction': 'down',
#   'inverse_id': None,
#   'room_id': 715},
#  '1169': {'connection': 'going a few steps inside',
#   'destination': 'whip room',
#   'direction': 'inside',
#   'inverse_id': None,
#   'room_id': 716},
#  '117': {'connection': 'following the grassy path',
#   'destination': 'Town Church',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 66},
#  '1170': {'connection': 'leaving the whip room',
#   'destination': 'hallway',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 716},
#  '1171': {'connection': 'Climbing its slope at the edge of the lake.',
#   'destination': 'Netherworld Volcano',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 717},
#  '1172': {'connection': 'Wandering from the eastern shore of the lake.',
#   'destination': 'Infernal Valley',
#   'direction': 'east',
#   'inverse_id': None,
#   'room_id': 717},
#  '1173': {'connection': 'walking west outside',
#   'destination': 'ghost monastery',
#   'direction': 'west',
#   'inverse_id': None,
#   'room_id': 718},
#  '1174': {'connection': 'walking outside along a footpath',
#   'destination': 'rectory',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 718},
#  '1175': {'connection': 'Calling the Astral Beast',
#   'destination': 'Lair of the Astral Beast',
#   'direction': 'inside',
#   'inverse_id': None,
#   'room_id': 719},
#  '1176': {'connection': 'Being cast from the astral plane by ones own volition or by another entity.',
#   'destination': 'Reality',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 719},
#  '1177': {'connection': 'Following the stream East',
#   'destination': 'Cave',
#   'direction': 'east',
#   'inverse_id': None,
#   'room_id': 720},
#  '1178': {'connection': 'Walk North 100 yards into the forest',
#   'destination': 'Large Oak tree',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 720},
#  '1179': {'connection': 'Walk past the tourney gates with an over arching top',
#   'destination': 'Stables',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 721},
#  '118': {'connection': 'following the stream',
#   'destination': 'clean water lake',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 67},
#  '1180': {'connection': 'walking pased the green and white arrow signs that point the way.',
#   'destination': 'Jousting Arena',
#   'direction': 'east',
#   'inverse_id': None,
#   'room_id': 721},
#  '1181': {'connection': 'walking east along the path',
#   'destination': 'farmhouse',
#   'direction': 'east',
#   'inverse_id': None,
#   'room_id': 722},
#  '1182': {'connection': 'going south along the path',
#   'destination': 'sea barn',
#   'direction': 'south',
#   'inverse_id': None,
#   'room_id': 722},
#  '1183': {'connection': 'stepping through the house, you find a small closet',
#   'destination': 'closet',
#   'direction': 'inside',
#   'inverse_id': None,
#   'room_id': 723},
#  '1184': {'connection': 'going outside, you see a barn for storing seaweed',
#   'destination': 'storage barn',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 723},
#  '1185': {'connection': 'Stepping onto the cloud elevator',
#   'destination': 'Jousting Knight Bar',
#   'direction': 'south',
#   'inverse_id': None,
#   'room_id': 724},
#  '1186': {'connection': 'Stepping onto the Cloud Elevator and get off in two stops',
#   'destination': "The Jester's Pride Bar",
#   'direction': 'south',
#   'inverse_id': None,
#   'room_id': 724},
#  '1187': {'connection': 'Climbing up the service ladder to the tier four',
#   'destination': 'Service ladder',
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 725},
#  '1188': {'connection': 'Going in the service door to enter the back of the bar.',
#   'destination': 'door',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 725},
#  '1189': {'connection': 'walking down a very narrow hall about ten feet long',
#   'destination': 'female dragons lair',
#   'direction': 'east',
#   'inverse_id': None,
#   'room_id': 726},
#  '119': {'connection': 'climbing the hill',
#   'destination': 'mountain top',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 67},
#  '1190': {'connection': 'travelling under a human sized stone arch.',
#   'destination': 'wizards work room',
#   'direction': 'west',
#   'inverse_id': None,
#   'room_id': 726},
#  '1191': {'connection': 'Going out the entrance door and using the staircase',
#   'destination': 'The security room',
#   'direction': 'down',
#   'inverse_id': None,
#   'room_id': 727},
#  '1192': {'connection': 'Going out the deck door',
#   'destination': 'The deck',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 727},
#  '1193': {'connection': 'going through the ornate door',
#   'destination': 'Rose garden',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 728},
#  '1194': {'connection': 'going through the iron door',
#   'destination': 'Cliffside',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 728},
#  '1195': {'connection': 'Walking down the dirt path to the chapel.',
#   'destination': 'The church',
#   'direction': 'south',
#   'inverse_id': None,
#   'room_id': 729},
#  '1196': {'connection': 'walking across the footbridge',
#   'destination': 'castle',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 729},
#  '12': {'connection': 'walk up the stream',
#   'destination': 'The waterfall',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 11},
#  '120': {'connection': 'Crossing the bridge onto the docks',
#   'destination': 'Port Skyline',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 68},
#  '1209': {'connection': 'passing the door',
#   'destination': 'Kitchen',
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 736},
#  '121': {'connection': 'Crossing ships thresehold',
#   'destination': 'Turk',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 68},
#  '1210': {'connection': 'operating the touchpad',
#   'destination': 'Storage room',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 736},
#  '1211': {'connection': 'opening the wooden door and walking out of the lair',
#   'destination': "The wizard's garden",
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 737},
#  '1212': {'connection': 'walking through a small hallway behind a grapevine in the corner.',
#   'destination': 'kitchen',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 737},
#  '1213': {'connection': 'Walking through the soft folds of the tent door',
#   'destination': 'The center of the encampment',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 738},
#  '1214': {'connection': 'Stepping onto the magical pearl flagstone',
#   'destination': 'The Contemplation Room',
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 738},
#  '1215': {'connection': 'Teleport from the top of the Echo Hall',
#   'destination': 'wizard tower',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 739},
#  '1216': {'connection': 'Provide a pure crystal to the magic door to open it',
#   'destination': 'bunker hall',
#   'direction': 'south',
#   'inverse_id': None,
#   'room_id': 739},
#  '1217': {'connection': 'Walking outside',
#   'destination': 'Troll cave enterance',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 740},
#  '1218': {'connection': 'Pullling a lever hidden by rocks in the wall.',
#   'destination': 'Secret passage way to the lost Tomb',
#   'direction': 'inside',
#   'inverse_id': None,
#   'room_id': 740},
#  '1219': {'connection': 'exiting through the door made of bone and turning right down the long hall.',
#   'destination': 'Holding Cell',
#   'direction': 'inside',
#   'inverse_id': None,
#   'room_id': 741},
#  '122': {'connection': 'Opening the wooden double door',
#   'destination': 'Fountain',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 69},
#  '1220': {'connection': 'walking out the bone gate and heading straight.',
#   'destination': 'Fiery Pit',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 741},
#  '1221': {'connection': 'walking along the dusty path through the trees',
#   'destination': 'The Dark Woods',
#   'direction': 'west',
#   'inverse_id': None,
#   'room_id': 742},
#  '1222': {'connection': 'walking upon the flagstone pathway',
#   'destination': 'The Garden Pavilion',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 742},
#  '1223': {'connection': 'Walk through a field of bodies and bone',
#   'destination': "Lucifer's Throne",
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 743},
#  '1224': {'connection': 'Drown from within the Pit of Despair, being dragged down by the limbs',
#   'destination': 'Lava Pits',
#   'direction': 'down',
#   'inverse_id': None,
#   'room_id': 743},
#  '1225': {'connection': 'descending the steps beneath the large wooden trapdoor',
#   'destination': "Lord's Dungeon",
#   'direction': 'down',
#   'inverse_id': None,
#   'room_id': 744},
#  '1226': {'connection': 'climbing a staircase',
#   'destination': 'Sentry Tower',
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 744},
#  '1227': {'connection': 'sneaking up the spiral staircase.',
#   'destination': 'courtyard of castle',
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 745},
#  '1228': {'connection': 'walking inside of the main castle entrance',
#   'destination': 'Throne Room',
#   'direction': 'inside',
#   'inverse_id': None,
#   'room_id': 745},
#  '1229': {'connection': 'travelling through the fog covered door',
#   'destination': 'The wastelands',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 746},
#  '123': {'connection': 'Opening the small wooden door',
#   'destination': 'Mess Hall',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 69},
#  '1230': {'connection': 'ascending a spiral staircase',
#   'destination': 'The upper chamber',
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 746},
#  '1231': {'connection': 'Going behind the tree',
#   'destination': 'The forest path',
#   'direction': 'east',
#   'inverse_id': None,
#   'room_id': 747},
#  '1232': {'connection': 'Climbing a ladder inside the room',
#   'destination': 'The hammock',
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 747},
#  '1233': {'connection': 'Crawling out the basement window',
#   'destination': 'Outdoors',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 748},
#  '1234': {'connection': 'Going up the stairs',
#   'destination': 'Kitchen',
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 748},
#  '1235': {'connection': 'Walking into the distance',
#   'destination': 'Throne room',
#   'direction': 'down',
#   'inverse_id': None,
#   'room_id': 749},
#  '1236': {'connection': 'Climbing down the stairs',
#   'destination': 'Bathroom',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 749},
#  '1237': {'connection': 'Walking along the stony path',
#   'destination': 'The Forest of Solitude',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 750},
#  '1238': {'connection': "Pushing one's way through the forest",
#   'destination': 'The River of Memories',
#   'direction': 'east',
#   'inverse_id': None,
#   'room_id': 750},
#  '1239': {'connection': 'strolling through the vibrant market and through the large glass doors.',
#   'destination': 'The front entrance room',
#   'direction': 'east',
#   'inverse_id': None,
#   'room_id': 751},
#  '1240': {'connection': 'weaving through the fresh produce stands and passing the large mermaid display',
#   'destination': "The fisherman's stand",
#   'direction': 'west',
#   'inverse_id': None,
#   'room_id': 751},
#  '1241': {'connection': 'Opening research lab door',
#   'destination': 'Front door of the research lab',
#   'direction': 'inside',
#   'inverse_id': None,
#   'room_id': 752},
#  '1242': {'connection': 'walking outside of the lab and open the across the hall door',
#   'destination': 'storage closet',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 752},
#  '1243': {'connection': 'Walk down maintence hall.',
#   'destination': 'Walk down the maintence hall and it is the last door on the right.',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 753},
#  '1244': {'connection': 'open the storage closet door',
#   'destination': 'Storage closet',
#   'direction': 'east',
#   'inverse_id': None,
#   'room_id': 753},
#  '1245': {'connection': 'Swimming up towards the island',
#   'destination': 'Above water basking caves',
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 754},
#  '1246': {'connection': 'Following the illuminated path of coral',
#   'destination': 'Underwater park',
#   'direction': 'east',
#   'inverse_id': None,
#   'room_id': 754},
#  '1247': {'connection': 'swimming through the pillars',
#   'destination': 'Deep Crevasse',
#   'direction': 'east',
#   'inverse_id': None,
#   'room_id': 755},
#  '1248': {'connection': 'Swimming through the broken rooftops',
#   'destination': 'The Ministry of Surface Affairs',
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 755},
#  '1249': {'connection': 'Taking a short walk through an underground hallway',
#   'destination': 'Courtyard',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 756},
#  '125': {'connection': 'taking the dirt trail',
#   'destination': "peasant's cottage",
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 71},
#  '1250': {'connection': 'Going up the staircase next to a seashell table in the corner.',
#   'destination': "King's throne room",
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 756},
#  '1251': {'connection': 'Taking a deep breath and dive down through the small opening swim north until you reach the subbasement',
#   'destination': 'The aquapolis subbasement',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 757},
#  '1252': {'connection': 'Diving down from the treasury',
#   'destination': 'The lords private chambers',
#   'direction': 'west',
#   'inverse_id': None,
#   'room_id': 757},
#  '1253': {'connection': 'You need to go to the end of the main hallway and take the elevator down to the Thrones of Death.  Then go down the lcng dark corridor.',
#   'destination': 'The Snakes of Death Pit.',
#   'direction': 'down',
#   'inverse_id': None,
#   'room_id': 758},
#  '1254': {'connection': 'Open the Darkly decorated  Steel door.',
#   'destination': 'The room with Pet Lions',
#   'direction': 'west',
#   'inverse_id': None,
#   'room_id': 758},
#  '1255': {'connection': 'walking out a usually open square wooden door.',
#   'destination': 'workers courtyard',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 759},
#  '1256': {'connection': 'walking through a stone opening at the far end.',
#   'destination': 'scullery',
#   'direction': 'north',
#   'inverse_id': None,
#   'room_id': 759},
#  '1257': {'connection': 'Opening the furthest door in the back.',
#   'destination': 'Storage Room of the Grand Hall',
#   'direction': 'inside',
#   'inverse_id': None,
#   'room_id': 760},
#  '1258': {'connection': 'Go through the opened massive door.',
#   'destination': 'The Grand Plaza',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 760},
#  '126': {'connection': 'following the hay trail',
#   'destination': 'hay field',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 71},
#  '1269': {'connection': 'walking along the golden pathway',
#   'destination': 'The Garden of Wisdom',
#   'direction': 'west',
#   'inverse_id': None,
#   'room_id': 766},
#  '127': {'connection': 'Stairs in the tunnels',
#   'destination': 'Treasure room',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 72},
#  '1270': {'connection': 'pushing through the twisted vines and branches',
#   'destination': 'The Enchanted Forest',
#   'direction': 'south',
#   'inverse_id': None,
#   'room_id': 766},
#  '1271': {'connection': 'walking out of the wooden door into an open field',
#   'destination': 'center of the forest',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 767},
#  '1272': {'connection': 'walking through the short hallway',
#   'destination': 'kitchen',
#   'direction': 'west',
#   'inverse_id': None,
#   'room_id': 767},
#  '1273': {'connection': 'walk out of the oak door into the forest',
#   'destination': 'Garden',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 768},
#  '1274': {'connection': 'using the open hallway on the other side of the room',
#   'destination': 'feasting room',
#   'direction': 'west',
#   'inverse_id': None,
#   'room_id': 768},
#  '1275': {'connection': 'Moving down the dark corridor and up the steep staircase to the main hall',
#   'destination': 'Main hall',
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 769},
#  '1276': {'connection': 'Climbing down a ladder into a dark pit in the corner of the room',
#   'destination': 'Pit',
#   'direction': 'down',
#   'inverse_id': None,
#   'room_id': 769},
#  '1277': {'connection': 'Entering the guarded portal in the back of the chamber',
#   'destination': 'The Heavens',
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 770},
#  '1278': {'connection': 'Falling into the endless crater',
#   'destination': 'The Abyss',
#   'direction': 'down',
#   'inverse_id': None,
#   'room_id': 770},
#  '1279': {'connection': 'Using the entrance of the lair',
#   'destination': 'The town square',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 771},
#  '128': {'connection': 'Through the main corridor',
#   'destination': 'Temple door',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 72},
#  '1280': {'connection': 'using the wooden staircase',
#   'destination': 'Chamber room',
#   'direction': 'down',
#   'inverse_id': None,
#   'room_id': 771},
#  '1281': {'connection': 'walking through the grassy trail',
#   'destination': 'Cliff',
#   'direction': 'east',
#   'inverse_id': None,
#   'room_id': 772},
#  '1282': {'connection': 'hiking through the brush',
#   'destination': 'pasture',
#   'direction': 'west',
#   'inverse_id': None,
#   'room_id': 772},
#  '1283': {'connection': 'Crawling straight through the tunnel',
#   'destination': 'If you take the right combination of tunnels, you can reach The Humble Knight Inn at street level',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 773},
#  '1284': {'connection': 'Crawling through another tunnel',
#   'destination': "Helma's Bakery",
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 773},
#  '1285': {'connection': 'moving up the winding staircase',
#   'destination': 'the high courtroom',
#   'direction': 'up',
#   'inverse_id': None,
#   'room_id': 774},
#  '1286': {'connection': 'opening the outer door',
#   'destination': 'the courtyard',
#   'direction': 'outside',
#   'inverse_id': None,
#   'room_id': 774},
#  '1287': {'connection': 'Swimming through a glass tunnel',
#   'destination': 'command center',
#   'direction': 'inside',
#   'inverse_id': None,
#   'room_id': 775},
#  '1288': {'connection': 'swimming through the deep canals',
#   'destination': 'Underwater trenches',
#   'direction': 'down',
#   'inverse_id': None,
#   'room_id': 775},
#  '129': {'connection': 'going down main aisle',
#   'destination': 'altar',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 73},
#  '13': {'connection': 'Opening the Metal Door',
#   'destination': 'Castle Kitchen',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 12},
#  '130': {'connection': 'going down main aisle',
#   'destination': 'church entrance',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 73},
#  '133': {'connection': 'opening door',
#   'destination': 'Main entrance',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 75},
#  '134': {'connection': 'taking staircase',
#   'destination': 'Dungeon',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 75},
#  '135': {'connection': 'taking staircase',
#   'destination': 'Dungeon',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 104},
#  '136': {'connection': 'taking staircase',
#   'destination': 'Dungeon',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 105},
#  '137': {'connection': 'taking staircase',
#   'destination': 'Dungeon',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 180},
#  '138': {'connection': 'taking staircase',
#   'destination': 'Dungeon',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 244},
#  '139': {'connection': 'walking',
#   'destination': "Witch's house",
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 76},
#  '14': {'connection': 'Climbing the ladder',
#   'destination': 'Castle Dining room',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 12},
#  '140': {'connection': 'walking',
#   'destination': 'Trading post',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 76},
#  '141': {'connection': 'south river jujo',
#   'destination': 'Dandre',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 77},
#  '142': {'connection': 'propping open the trapdoor in the floor',
#   'destination': 'North Tower',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 78},
#  '144': {'connection': 'exiting the oak door',
#   'destination': 'Tower room',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 80},
#  '145': {'connection': 'walking out the door from the staircase',
#   'destination': 'Keep',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 80},
#  '146': {'connection': 'the front door',
#   'destination': 'Throne Room',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 81},
#  '147': {'connection': 'the door just down the hall',
#   'destination': 'The kitchen',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 81},
#  '148': {'connection': 'Opening the heavy double doors at the North end',
#   'destination': 'Guard Barracks',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 82},
#  '149': {'connection': 'Opening the small oak door and taking a flight of stairs downwards',
#   'destination': 'Smithery',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 82},
#  '15': {'connection': 'horse',
#   'destination': 'Flower filled meadow',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 13},
#  '150': {'connection': 'the sandpit',
#   'destination': 'beach front',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 83},
#  '151': {'connection': 'the dock',
#   'destination': 'water well',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 83},
#  '152': {'connection': 'going through the draped curtain',
#   'destination': 'Arch Hall',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 84},
#  '153': {'connection': 'opening the glass door',
#   'destination': 'Bright Path',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 84},
#  '156': {'connection': 'Gatehouse',
#   'destination': 'Royal City',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 86},
#  '157': {'connection': 'Water',
#   'destination': 'The Great Sea',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 86},
#  '158': {'connection': 'the water bridge',
#   'destination': 'Guard tower',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 87},
#  '159': {'connection': 'the temple',
#   'destination': 'main entrance',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 87},
#  '16': {'connection': 'foot',
#   'destination': 'blacksmiths',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 13},
#  '160': {'connection': 'walkway',
#   'destination': 'weapon storage',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 88},
#  '161': {'connection': 'path',
#   'destination': 'stables',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 88},
#  '164': {'connection': 'descending the spiral stairs',
#   'destination': 'Slave quarters',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 90},
#  '165': {'connection': 'crossing the bridge',
#   'destination': 'Castle moat',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 90},
#  '166': {'connection': 'walking up the winding staircase',
#   'destination': 'Entrance',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 91},
#  '167': {'connection': 'either going down the staircase or by rappelling down out through the window',
#   'destination': 'Exit',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 91},
#  '168': {'connection': 'walking to the end of the hall',
#   'destination': 'Throne room',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 92},
#  '169': {'connection': 'following the velvet carpet',
#   'destination': 'Shrine',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 93},
#  '17': {'connection': 'the edge of the forest',
#   'destination': 'forest entrance',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 14},
#  '170': {'connection': 'climbing the wooden stairs',
#   'destination': 'Bell Tower',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 93},
#  '171': {'connection': 'walking down the pier',
#   'destination': 'Wharf',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 94},
#  '172': {'connection': "Walking toward the water's edge",
#   'destination': 'Quay',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 94},
#  '175': {'connection': 'crawling under the caves low entrance',
#   'destination': 'Woods',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 96},
#  '176': {'connection': 'exiting the confessional and walking down the church aisle',
#   'destination': 'Altar',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 97},
#  '177': {'connection': 'walking past the altar and through the small door in the back of the church',
#   'destination': 'Graveyard',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 97},
#  '18': {'connection': 'walking through the forest',
#   'destination': 'river',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 14},
#  '180': {'connection': 'opening the glass doors',
#   'destination': 'Balcony',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 99},
#  '181': {'connection': 'opening the ornate door',
#   'destination': 'Landing in the Foyer',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 99},
#  '182': {'connection': 'walking down the cobbled path',
#   'destination': 'Abandoned workers shed',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 100},
#  '183': {'connection': 'walking through the bramble woods',
#   'destination': 'Small cottage at the edge of the woods',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 100},
#  '184': {'connection': 'open the main door',
#   'destination': 'Inside the Castle',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 101},
#  '185': {'connection': 'The west wing of the castle',
#   'destination': 'Show Room',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 101},
#  '186': {'connection': 'taking the bone bridge',
#   'destination': 'acid yard',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 102},
#  '187': {'connection': 'crawling under the guard nets',
#   'destination': 'acid sea',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 102},
#  '188': {'connection': 'Opening the hidden door on the south wall',
#   'destination': 'The Bottlery',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 103},
#  '189': {'connection': 'pulling a ceiling handle to open door',
#   'destination': 'The Pantry',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 103},
# ...
#   'destination': "gardener's cottage",
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 457},
#  '857': {'connection': 'Go inside the wooden door of the church entrance.',
#   'destination': 'Inside Church',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 458},
#  '858': {'connection': 'Follow the dirt path',
#   'destination': 'the church cemetery',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 458},
#  '859': {'connection': 'Descent the stairway near the tapestry with the white angel.',
#   'destination': 'Grand Ballroom',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 459},
#  '860': {'connection': 'Climb the ladder that is net to the doorway to the kitchen.',
#   'destination': 'the attic',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 459},
#  '861': {'connection': 'walking along the river',
#   'destination': 'Along the banks of a river in the forest',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 505},
#  '862': {'connection': 'Walking on the dirt path next to the tall trees.',
#   'destination': 'the country cottage',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 505},
#  '863': {'connection': 'Go through the small wooden door next to the largest window.',
#   'destination': 'Meditation room',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 461},
#  '864': {'connection': 'Travel through the golden door next to the small window.',
#   'destination': 'clergy room',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 461},
#  '867': {'connection': 'walking to the entrance of the cave',
#   'destination': 'Primary Cave',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 463},
#  '868': {'connection': 'descending a stone staircase',
#   'destination': 'a root cellar',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 463},
#  '869': {'connection': 'going up the ladder',
#   'destination': 'Pirate Ship',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 466},
#  '87': {'connection': 'walking through the docks',
#   'destination': 'Fish Market',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 51},
#  '870': {'connection': 'going through a locked door.',
#   'destination': 'Captains quarters',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 466},
#  '871': {'connection': 'Opening an ornate door off the side',
#   'destination': "King's Bedroom",
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 465},
#  '872': {'connection': 'going up the staircase to the left',
#   'destination': 'the dancing hall',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 465},
#  '873': {'connection': 'opening the wooden door',
#   'destination': 'Pirate Ship',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 466},
#  '874': {'connection': 'going through the trap door in the floor',
#   'destination': 'hidey hole',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 466},
#  '875': {'connection': 'Going up by the pier',
#   'destination': "Fishmonger's stall",
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 470},
#  '876': {'connection': 'Taking a left at the entrance of the pier.',
#   'destination': "Fishermen's Fountain",
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 470},
#  '877': {'connection': 'following the poles with golden flags',
#   'destination': 'Hunting grounds',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 468},
#  '878': {'connection': 'taking the paved path with red markings.',
#   'destination': 'the armory',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 468},
#  '879': {'connection': 'following the stream up water',
#   'destination': 'Tree of Spirits',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 469},
#  '88': {'connection': 'walking out the back door',
#   'destination': 'Fishing Store',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 51},
#  '880': {'connection': 'traversing the forest path',
#   'destination': 'Brambleton Village',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 469},
#  '881': {'connection': 'walking inland',
#   'destination': "Fishmonger's stall",
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 470},
#  '882': {'connection': 'walking north',
#   'destination': 'the inn',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 470},
#  '883': {'connection': 'entering the rear door',
#   'destination': 'Port Tavern',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 471},
#  '884': {'connection': 'walking across the road',
#   'destination': 'the front porch of the inn',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 471},
#  '885': {'connection': "walking through the cave's entrance",
#   'destination': 'Cave',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 472},
#  '886': {'connection': 'walking through the trees',
#   'destination': 'Jungle of the Beasts',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 472},
#  '887': {'connection': 'climbing out the water',
#   'destination': 'The stream',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 473},
#  '888': {'connection': 'climbing out of the water',
#   'destination': 'forest',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 473},
#  '893': {'connection': 'Taking the arrow trail',
#   'destination': 'Archery zone',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 476},
#  '894': {'connection': 'Taking the Jousting Trail',
#   'destination': 'The Jousting Field',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 476},
#  '895': {'connection': 'opening the side door.',
#   'destination': "Servant's Quarters",
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 477},
#  '896': {'connection': 'Opening the smoke blackened wooden door.',
#   'destination': 'The fire pit outside the kitchens',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 477},
#  '897': {'connection': 'opening the glass door',
#   'destination': 'Banquet Hall',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 492},
#  '898': {'connection': 'walking on the path',
#   'destination': 'the pond',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 492},
#  '899': {'connection': 'opening cottage door',
#   'destination': 'Kitchen',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 479},
#  '900': {'connection': 'crossing the yard',
#   'destination': 'the barn',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 479},
#  '901': {'connection': 'following the path back to the shoreline.',
#   'destination': 'Northern Shore',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 480},
#  '902': {'connection': 'following the path deeper into the woods.',
#   'destination': 'The haunted shrine',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 480},
#  '903': {'connection': 'Taking the stairs up',
#   'destination': "Debtor's Prison",
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 481},
#  '904': {'connection': 'taking the northern path',
#   'destination': 'Prison armory',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 481},
#  '905': {'connection': 'taking the western path',
#   'destination': 'The Docks',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 482},
#  '906': {'connection': 'taking the northern path',
#   'destination': "Fisherman's cottage",
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 482},
#  '909': {'connection': 'taking the staircase',
#   'destination': 'Temple Entrance',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 491},
#  '91': {'connection': 'following the stone path by the cave.',
#   'destination': 'the underground river',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 53},
#  '910': {'connection': 'taking the northern path',
#   'destination': 'Small garden',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 491},
#  '913': {'connection': 'taking the inner path',
#   'destination': 'Lush meadow in the country side',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 486},
#  '914': {'connection': 'northern path',
#   'destination': 'Dilapidated cottage',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 486},
#  '915': {'connection': 'taking the eastern path',
#   'destination': 'Kings bedroom',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 657},
#  '916': {'connection': 'taking the northern path',
#   'destination': 'Royal armory',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 657},
#  '917': {'connection': 'Taking the southern path',
#   'destination': 'The old red barn',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 488},
#  '918': {'connection': 'taking the northern route',
#   'destination': 'Small farm field',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 488},
#  '92': {'connection': 'climbing up the stone',
#   'destination': 'cave exit',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 53},
#  '921': {'connection': 'climbing the stones at the mouth of the river.',
#   'destination': 'Underground Cavern',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 693},
#  '922': {'connection': 'following the stone path.',
#   'destination': 'The entrance to the cavern',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 693},
#  '923': {'connection': 'passing through the temple entrance door on the South wall.',
#   'destination': 'Temple Entrance',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 491},
#  '924': {'connection': 'Walking passed the pews along the red carpet',
#   'destination': 'The throne by the giant statues',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 491},
#  '925': {'connection': 'Going through the red draped archway on the South wall.',
#   'destination': 'Banquet Hall',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 492},
#  '926': {'connection': 'moving through the opposite archway on the other side of the room',
#   'destination': 'Chapel',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 492},
#  '929': {'connection': 'crawling into the small entrance of the cave',
#   'destination': 'Dark Cave',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 494},
#  '93': {'connection': "Leaving the church's entrance",
#   'destination': 'Church Garden',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 54},
#  '930': {'connection': 'following the markers on the trees',
#   'destination': 'small lake',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 494},
#  '931': {'connection': 'walking the dirt road',
#   'destination': 'Shop in Bazaar',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 495},
#  '932': {'connection': 'walking a flower filled path past the bazaar',
#   'destination': "the king's memorial",
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 495},
#  '939': {'connection': 'going through the crypt door',
#   'destination': 'inside temple crypt',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 499},
#  '94': {'connection': 'Walking to the east of the church',
#   'destination': 'Marketplace',
#   'direction': 'East',
#   'inverse_id': None,
#   'room_id': 54},
#  '940': {'connection': 'heading back out to the entrance of the temple',
#   'destination': 'Temple Steps',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 499},
#  '941': {'connection': 'exiting the front entrance',
#   'destination': 'stable',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 500},
#  '942': {'connection': 'walking past the stable and to the left',
#   'destination': "King's Horse's Tent",
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 500},
#  '943': {'connection': 'walking up the winding staircase',
#   'destination': "Wizard's Quarters",
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 501},
#  '944': {'connection': 'Walking around the tower to a small stream',
#   'destination': 'Wishing Well',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 501},
#  '945': {'connection': 'going up the path on the mountainside',
#   'destination': 'Abandoned Mine',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 671},
#  '946': {'connection': 'heading north past the mine entrance',
#   'destination': "The abandoned miner's outpost",
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 671},
#  '949': {'connection': 'Opening door',
#   'destination': 'Royal Kitchen',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 504},
#  '95': {'connection': 'the kings castle, go up the hill and it is near the top.',
#   'destination': 'unicorn palace',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 55},
#  '950': {'connection': 'opening the gate',
#   'destination': 'The stable',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 504},
#  '951': {'connection': 'Walking north towards the two thickest trees in the forest',
#   'destination': 'Along the banks of a river in the forest',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 505},
#  '952': {'connection': 'Walking west up the trail right before the trail turns from dirt to stone.',
#   'destination': 'opening of the forest',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 505},
#  '953': {'connection': 'climbing the stairs and exiting the wardrobe',
#   'destination': "Queen's quarters",
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 506},
#  '954': {'connection': 'accessing a secret panel in the wall',
#   'destination': 'the palace garden',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 506},
#  '957': {'connection': 'the same wishing well you first passed',
#   'destination': 'Firewood Forest',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 628},
#  '96': {'connection': 'walking',
#   'destination': 'Dungeon',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 56},
#  '960': {'connection': 'Walking up the steep and narrow staircase.',
#   'destination': 'Temple foyer',
#   'direction': 'Up',
#   'inverse_id': None,
#   'room_id': 625},
#  '961': {'connection': 'Walking up a flight of stairs and entering the great dining hall.',
#   'destination': 'Dining Hall',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 631},
#  '962': {'connection': 'Walking to the newly remodeled east wing of the castle.',
#   'destination': 'Knights Quarters',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 604},
#  '97': {'connection': 'walking',
#   'destination': 'Main hallway',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 56},
#  '973': {'connection': 'heading through a broken gate',
#   'destination': 'Southernmost Tower Entryway',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 582},
#  '978': {'connection': 'the door to the Wizards layer',
#   'destination': 'Desolate hallway',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 601},
#  '979': {'connection': 'Moving down a hill and going left into a dense collection of trees.',
#   'destination': 'weathered shack',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 679},
#  '98': {'connection': 'village beach',
#   'destination': 'pier walkway',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 57},
#  '983': {'connection': 'walking down the path',
#   'destination': 'mysterious forest outskirts',
#   'direction': 'Outside',
#   'inverse_id': None,
#   'room_id': 638},
#  '987': {'connection': 'The king of the north has a chest where he keeps a very powerful weapon, a magic sword capable of spitting fire',
#   'destination': 'Great Armory',
#   'direction': 'North',
#   'inverse_id': None,
#   'room_id': 649},
#  '99': {'connection': 'pier walkway',
#   'destination': 'village beach',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 57},
#  '993': {'connection': 'walking down the stairs',
#   'destination': 'Dungeon',
#   'direction': 'Down',
#   'inverse_id': None,
#   'room_id': 608},
#  '996': {'connection': '{}',
#   'destination': 'Riverbed',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 637},
#  '998': {'connection': '{}',
#   'destination': 'Boat House',
#   'direction': 'Inside',
#   'inverse_id': None,
#   'room_id': 583}}

# %%
# get connections of one specific location
def get_location_connection(room_id, rooms_by_id, light_environment, current_connections):
  """
  This generates a prompt and a completion which can be used to fine-tune OpenAI.
  This version just gnnerates 
  """
  prompt = ""
  completion = ""
  prompt += "Category: {category}\n".format(category=rooms_by_id[room_id]['category'].capitalize())
  prompt += "Setting: {setting}\n".format(setting=rooms_by_id[room_id]['setting'].capitalize())
  prompt += "Description: {description}\n".format(description=rooms_by_id[room_id]['description'])
  prompt += "Current_Connections: {current_connections}\n".format(current_connections=str(current_connections))
  connections=[]
  for neighbor_code in rooms_by_id[room_id]['neighbors']:
    connections.append((light_environment['neighbors'][str(neighbor_code)]["direction"],light_environment['neighbors'][str(neighbor_code)]["destination"]))
  completion += "Connections: {connections}\n".format(connections=str(connections))
  completion += "###\n"

  return prompt, completion

possible_connections=[]
n=0
neighbors=None
def backtrack(i, array):
  if i==n:
    possible_connections.append(array[:])
    return
  neighbor_code = neighbors[i]
  array.append((light_environment['neighbors'][str(neighbor_code)]["direction"],light_environment['neighbors'][str(neighbor_code)]["destination"]))
  backtrack(i+1, array)
  array.pop()
  backtrack(i+1, array)

def create_location_connections_finetuning_data(filename='fine_tuning_location_connections.jsonl'):
  global possible_connections, n, neighbors
  # fine_tuning_data = []
  with open(filename, 'w') as out:
    for category in categories:
      rooms = rooms_by_category[category]
      for room_id in rooms:
        data = {}
        possible_connections=[]
        neighbors=rooms_by_id[room_id]['neighbors']
        n = len(neighbors)
        backtrack(0, [])
        for current_connections in possible_connections:
          prompt, completion = get_location_connection(room_id, rooms_by_id, light_environment, current_connections)
          data['prompt'] = prompt
          data['completion'] = completion
          out.write(json.dumps(data))
          out.write('\n')
          print(prompt[:], end="")
          print(completion[:])
        

create_location_connections_finetuning_data()
# Out:
# Streaming output truncated to the last 5000 lines.
# ###
#
# Category: Inside tower
# Setting: Dining hall
# Description: A somewhat ornate room with stone walls, hanging tapestries, and a detailed look dinner table in the center with many chairs.  There's candles on the dinner tables along with place mats for those who come to eat.
# Current_Connections: [('Down', 'Dungeon')]
# Connections: [('North', 'Main entrance'), ('Down', 'Dungeon')]
# ###
#
# Category: Inside tower
# Setting: Dining hall
# Description: A somewhat ornate room with stone walls, hanging tapestries, and a detailed look dinner table in the center with many chairs.  There's candles on the dinner tables along with place mats for those who come to eat.
# Current_Connections: []
# Connections: [('North', 'Main entrance'), ('Down', 'Dungeon')]
# ###
#
# Category: Inside tower
# Setting: Weapon closet
# Description: The closet is a small dark room. There are different types of swords, axes, bows and arrows, and other types of weapons organized inside of the closet. It is just a barren, dark room with simple white walls and wooden floor.
# Current_Connections: [('Outside', 'Balcony'), ('Up', 'tower bedroom')]
# Connections: [('Outside', 'Balcony'), ('Up', 'tower bedroom')]
# ###
#
# Category: Inside tower
# Setting: Weapon closet
# Description: The closet is a small dark room. There are different types of swords, axes, bows and arrows, and other types of weapons organized inside of the closet. It is just a barren, dark room with simple white walls and wooden floor.
# Current_Connections: [('Outside', 'Balcony')]
# Connections: [('Outside', 'Balcony'), ('Up', 'tower bedroom')]
# ###
#
# Category: Inside tower
# Setting: Weapon closet
# Description: The closet is a small dark room. There are different types of swords, axes, bows and arrows, and other types of weapons organized inside of the closet. It is just a barren, dark room with simple white walls and wooden floor.
# Current_Connections: [('Up', 'tower bedroom')]
# Connections: [('Outside', 'Balcony'), ('Up', 'tower bedroom')]
# ###
#
# Category: Inside tower
# Setting: Weapon closet
# Description: The closet is a small dark room. There are different types of swords, axes, bows and arrows, and other types of weapons organized inside of the closet. It is just a barren, dark room with simple white walls and wooden floor.
# Current_Connections: []
# Connections: [('Outside', 'Balcony'), ('Up', 'tower bedroom')]
# ###
#
# Category: Inside tower
# Setting: Southernmost tower entryway
# Description: The rather drab tower was made of gray stones approximately all the same size. Artwork hung on the walls depicting battle scenes from long ago but even the color from these had faded with time. The cold, outside air seeped in through every small crack and crevice leaving a damp quality to the air. Sealed off rooms lined the perimeter and obviously had not been seen by human eyes for centuries.
# Current_Connections: [('Inside', 'South Castle'), ('North', 'Forest of Wonder')]
# Connections: [('Inside', 'South Castle'), ('North', 'Forest of Wonder')]
# ###
#
# Category: Inside tower
# Setting: Southernmost tower entryway
# Description: The rather drab tower was made of gray stones approximately all the same size. Artwork hung on the walls depicting battle scenes from long ago but even the color from these had faded with time. The cold, outside air seeped in through every small crack and crevice leaving a damp quality to the air. Sealed off rooms lined the perimeter and obviously had not been seen by human eyes for centuries.
# Current_Connections: [('Inside', 'South Castle')]
# Connections: [('Inside', 'South Castle'), ('North', 'Forest of Wonder')]
# ###
#
# Category: Inside tower
# Setting: Southernmost tower entryway
# Description: The rather drab tower was made of gray stones approximately all the same size. Artwork hung on the walls depicting battle scenes from long ago but even the color from these had faded with time. The cold, outside air seeped in through every small crack and crevice leaving a damp quality to the air. Sealed off rooms lined the perimeter and obviously had not been seen by human eyes for centuries.
# Current_Connections: [('North', 'Forest of Wonder')]
# Connections: [('Inside', 'South Castle'), ('North', 'Forest of Wonder')]
# ###
#
# Category: Inside tower
# Setting: Southernmost tower entryway
# Description: The rather drab tower was made of gray stones approximately all the same size. Artwork hung on the walls depicting battle scenes from long ago but even the color from these had faded with time. The cold, outside air seeped in through every small crack and crevice leaving a damp quality to the air. Sealed off rooms lined the perimeter and obviously had not been seen by human eyes for centuries.
# Current_Connections: []
# Connections: [('Inside', 'South Castle'), ('North', 'Forest of Wonder')]
# ###
#
# Category: Inside tower
# Setting: Alchemists bedroom
# Description: This room holds a small bed, a table and several work benches. More flasks, beakers, candles, alembics, decanters, herbs, kettles, and the like may be found. Several books of forbidden lore sit upon the table. A circle, nine feet across and adorned with words of power is etched into the floor.
# Current_Connections: [('Up', 'Alchemists Lab'), ('Up', 'Alchemists Lab')]
# Connections: [('Up', 'Alchemists Lab'), ('Up', 'Alchemists Lab')]
# ###
#
# Category: Inside tower
# Setting: Alchemists bedroom
# Description: This room holds a small bed, a table and several work benches. More flasks, beakers, candles, alembics, decanters, herbs, kettles, and the like may be found. Several books of forbidden lore sit upon the table. A circle, nine feet across and adorned with words of power is etched into the floor.
# Current_Connections: [('Up', 'Alchemists Lab')]
# Connections: [('Up', 'Alchemists Lab'), ('Up', 'Alchemists Lab')]
# ###
#
# Category: Inside tower
# Setting: Alchemists bedroom
# Description: This room holds a small bed, a table and several work benches. More flasks, beakers, candles, alembics, decanters, herbs, kettles, and the like may be found. Several books of forbidden lore sit upon the table. A circle, nine feet across and adorned with words of power is etched into the floor.
# Current_Connections: [('Up', 'Alchemists Lab')]
# Connections: [('Up', 'Alchemists Lab'), ('Up', 'Alchemists Lab')]
# ###
#
# Category: Inside tower
# Setting: Alchemists bedroom
# Description: This room holds a small bed, a table and several work benches. More flasks, beakers, candles, alembics, decanters, herbs, kettles, and the like may be found. Several books of forbidden lore sit upon the table. A circle, nine feet across and adorned with words of power is etched into the floor.
# Current_Connections: []
# Connections: [('Up', 'Alchemists Lab'), ('Up', 'Alchemists Lab')]
# ###
#
# Category: Inside tower
# Setting: Prison room
# Description: Up at the top of the tower, among the gray clouds, is the prison room. The room is round, with a circumference of about 15 feet. The walls are barren and made of stone; only one barred window gives a view out onto the vast landscape. A small bed and a dirty wooden bucket are the only decorations. The desolate princess spends day and night laying on that small bed, wondering where things went wrong
# Current_Connections: [('Down', 'Castle entrance'), ('North', 'Town')]
# Connections: [('Down', 'Castle entrance'), ('North', 'Town')]
# ###
#
# Category: Inside tower
# Setting: Prison room
# Description: Up at the top of the tower, among the gray clouds, is the prison room. The room is round, with a circumference of about 15 feet. The walls are barren and made of stone; only one barred window gives a view out onto the vast landscape. A small bed and a dirty wooden bucket are the only decorations. The desolate princess spends day and night laying on that small bed, wondering where things went wrong
# Current_Connections: [('Down', 'Castle entrance')]
# Connections: [('Down', 'Castle entrance'), ('North', 'Town')]
# ###
#
# Category: Inside tower
# Setting: Prison room
# Description: Up at the top of the tower, among the gray clouds, is the prison room. The room is round, with a circumference of about 15 feet. The walls are barren and made of stone; only one barred window gives a view out onto the vast landscape. A small bed and a dirty wooden bucket are the only decorations. The desolate princess spends day and night laying on that small bed, wondering where things went wrong
# Current_Connections: [('North', 'Town')]
# Connections: [('Down', 'Castle entrance'), ('North', 'Town')]
# ###
#
# Category: Inside tower
# Setting: Prison room
# Description: Up at the top of the tower, among the gray clouds, is the prison room. The room is round, with a circumference of about 15 feet. The walls are barren and made of stone; only one barred window gives a view out onto the vast landscape. A small bed and a dirty wooden bucket are the only decorations. The desolate princess spends day and night laying on that small bed, wondering where things went wrong
# Current_Connections: []
# Connections: [('Down', 'Castle entrance'), ('North', 'Town')]
# ###
#
# Category: Inside tower
# Setting: Artillery room
# Description: The artillery room is dark and spacious. Weapons and gunpowder hang from the walls. A darkly set of walls line the room and tower.
# Current_Connections: [('North', 'artillery room'), ('Down', 'artillery room')]
# Connections: [('North', 'artillery room'), ('Down', 'artillery room')]
# ###
#
# Category: Inside tower
# Setting: Artillery room
# Description: The artillery room is dark and spacious. Weapons and gunpowder hang from the walls. A darkly set of walls line the room and tower.
# Current_Connections: [('North', 'artillery room')]
# Connections: [('North', 'artillery room'), ('Down', 'artillery room')]
# ###
#
# Category: Inside tower
# Setting: Artillery room
# Description: The artillery room is dark and spacious. Weapons and gunpowder hang from the walls. A darkly set of walls line the room and tower.
# Current_Connections: [('Down', 'artillery room')]
# Connections: [('North', 'artillery room'), ('Down', 'artillery room')]
# ###
#
# Category: Inside tower
# Setting: Artillery room
# Description: The artillery room is dark and spacious. Weapons and gunpowder hang from the walls. A darkly set of walls line the room and tower.
# Current_Connections: []
# Connections: [('North', 'artillery room'), ('Down', 'artillery room')]
# ###
#
# Category: Inside tower
# Setting: Jail entrance
# Description: The jail entrance is massive with a huge fence. There are guards on all sides. There are barbs and dangerous things surrounding.
# Current_Connections: [('North', 'Jail room'), ('North', 'Dining room'), ('Inside', 'the jail room')]
# Connections: [('North', 'Jail room'), ('North', 'Dining room'), ('Inside', 'the jail room')]
# ###
#
# Category: Inside tower
# Setting: Jail entrance
# Description: The jail entrance is massive with a huge fence. There are guards on all sides. There are barbs and dangerous things surrounding.
# Current_Connections: [('North', 'Jail room'), ('North', 'Dining room')]
# Connections: [('North', 'Jail room'), ('North', 'Dining room'), ('Inside', 'the jail room')]
# ###
#
# Category: Inside tower
# Setting: Jail entrance
# Description: The jail entrance is massive with a huge fence. There are guards on all sides. There are barbs and dangerous things surrounding.
# Current_Connections: [('North', 'Jail room'), ('Inside', 'the jail room')]
# Connections: [('North', 'Jail room'), ('North', 'Dining room'), ('Inside', 'the jail room')]
# ###
#
# Category: Inside tower
# Setting: Jail entrance
# Description: The jail entrance is massive with a huge fence. There are guards on all sides. There are barbs and dangerous things surrounding.
# Current_Connections: [('North', 'Jail room')]
# Connections: [('North', 'Jail room'), ('North', 'Dining room'), ('Inside', 'the jail room')]
# ###
#
# Category: Inside tower
# Setting: Jail entrance
# Description: The jail entrance is massive with a huge fence. There are guards on all sides. There are barbs and dangerous things surrounding.
# Current_Connections: [('North', 'Dining room'), ('Inside', 'the jail room')]
# Connections: [('North', 'Jail room'), ('North', 'Dining room'), ('Inside', 'the jail room')]
# ###
#
# Category: Inside tower
# Setting: Jail entrance
# Description: The jail entrance is massive with a huge fence. There are guards on all sides. There are barbs and dangerous things surrounding.
# Current_Connections: [('North', 'Dining room')]
# Connections: [('North', 'Jail room'), ('North', 'Dining room'), ('Inside', 'the jail room')]
# ###
#
# Category: Inside tower
# Setting: Jail entrance
# Description: The jail entrance is massive with a huge fence. There are guards on all sides. There are barbs and dangerous things surrounding.
# Current_Connections: [('Inside', 'the jail room')]
# Connections: [('North', 'Jail room'), ('North', 'Dining room'), ('Inside', 'the jail room')]
# ###
#
# Category: Inside tower
# Setting: Jail entrance
# Description: The jail entrance is massive with a huge fence. There are guards on all sides. There are barbs and dangerous things surrounding.
# Current_Connections: []
# Connections: [('North', 'Jail room'), ('North', 'Dining room'), ('Inside', 'the jail room')]
# ###
#
# Category: Inside tower
# Setting: Tower dungeon
# Description: A rank, pitiful room filled with detestable creatures. Among the creatures are traitors of the King and criminals of the kingdom. All around the dungeon these ingrates line the walls, shackled and unable to move.
# Current_Connections: [('North', 'dungeon entrance'), ('Down', 'dungeon cells')]
# Connections: [('North', 'dungeon entrance'), ('Down', 'dungeon cells')]
# ###
#
# Category: Inside tower
# Setting: Tower dungeon
# Description: A rank, pitiful room filled with detestable creatures. Among the creatures are traitors of the King and criminals of the kingdom. All around the dungeon these ingrates line the walls, shackled and unable to move.
# Current_Connections: [('North', 'dungeon entrance')]
# Connections: [('North', 'dungeon entrance'), ('Down', 'dungeon cells')]
# ###
#
# Category: Inside tower
# Setting: Tower dungeon
# Description: A rank, pitiful room filled with detestable creatures. Among the creatures are traitors of the King and criminals of the kingdom. All around the dungeon these ingrates line the walls, shackled and unable to move.
# Current_Connections: [('Down', 'dungeon cells')]
# Connections: [('North', 'dungeon entrance'), ('Down', 'dungeon cells')]
# ###
#
# Category: Inside tower
# Setting: Tower dungeon
# Description: A rank, pitiful room filled with detestable creatures. Among the creatures are traitors of the King and criminals of the kingdom. All around the dungeon these ingrates line the walls, shackled and unable to move.
# Current_Connections: []
# Connections: [('North', 'dungeon entrance'), ('Down', 'dungeon cells')]
# ###
#
# Category: Inside tower
# Setting: Tower sewers
# Description: A rank maze of sewers that lie below the tower. They course with filthy ooze from the experiments of the mad king. Rats patrol its smelly walkways. Bones of treasure seekers lie riddled across the walkways, nibbled clean by the fat rats.
# Current_Connections: [('Inside', 'sewer entrance'), ('Inside', 'rat den')]
# Connections: [('Inside', 'sewer entrance'), ('Inside', 'rat den')]
# ###
#
# Category: Inside tower
# Setting: Tower sewers
# Description: A rank maze of sewers that lie below the tower. They course with filthy ooze from the experiments of the mad king. Rats patrol its smelly walkways. Bones of treasure seekers lie riddled across the walkways, nibbled clean by the fat rats.
# Current_Connections: [('Inside', 'sewer entrance')]
# Connections: [('Inside', 'sewer entrance'), ('Inside', 'rat den')]
# ###
#
# Category: Inside tower
# Setting: Tower sewers
# Description: A rank maze of sewers that lie below the tower. They course with filthy ooze from the experiments of the mad king. Rats patrol its smelly walkways. Bones of treasure seekers lie riddled across the walkways, nibbled clean by the fat rats.
# Current_Connections: [('Inside', 'rat den')]
# Connections: [('Inside', 'sewer entrance'), ('Inside', 'rat den')]
# ###
#
# Category: Inside tower
# Setting: Tower sewers
# Description: A rank maze of sewers that lie below the tower. They course with filthy ooze from the experiments of the mad king. Rats patrol its smelly walkways. Bones of treasure seekers lie riddled across the walkways, nibbled clean by the fat rats.
# Current_Connections: []
# Connections: [('Inside', 'sewer entrance'), ('Inside', 'rat den')]
# ###
#
# Category: Inside tower
# Setting: Dining hall
# Description: The dining hall has a long, elegant wooden table with ornate chairs at both ends and along the sides. There are place settings at each seat with a rustic silverware set and gold plates. The wall is decorated with paintings of knights and past royalty.
# Current_Connections: [('East', "King's Dorm"), ('North', 'Gold Room')]
# Connections: [('East', "King's Dorm"), ('North', 'Gold Room')]
# ###
#
# Category: Inside tower
# Setting: Dining hall
# Description: The dining hall has a long, elegant wooden table with ornate chairs at both ends and along the sides. There are place settings at each seat with a rustic silverware set and gold plates. The wall is decorated with paintings of knights and past royalty.
# Current_Connections: [('East', "King's Dorm")]
# Connections: [('East', "King's Dorm"), ('North', 'Gold Room')]
# ###
#
# Category: Inside tower
# Setting: Dining hall
# Description: The dining hall has a long, elegant wooden table with ornate chairs at both ends and along the sides. There are place settings at each seat with a rustic silverware set and gold plates. The wall is decorated with paintings of knights and past royalty.
# Current_Connections: [('North', 'Gold Room')]
# Connections: [('East', "King's Dorm"), ('North', 'Gold Room')]
# ###
#
# Category: Inside tower
# Setting: Dining hall
# Description: The dining hall has a long, elegant wooden table with ornate chairs at both ends and along the sides. There are place settings at each seat with a rustic silverware set and gold plates. The wall is decorated with paintings of knights and past royalty.
# Current_Connections: []
# Connections: [('East', "King's Dorm"), ('North', 'Gold Room')]
# ###
#
# Category: Inside tower
# Setting: The king's quarters
# Description: Decadent, sensual, and tranquil, the King's Quarters sparkles with the various diamonds and gold-laced furniture comprising the entire room.  Self-portraits of the king himself, his queen, and various demigods line the walls leading up to the bed.  Smooth, bear- and tiger-skin rugs cover the entire floor to protect the bare feet of scantily clad virgins who serve to the beckon and call of the king and his queen.  There is a faint smell of sandalwood wafting to and from each section of the room at all times.
# Current_Connections: [('Up', 'Entrance'), ('Down', 'Exit')]
# Connections: [('Up', 'Entrance'), ('Down', 'Exit')]
# ###
#
# Category: Inside tower
# Setting: The king's quarters
# Description: Decadent, sensual, and tranquil, the King's Quarters sparkles with the various diamonds and gold-laced furniture comprising the entire room.  Self-portraits of the king himself, his queen, and various demigods line the walls leading up to the bed.  Smooth, bear- and tiger-skin rugs cover the entire floor to protect the bare feet of scantily clad virgins who serve to the beckon and call of the king and his queen.  There is a faint smell of sandalwood wafting to and from each section of the room at all times.
# Current_Connections: [('Up', 'Entrance')]
# Connections: [('Up', 'Entrance'), ('Down', 'Exit')]
# ###
#
# Category: Inside tower
# Setting: The king's quarters
# Description: Decadent, sensual, and tranquil, the King's Quarters sparkles with the various diamonds and gold-laced furniture comprising the entire room.  Self-portraits of the king himself, his queen, and various demigods line the walls leading up to the bed.  Smooth, bear- and tiger-skin rugs cover the entire floor to protect the bare feet of scantily clad virgins who serve to the beckon and call of the king and his queen.  There is a faint smell of sandalwood wafting to and from each section of the room at all times.
# Current_Connections: [('Down', 'Exit')]
# Connections: [('Up', 'Entrance'), ('Down', 'Exit')]
# ###
#
# Category: Inside tower
# Setting: The king's quarters
# Description: Decadent, sensual, and tranquil, the King's Quarters sparkles with the various diamonds and gold-laced furniture comprising the entire room.  Self-portraits of the king himself, his queen, and various demigods line the walls leading up to the bed.  Smooth, bear- and tiger-skin rugs cover the entire floor to protect the bare feet of scantily clad virgins who serve to the beckon and call of the king and his queen.  There is a faint smell of sandalwood wafting to and from each section of the room at all times.
# Current_Connections: []
# Connections: [('Up', 'Entrance'), ('Down', 'Exit')]
# ###
#
# Category: Inside tower
# Setting: King's dorm
# Description: The walls are adorned with artwork of previous Kings and Queens, battles and events of note. The walls are smooth hewn marble, the floor a mosaic of colored stones quarried far away.
# Current_Connections: [('South', 'Dining Hall'), ('Down', 'Dining Hall')]
# Connections: [('South', 'Dining Hall'), ('Down', 'Dining Hall')]
# ###
#
# Category: Inside tower
# Setting: King's dorm
# Description: The walls are adorned with artwork of previous Kings and Queens, battles and events of note. The walls are smooth hewn marble, the floor a mosaic of colored stones quarried far away.
# Current_Connections: [('South', 'Dining Hall')]
# Connections: [('South', 'Dining Hall'), ('Down', 'Dining Hall')]
# ###
#
# Category: Inside tower
# Setting: King's dorm
# Description: The walls are adorned with artwork of previous Kings and Queens, battles and events of note. The walls are smooth hewn marble, the floor a mosaic of colored stones quarried far away.
# Current_Connections: [('Down', 'Dining Hall')]
# Connections: [('South', 'Dining Hall'), ('Down', 'Dining Hall')]
# ###
#
# Category: Inside tower
# Setting: King's dorm
# Description: The walls are adorned with artwork of previous Kings and Queens, battles and events of note. The walls are smooth hewn marble, the floor a mosaic of colored stones quarried far away.
# Current_Connections: []
# Connections: [('South', 'Dining Hall'), ('Down', 'Dining Hall')]
# ###
#
# Category: Inside tower
# Setting: Prison room
# Description: it has old gray brick and it is hard to breathe because it is so high up in the sky, there are old skeletons there from previous prisoners.
# Current_Connections: [('Up', 'East Watch')]
# Connections: [('Up', 'East Watch')]
# ###
#
# Category: Inside tower
# Setting: Prison room
# Description: it has old gray brick and it is hard to breathe because it is so high up in the sky, there are old skeletons there from previous prisoners.
# Current_Connections: []
# Connections: [('Up', 'East Watch')]
# ###
#
# Category: Inside tower
# Setting: Inside tower
# Description: The walls and are made of marble and trimmed in gold.  So too are the winding stairs that lead up to the observation deck.  Ivy lines the outside of the walls and sprawls all the way up the side to just near the top of the tower.  The tower itself is intimidating for those who dare to approach.  The tower stands tall so as to see out way across the beautiful land it watches over.
# Current_Connections: [('Up', 'Castle entrance'), ('North', 'Tower 2')]
# Connections: [('Up', 'Castle entrance'), ('North', 'Tower 2')]
# ###
#
# Category: Inside tower
# Setting: Inside tower
# Description: The walls and are made of marble and trimmed in gold.  So too are the winding stairs that lead up to the observation deck.  Ivy lines the outside of the walls and sprawls all the way up the side to just near the top of the tower.  The tower itself is intimidating for those who dare to approach.  The tower stands tall so as to see out way across the beautiful land it watches over.
# Current_Connections: [('Up', 'Castle entrance')]
# Connections: [('Up', 'Castle entrance'), ('North', 'Tower 2')]
# ###
#
# Category: Inside tower
# Setting: Inside tower
# Description: The walls and are made of marble and trimmed in gold.  So too are the winding stairs that lead up to the observation deck.  Ivy lines the outside of the walls and sprawls all the way up the side to just near the top of the tower.  The tower itself is intimidating for those who dare to approach.  The tower stands tall so as to see out way across the beautiful land it watches over.
# Current_Connections: [('North', 'Tower 2')]
# Connections: [('Up', 'Castle entrance'), ('North', 'Tower 2')]
# ###
#
# Category: Inside tower
# Setting: Inside tower
# Description: The walls and are made of marble and trimmed in gold.  So too are the winding stairs that lead up to the observation deck.  Ivy lines the outside of the walls and sprawls all the way up the side to just near the top of the tower.  The tower itself is intimidating for those who dare to approach.  The tower stands tall so as to see out way across the beautiful land it watches over.
# Current_Connections: []
# Connections: [('Up', 'Castle entrance'), ('North', 'Tower 2')]
# ###
#
# Category: Inside tower
# Setting: Curved hallway
# Description: The curved hallway is made of large, blocky stones that provide a secure defense. The walls are streaked with dark water stains. Light from thin arrow slits streaks down at angles as the hallway curves gently to the left. An old, wooden door is tucked into the eastern side of the wall.
# Current_Connections: [('Down', 'Weapon Closet'), ('East', 'Weapon Closet')]
# Connections: [('Down', 'Weapon Closet'), ('East', 'Weapon Closet')]
# ###
#
# Category: Inside tower
# Setting: Curved hallway
# Description: The curved hallway is made of large, blocky stones that provide a secure defense. The walls are streaked with dark water stains. Light from thin arrow slits streaks down at angles as the hallway curves gently to the left. An old, wooden door is tucked into the eastern side of the wall.
# Current_Connections: [('Down', 'Weapon Closet')]
# Connections: [('Down', 'Weapon Closet'), ('East', 'Weapon Closet')]
# ###
#
# Category: Inside tower
# Setting: Curved hallway
# Description: The curved hallway is made of large, blocky stones that provide a secure defense. The walls are streaked with dark water stains. Light from thin arrow slits streaks down at angles as the hallway curves gently to the left. An old, wooden door is tucked into the eastern side of the wall.
# Current_Connections: [('East', 'Weapon Closet')]
# Connections: [('Down', 'Weapon Closet'), ('East', 'Weapon Closet')]
# ###
#
# Category: Inside tower
# Setting: Curved hallway
# Description: The curved hallway is made of large, blocky stones that provide a secure defense. The walls are streaked with dark water stains. Light from thin arrow slits streaks down at angles as the hallway curves gently to the left. An old, wooden door is tucked into the eastern side of the wall.
# Current_Connections: []
# Connections: [('Down', 'Weapon Closet'), ('East', 'Weapon Closet')]
# ###
#
# Category: Inside tower
# Setting: Gold room
# Description: A hidden room, the Gold Room is adorned with gold candle fixtures on either side, and a gold plated wooden table in the center. Riches lay all around the room and on top of the table. Here can be found the crowns of past kings and the royalty of conquered nations.
# Current_Connections: []
# Connections: []
# ###
#
# Category: Inside tower
# Setting: Entryway to the wizards tower
# Description: The Wizard tower is cluttered with book shelves and wooden tables. Every shelf is filled to the brim with books, stacked vertically and horizontally in every which way, and books lay scattered across the tables falling onto the cold stone floors below. There sit's a shelf with a variety of strange potions and powders, as well as various wands.
# Current_Connections: [('Outside', 'Town')]
# Connections: [('Outside', 'Town')]
# ###
#
# Category: Inside tower
# Setting: Entryway to the wizards tower
# Description: The Wizard tower is cluttered with book shelves and wooden tables. Every shelf is filled to the brim with books, stacked vertically and horizontally in every which way, and books lay scattered across the tables falling onto the cold stone floors below. There sit's a shelf with a variety of strange potions and powders, as well as various wands.
# Current_Connections: []
# Connections: [('Outside', 'Town')]
# ###
#
# Category: Inside tower
# Setting: Throne room
# Description: Ornate and luxurious, the throne room gleams with gold and precious jewels. Priceless paintings of past kings line the sides. Underneath a vaulted ceiling, a regal red carpet connects the throne room's entrance to the golden throne itself.
# Current_Connections: [('North', 'Castle Entrance'), ('Up', "King's Quarters")]
# Connections: [('North', 'Castle Entrance'), ('Up', "King's Quarters")]
# ###
#
# Category: Inside tower
# Setting: Throne room
# Description: Ornate and luxurious, the throne room gleams with gold and precious jewels. Priceless paintings of past kings line the sides. Underneath a vaulted ceiling, a regal red carpet connects the throne room's entrance to the golden throne itself.
# Current_Connections: [('North', 'Castle Entrance')]
# Connections: [('North', 'Castle Entrance'), ('Up', "King's Quarters")]
# ###
#
# Category: Inside tower
# Setting: Throne room
# Description: Ornate and luxurious, the throne room gleams with gold and precious jewels. Priceless paintings of past kings line the sides. Underneath a vaulted ceiling, a regal red carpet connects the throne room's entrance to the golden throne itself.
# Current_Connections: [('Up', "King's Quarters")]
# Connections: [('North', 'Castle Entrance'), ('Up', "King's Quarters")]
# ###
#
# Category: Inside tower
# Setting: Throne room
# Description: Ornate and luxurious, the throne room gleams with gold and precious jewels. Priceless paintings of past kings line the sides. Underneath a vaulted ceiling, a regal red carpet connects the throne room's entrance to the golden throne itself.
# Current_Connections: []
# Connections: [('North', 'Castle Entrance'), ('Up', "King's Quarters")]
# ###
#
# Category: Inside tower
# Setting: The great hall
# Description: Large room with vast ceilings for meetings and dining. There is a large ornate table at the head of the room for the king and his guest overlooking smaller tables for the servants.
# Current_Connections: [('South', 'The Bottlery'), ('North', 'The Pantry')]
# Connections: [('South', 'The Bottlery'), ('North', 'The Pantry')]
# ###
#
# Category: Inside tower
# Setting: The great hall
# Description: Large room with vast ceilings for meetings and dining. There is a large ornate table at the head of the room for the king and his guest overlooking smaller tables for the servants.
# Current_Connections: [('South', 'The Bottlery')]
# Connections: [('South', 'The Bottlery'), ('North', 'The Pantry')]
# ###
#
# Category: Inside tower
# Setting: The great hall
# Description: Large room with vast ceilings for meetings and dining. There is a large ornate table at the head of the room for the king and his guest overlooking smaller tables for the servants.
# Current_Connections: [('North', 'The Pantry')]
# Connections: [('South', 'The Bottlery'), ('North', 'The Pantry')]
# ###
#
# Category: Inside tower
# Setting: The great hall
# Description: Large room with vast ceilings for meetings and dining. There is a large ornate table at the head of the room for the king and his guest overlooking smaller tables for the servants.
# Current_Connections: []
# Connections: [('South', 'The Bottlery'), ('North', 'The Pantry')]
# ###
#
# Category: Inside tower
# Setting: Within the walls of the city
# Description: The Tower stands tall, built of the best stone with a number of odd runes that only the local mages truly know how to read. Despite age the stones do not crumble, and stand ever vigilante as a watch station for the city.
# Current_Connections: [('Up', 'Top point'), ('Inside', 'Armory')]
# Connections: [('Up', 'Top point'), ('Inside', 'Armory')]
# ###
#
# Category: Inside tower
# Setting: Within the walls of the city
# Description: The Tower stands tall, built of the best stone with a number of odd runes that only the local mages truly know how to read. Despite age the stones do not crumble, and stand ever vigilante as a watch station for the city.
# Current_Connections: [('Up', 'Top point')]
# Connections: [('Up', 'Top point'), ('Inside', 'Armory')]
# ###
#
# Category: Inside tower
# Setting: Within the walls of the city
# Description: The Tower stands tall, built of the best stone with a number of odd runes that only the local mages truly know how to read. Despite age the stones do not crumble, and stand ever vigilante as a watch station for the city.
# Current_Connections: [('Inside', 'Armory')]
# Connections: [('Up', 'Top point'), ('Inside', 'Armory')]
# ###
#
# Category: Inside tower
# Setting: Within the walls of the city
# Description: The Tower stands tall, built of the best stone with a number of odd runes that only the local mages truly know how to read. Despite age the stones do not crumble, and stand ever vigilante as a watch station for the city.
# Current_Connections: []
# Connections: [('Up', 'Top point'), ('Inside', 'Armory')]
# ###
#
# Category: Inside tower
# Setting: Kitchens
# Description: The kitchens of the tower are a giant kabob of tables and cans of herbs and various condiments. Some VERY fresh meats are found here as well. So fresh they are... well, alive. You see holding cells for various fowl and beast in a pen in the room. The smell is not very pleasant, but the food generally tastes a lot better.
# Current_Connections: []
# Connections: []
# ###
#
# Category: Inside tower
# Setting: Alchemists lab
# Description: The alchemists lab is a hidden, mysterious chamber at the top of the tower. There are all sorts of beakers and potions laid out on wooden tables. Smoke and light emanate from the experiments. A large shelf holds jars of strange ingredients, and in the center of the room there is some sort of huge vat of brewing liquid, bubbling and steaming.
# Current_Connections: [('Down', 'Alchemists bedroom'), ('Down', 'kitchens')]
# Connections: [('Down', 'Alchemists bedroom'), ('Down', 'kitchens')]
# ###
#
# Category: Inside tower
# Setting: Alchemists lab
# Description: The alchemists lab is a hidden, mysterious chamber at the top of the tower. There are all sorts of beakers and potions laid out on wooden tables. Smoke and light emanate from the experiments. A large shelf holds jars of strange ingredients, and in the center of the room there is some sort of huge vat of brewing liquid, bubbling and steaming.
# Current_Connections: [('Down', 'Alchemists bedroom')]
# Connections: [('Down', 'Alchemists bedroom'), ('Down', 'kitchens')]
# ###
#
# Category: Inside tower
# Setting: Alchemists lab
# Description: The alchemists lab is a hidden, mysterious chamber at the top of the tower. There are all sorts of beakers and potions laid out on wooden tables. Smoke and light emanate from the experiments. A large shelf holds jars of strange ingredients, and in the center of the room there is some sort of huge vat of brewing liquid, bubbling and steaming.
# Current_Connections: [('Down', 'kitchens')]
# Connections: [('Down', 'Alchemists bedroom'), ('Down', 'kitchens')]
# ###
#
# Category: Inside tower
# Setting: Alchemists lab
# Description: The alchemists lab is a hidden, mysterious chamber at the top of the tower. There are all sorts of beakers and potions laid out on wooden tables. Smoke and light emanate from the experiments. A large shelf holds jars of strange ingredients, and in the center of the room there is some sort of huge vat of brewing liquid, bubbling and steaming.
# Current_Connections: []
# Connections: [('Down', 'Alchemists bedroom'), ('Down', 'kitchens')]
# ###
#
# Category: Inside tower
# Setting: Tower
# Description: The inside tower is made from a combination of wood and brick. It also has some metal to hold all the doors in place. There are three doors and a staircase that leads up to the guards quarters.
# Current_Connections: [('Up', 'Guards quarters'), ('South', 'Front entrance')]
# Connections: [('Up', 'Guards quarters'), ('South', 'Front entrance')]
# ###
#
# Category: Inside tower
# Setting: Tower
# Description: The inside tower is made from a combination of wood and brick. It also has some metal to hold all the doors in place. There are three doors and a staircase that leads up to the guards quarters.
# Current_Connections: [('Up', 'Guards quarters')]
# Connections: [('Up', 'Guards quarters'), ('South', 'Front entrance')]
# ###
#
# Category: Inside tower
# Setting: Tower
# Description: The inside tower is made from a combination of wood and brick. It also has some metal to hold all the doors in place. There are three doors and a staircase that leads up to the guards quarters.
# Current_Connections: [('South', 'Front entrance')]
# Connections: [('Up', 'Guards quarters'), ('South', 'Front entrance')]
# ###
#
# Category: Inside tower
# Setting: Tower
# Description: The inside tower is made from a combination of wood and brick. It also has some metal to hold all the doors in place. There are three doors and a staircase that leads up to the guards quarters.
# Current_Connections: []
# Connections: [('Up', 'Guards quarters'), ('South', 'Front entrance')]
# ###
#
# Category: Inside tower
# Setting: Arsenal
# Description: Arsenal is a vast room of military equipment, it is made of stone, and there are shelves and table and organized things. Crossbows hang on the wall, and there is a sort of umbrella stand, but it's full of swords, and there is Armour in large bins accordion to size, and at one end is a row of trebuchets and even catapults, and torches and spears are in a big pile
# Current_Connections: [('Down', 'Dungeon'), ('South', 'Outside tower')]
# Connections: [('Down', 'Dungeon'), ('South', 'Outside tower')]
# ###
#
# Category: Inside tower
# Setting: Arsenal
# Description: Arsenal is a vast room of military equipment, it is made of stone, and there are shelves and table and organized things. Crossbows hang on the wall, and there is a sort of umbrella stand, but it's full of swords, and there is Armour in large bins accordion to size, and at one end is a row of trebuchets and even catapults, and torches and spears are in a big pile
# Current_Connections: [('Down', 'Dungeon')]
# Connections: [('Down', 'Dungeon'), ('South', 'Outside tower')]
# ###
#
# Category: Inside tower
# Setting: Arsenal
# Description: Arsenal is a vast room of military equipment, it is made of stone, and there are shelves and table and organized things. Crossbows hang on the wall, and there is a sort of umbrella stand, but it's full of swords, and there is Armour in large bins accordion to size, and at one end is a row of trebuchets and even catapults, and torches and spears are in a big pile
# Current_Connections: [('South', 'Outside tower')]
# Connections: [('Down', 'Dungeon'), ('South', 'Outside tower')]
# ###
#
# Category: Inside tower
# Setting: Arsenal
# Description: Arsenal is a vast room of military equipment, it is made of stone, and there are shelves and table and organized things. Crossbows hang on the wall, and there is a sort of umbrella stand, but it's full of swords, and there is Armour in large bins accordion to size, and at one end is a row of trebuchets and even catapults, and torches and spears are in a big pile
# Current_Connections: []
# Connections: [('Down', 'Dungeon'), ('South', 'Outside tower')]
# ###
#
# Category: Inside tower
# Setting: Tower kitchen
# Description: A large Stone oven is placed in the center by the wall at the end of the room, next to it are placed many baskets containing specific kinds of food, like eggs, bread, potatoes. On the left wall beside the oven is a big table with pans and pots hanging from the ceiling above it. Many rolling pins, knives and cutting boards are scattered around the table. On the right wall beside of the oven are standing sacks of flour above which are settled small jars of powers and liquids of all kinds, and closer to the door, right next to them are hanging aprons and protective caps of the cooks who work in that kitchen. The place is very clean, shiny almost.
# Current_Connections: []
# Connections: []
# ###
#
# Category: Inside tower
# Setting: Staircase
# Description: The staircase is spiral and made of stone. The stone is smooth and cold from years of friction. The staircase reaches multiple levels of the tower and is the only way up or down.
# Current_Connections: [('Down', 'Castle door'), ('East', 'Royal quarters')]
# Connections: [('Down', 'Castle door'), ('East', 'Royal quarters')]
# ###
#
# Category: Inside tower
# Setting: Staircase
# Description: The staircase is spiral and made of stone. The stone is smooth and cold from years of friction. The staircase reaches multiple levels of the tower and is the only way up or down.
# Current_Connections: [('Down', 'Castle door')]
# Connections: [('Down', 'Castle door'), ('East', 'Royal quarters')]
# ###
#
# Category: Inside tower
# Setting: Staircase
# Description: The staircase is spiral and made of stone. The stone is smooth and cold from years of friction. The staircase reaches multiple levels of the tower and is the only way up or down.
# Current_Connections: [('East', 'Royal quarters')]
# Connections: [('Down', 'Castle door'), ('East', 'Royal quarters')]
# ###
#
# Category: Inside tower
# Setting: Staircase
# Description: The staircase is spiral and made of stone. The stone is smooth and cold from years of friction. The staircase reaches multiple levels of the tower and is the only way up or down.
# Current_Connections: []
# Connections: [('Down', 'Castle door'), ('East', 'Royal quarters')]
# ###
#
# Category: Inside tower
# Setting: Keep
# Description: The keep is the most fortified part of the castle. Swords, bows and arrows, lances, and armor are housed here. From the stone windows you can see past the castle walls into the surrounding fields. This is the castle's last defense.
# Current_Connections: [('South', 'A spiral staircase')]
# Connections: [('South', 'A spiral staircase')]
# ###
#
# Category: Inside tower
# Setting: Keep
# Description: The keep is the most fortified part of the castle. Swords, bows and arrows, lances, and armor are housed here. From the stone windows you can see past the castle walls into the surrounding fields. This is the castle's last defense.
# Current_Connections: []
# Connections: [('South', 'A spiral staircase')]
# ###
#
# Category: Inside tower
# Setting: Sewer entrance
# Description: There is no treasure to be found here. All you see is filth. Dirty murky water and fumes rising from it burns your eyes. You see animals roaming around. Are they small dogs? No they are rodents, big rats. They glisten with the filth they are covered with. It is dark and difficult to see much else.
# Current_Connections: []
# Connections: []
# ###
#
# Category: Inside tower
# Setting: Rat den
# Description: The rat den is a disgusting, musty room deep inside the tower sewers. This is the area that the rats pull the bones of the treasure seekers, so they are able to get full access to all of the decomposing meat on the bones. Around the room are empty crates, that are broken and falling to pieces. Scattered glass litters the floor, broken ale bottles where some of the poor have tried to stay in the den, before the rat's had over taken it. There are torches on the wall, but dim now, as no soul wants to see the what the light would show. There are rat's nests in the corner, bits of straw, cloth and other odds and ends the rats have dug up.
# Current_Connections: [('Outside', 'Tower Sewers'), ('Outside', 'Tower Sewers')]
# Connections: [('Outside', 'Tower Sewers'), ('Outside', 'Tower Sewers')]
# ###
#
# Category: Inside tower
# Setting: Rat den
# Description: The rat den is a disgusting, musty room deep inside the tower sewers. This is the area that the rats pull the bones of the treasure seekers, so they are able to get full access to all of the decomposing meat on the bones. Around the room are empty crates, that are broken and falling to pieces. Scattered glass litters the floor, broken ale bottles where some of the poor have tried to stay in the den, before the rat's had over taken it. There are torches on the wall, but dim now, as no soul wants to see the what the light would show. There are rat's nests in the corner, bits of straw, cloth and other odds and ends the rats have dug up.
# Current_Connections: [('Outside', 'Tower Sewers')]
# Connections: [('Outside', 'Tower Sewers'), ('Outside', 'Tower Sewers')]
# ###
#
# Category: Inside tower
# Setting: Rat den
# Description: The rat den is a disgusting, musty room deep inside the tower sewers. This is the area that the rats pull the bones of the treasure seekers, so they are able to get full access to all of the decomposing meat on the bones. Around the room are empty crates, that are broken and falling to pieces. Scattered glass litters the floor, broken ale bottles where some of the poor have tried to stay in the den, before the rat's had over taken it. There are torches on the wall, but dim now, as no soul wants to see the what the light would show. There are rat's nests in the corner, bits of straw, cloth and other odds and ends the rats have dug up.
# Current_Connections: [('Outside', 'Tower Sewers')]
# Connections: [('Outside', 'Tower Sewers'), ('Outside', 'Tower Sewers')]
# ###
#
# Category: Inside tower
# Setting: Rat den
# Description: The rat den is a disgusting, musty room deep inside the tower sewers. This is the area that the rats pull the bones of the treasure seekers, so they are able to get full access to all of the decomposing meat on the bones. Around the room are empty crates, that are broken and falling to pieces. Scattered glass litters the floor, broken ale bottles where some of the poor have tried to stay in the den, before the rat's had over taken it. There are torches on the wall, but dim now, as no soul wants to see the what the light would show. There are rat's nests in the corner, bits of straw, cloth and other odds and ends the rats have dug up.
# Current_Connections: []
# Connections: [('Outside', 'Tower Sewers'), ('Outside', 'Tower Sewers')]
# ###
#
# Category: Inside tower
# Setting: Princess' chamber
# Description: This chamber is the bedroom of a princess who lives in the castle. The bedroom is very luxurious and ornate, with a soft bed piled in quilts and a nice warm fire place adorned with trinkets. On the floor there is a big rug with a beautiful design. On the wall, there is a tapestry depicting a romantic looking garden scene. There are some fresh flowers on a table near the bed. There is one big window framed with heavy drapes near the bed.
# Current_Connections: [('Down', 'Library'), ('West', "maid's quarters")]
# Connections: [('Down', 'Library'), ('West', "maid's quarters")]
# ###
#
# Category: Inside tower
# Setting: Princess' chamber
# Description: This chamber is the bedroom of a princess who lives in the castle. The bedroom is very luxurious and ornate, with a soft bed piled in quilts and a nice warm fire place adorned with trinkets. On the floor there is a big rug with a beautiful design. On the wall, there is a tapestry depicting a romantic looking garden scene. There are some fresh flowers on a table near the bed. There is one big window framed with heavy drapes near the bed.
# Current_Connections: [('Down', 'Library')]
# Connections: [('Down', 'Library'), ('West', "maid's quarters")]
# ###
#
# Category: Inside tower
# Setting: Princess' chamber
# Description: This chamber is the bedroom of a princess who lives in the castle. The bedroom is very luxurious and ornate, with a soft bed piled in quilts and a nice warm fire place adorned with trinkets. On the floor there is a big rug with a beautiful design. On the wall, there is a tapestry depicting a romantic looking garden scene. There are some fresh flowers on a table near the bed. There is one big window framed with heavy drapes near the bed.
# Current_Connections: [('West', "maid's quarters")]
# Connections: [('Down', 'Library'), ('West', "maid's quarters")]
# ###
#
# Category: Inside tower
# Setting: Princess' chamber
# ...
# Current_Connections: [('west', "The fisherman's stand")]
# Connections: [('east', 'The front entrance room'), ('west', "The fisherman's stand")]
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater marketplace
# Description: The marketplace is the main hub for the residents of the aquapolis. With high ceilings and bright, colorful flags at each market stand, the place seems to stretch on forever. Near the entrance, there is a young boy attempting to sell the latest news of the kingdom.
# Current_Connections: []
# Connections: [('east', 'The front entrance room'), ('west', "The fisherman's stand")]
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater aquapolis
# Description: The underwater aquapolis is a massive and ornate city at the bottom of the ocean. The walls of the buildings are made or coral, pearl, and seashells. Schools of fish swim in and out of the circular holes in the walls that act as windows. The aquapolis is illuminated by florescent rocks and shells that line every building.
# Current_Connections: [('up', 'Above water basking caves'), ('east', 'Underwater park')]
# Connections: [('up', 'Above water basking caves'), ('east', 'Underwater park')]
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater aquapolis
# Description: The underwater aquapolis is a massive and ornate city at the bottom of the ocean. The walls of the buildings are made or coral, pearl, and seashells. Schools of fish swim in and out of the circular holes in the walls that act as windows. The aquapolis is illuminated by florescent rocks and shells that line every building.
# Current_Connections: [('up', 'Above water basking caves')]
# Connections: [('up', 'Above water basking caves'), ('east', 'Underwater park')]
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater aquapolis
# Description: The underwater aquapolis is a massive and ornate city at the bottom of the ocean. The walls of the buildings are made or coral, pearl, and seashells. Schools of fish swim in and out of the circular holes in the walls that act as windows. The aquapolis is illuminated by florescent rocks and shells that line every building.
# Current_Connections: [('east', 'Underwater park')]
# Connections: [('up', 'Above water basking caves'), ('east', 'Underwater park')]
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater aquapolis
# Description: The underwater aquapolis is a massive and ornate city at the bottom of the ocean. The walls of the buildings are made or coral, pearl, and seashells. Schools of fish swim in and out of the circular holes in the walls that act as windows. The aquapolis is illuminated by florescent rocks and shells that line every building.
# Current_Connections: []
# Connections: [('up', 'Above water basking caves'), ('east', 'Underwater park')]
# ###
#
# Category: Underwater aquapolis
# Setting: Dry dock room
# Description: The room is located on the border wall of the aquapolis. There is one on the far north and far south side.
# Current_Connections: [('north', 'Walk down the maintence hall and it is the last door on the right.'), ('east', 'Storage closet')]
# Connections: [('north', 'Walk down the maintence hall and it is the last door on the right.'), ('east', 'Storage closet')]
# ###
#
# Category: Underwater aquapolis
# Setting: Dry dock room
# Description: The room is located on the border wall of the aquapolis. There is one on the far north and far south side.
# Current_Connections: [('north', 'Walk down the maintence hall and it is the last door on the right.')]
# Connections: [('north', 'Walk down the maintence hall and it is the last door on the right.'), ('east', 'Storage closet')]
# ###
#
# Category: Underwater aquapolis
# Setting: Dry dock room
# Description: The room is located on the border wall of the aquapolis. There is one on the far north and far south side.
# Current_Connections: [('east', 'Storage closet')]
# Connections: [('north', 'Walk down the maintence hall and it is the last door on the right.'), ('east', 'Storage closet')]
# ###
#
# Category: Underwater aquapolis
# Setting: Dry dock room
# Description: The room is located on the border wall of the aquapolis. There is one on the far north and far south side.
# Current_Connections: []
# Connections: [('north', 'Walk down the maintence hall and it is the last door on the right.'), ('east', 'Storage closet')]
# ###
#
# Category: Underwater aquapolis
# Setting: Neptune's throne room
# Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# Current_Connections: [('outside', 'Courtyard'), ('up', "King's throne room")]
# Connections: [('outside', 'Courtyard'), ('up', "King's throne room")]
# ###
#
# Category: Underwater aquapolis
# Setting: Neptune's throne room
# Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# Current_Connections: [('outside', 'Courtyard')]
# Connections: [('outside', 'Courtyard'), ('up', "King's throne room")]
# ###
#
# Category: Underwater aquapolis
# Setting: Neptune's throne room
# Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# Current_Connections: [('up', "King's throne room")]
# Connections: [('outside', 'Courtyard'), ('up', "King's throne room")]
# ###
#
# Category: Underwater aquapolis
# Setting: Neptune's throne room
# Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# Current_Connections: []
# Connections: [('outside', 'Courtyard'), ('up', "King's throne room")]
# ###
#
# Category: Underwater aquapolis
# Setting: The lords treasury
# Description: Deep inside the volcanic cave that is the foundation of the aquapolis lies the treasury.  Some believe its existence is a myth, but others claim they have been there.  Those that claim they have seen it say you must dive out of the aquapolis' basement while holding your breath, through the cold deep water that is filled with deadly volcanic gas.  The treasury room itself is a dry cave filled with riches from the very infancy of the empire
# Current_Connections: [('north', 'The aquapolis subbasement'), ('west', 'The lords private chambers')]
# Connections: [('north', 'The aquapolis subbasement'), ('west', 'The lords private chambers')]
# ###
#
# Category: Underwater aquapolis
# Setting: The lords treasury
# Description: Deep inside the volcanic cave that is the foundation of the aquapolis lies the treasury.  Some believe its existence is a myth, but others claim they have been there.  Those that claim they have seen it say you must dive out of the aquapolis' basement while holding your breath, through the cold deep water that is filled with deadly volcanic gas.  The treasury room itself is a dry cave filled with riches from the very infancy of the empire
# Current_Connections: [('north', 'The aquapolis subbasement')]
# Connections: [('north', 'The aquapolis subbasement'), ('west', 'The lords private chambers')]
# ###
#
# Category: Underwater aquapolis
# Setting: The lords treasury
# Description: Deep inside the volcanic cave that is the foundation of the aquapolis lies the treasury.  Some believe its existence is a myth, but others claim they have been there.  Those that claim they have seen it say you must dive out of the aquapolis' basement while holding your breath, through the cold deep water that is filled with deadly volcanic gas.  The treasury room itself is a dry cave filled with riches from the very infancy of the empire
# Current_Connections: [('west', 'The lords private chambers')]
# Connections: [('north', 'The aquapolis subbasement'), ('west', 'The lords private chambers')]
# ###
#
# Category: Underwater aquapolis
# Setting: The lords treasury
# Description: Deep inside the volcanic cave that is the foundation of the aquapolis lies the treasury.  Some believe its existence is a myth, but others claim they have been there.  Those that claim they have seen it say you must dive out of the aquapolis' basement while holding your breath, through the cold deep water that is filled with deadly volcanic gas.  The treasury room itself is a dry cave filled with riches from the very infancy of the empire
# Current_Connections: []
# Connections: [('north', 'The aquapolis subbasement'), ('west', 'The lords private chambers')]
# ###
#
# Category: Underwater aquapolis
# Setting: Geothermal valley
# Description: Deep and warm the geothermal valley boasts a reviving epicenter for all to migrate to. The warm bursts of heat send bubble around the perimeter of the valley reflecting colors of green and blue.
# Current_Connections: [('inside', 'command center'), ('down', 'Underwater trenches')]
# Connections: [('inside', 'command center'), ('down', 'Underwater trenches')]
# ###
#
# Category: Underwater aquapolis
# Setting: Geothermal valley
# Description: Deep and warm the geothermal valley boasts a reviving epicenter for all to migrate to. The warm bursts of heat send bubble around the perimeter of the valley reflecting colors of green and blue.
# Current_Connections: [('inside', 'command center')]
# Connections: [('inside', 'command center'), ('down', 'Underwater trenches')]
# ###
#
# Category: Underwater aquapolis
# Setting: Geothermal valley
# Description: Deep and warm the geothermal valley boasts a reviving epicenter for all to migrate to. The warm bursts of heat send bubble around the perimeter of the valley reflecting colors of green and blue.
# Current_Connections: [('down', 'Underwater trenches')]
# Connections: [('inside', 'command center'), ('down', 'Underwater trenches')]
# ###
#
# Category: Underwater aquapolis
# Setting: Geothermal valley
# Description: Deep and warm the geothermal valley boasts a reviving epicenter for all to migrate to. The warm bursts of heat send bubble around the perimeter of the valley reflecting colors of green and blue.
# Current_Connections: []
# Connections: [('inside', 'command center'), ('down', 'Underwater trenches')]
# ###
#
# Category: Underwater aquapolis
# Setting: The marketplace
# Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# Current_Connections: [('east', 'Deep Crevasse'), ('up', 'The Ministry of Surface Affairs')]
# Connections: [('east', 'Deep Crevasse'), ('up', 'The Ministry of Surface Affairs')]
# ###
#
# Category: Underwater aquapolis
# Setting: The marketplace
# Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# Current_Connections: [('east', 'Deep Crevasse')]
# Connections: [('east', 'Deep Crevasse'), ('up', 'The Ministry of Surface Affairs')]
# ###
#
# Category: Underwater aquapolis
# Setting: The marketplace
# Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# Current_Connections: [('up', 'The Ministry of Surface Affairs')]
# Connections: [('east', 'Deep Crevasse'), ('up', 'The Ministry of Surface Affairs')]
# ###
#
# Category: Underwater aquapolis
# Setting: The marketplace
# Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# Current_Connections: []
# Connections: [('east', 'Deep Crevasse'), ('up', 'The Ministry of Surface Affairs')]
# ###
#
# Category: Underwater aquapolis
# Setting: Farmhouse
# Description: a small house on a seaweed plantation, small and rustic, really only the single room with a closet, maybe, a table and some chairs
# Current_Connections: [('inside', 'closet'), ('outside', 'storage barn')]
# Connections: [('inside', 'closet'), ('outside', 'storage barn')]
# ###
#
# Category: Underwater aquapolis
# Setting: Farmhouse
# Description: a small house on a seaweed plantation, small and rustic, really only the single room with a closet, maybe, a table and some chairs
# Current_Connections: [('inside', 'closet')]
# Connections: [('inside', 'closet'), ('outside', 'storage barn')]
# ###
#
# Category: Underwater aquapolis
# Setting: Farmhouse
# Description: a small house on a seaweed plantation, small and rustic, really only the single room with a closet, maybe, a table and some chairs
# Current_Connections: [('outside', 'storage barn')]
# Connections: [('inside', 'closet'), ('outside', 'storage barn')]
# ###
#
# Category: Underwater aquapolis
# Setting: Farmhouse
# Description: a small house on a seaweed plantation, small and rustic, really only the single room with a closet, maybe, a table and some chairs
# Current_Connections: []
# Connections: [('inside', 'closet'), ('outside', 'storage barn')]
# ###
#
# Category: Underwater aquapolis
# Setting: Tool shed
# Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Current_Connections: [('east', 'farmhouse'), ('south', 'sea barn')]
# Connections: [('east', 'farmhouse'), ('south', 'sea barn')]
# ###
#
# Category: Underwater aquapolis
# Setting: Tool shed
# Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Current_Connections: [('east', 'farmhouse')]
# Connections: [('east', 'farmhouse'), ('south', 'sea barn')]
# ###
#
# Category: Underwater aquapolis
# Setting: Tool shed
# Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Current_Connections: [('south', 'sea barn')]
# Connections: [('east', 'farmhouse'), ('south', 'sea barn')]
# ###
#
# Category: Underwater aquapolis
# Setting: Tool shed
# Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Current_Connections: []
# Connections: [('east', 'farmhouse'), ('south', 'sea barn')]
# ###

# %%
# !head fine_tuning_location_connections.jsonl
# Out:
# {"prompt": "Category: Forest\nSetting: Mysterious forest outskirts\nDescription: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.\nCurrent_Connections: [('East', \"Hunters' cabins\"), ('Inside', 'Mythical dragon castle'), ('Outside', 'castle entrance')]\n", "completion": "Connections: [('East', \"Hunters' cabins\"), ('Inside', 'Mythical dragon castle'), ('Outside', 'castle entrance')]\n###\n"}
# {"prompt": "Category: Forest\nSetting: Mysterious forest outskirts\nDescription: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.\nCurrent_Connections: [('East', \"Hunters' cabins\"), ('Inside', 'Mythical dragon castle')]\n", "completion": "Connections: [('East', \"Hunters' cabins\"), ('Inside', 'Mythical dragon castle'), ('Outside', 'castle entrance')]\n###\n"}
# {"prompt": "Category: Forest\nSetting: Mysterious forest outskirts\nDescription: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.\nCurrent_Connections: [('East', \"Hunters' cabins\"), ('Outside', 'castle entrance')]\n", "completion": "Connections: [('East', \"Hunters' cabins\"), ('Inside', 'Mythical dragon castle'), ('Outside', 'castle entrance')]\n###\n"}
# {"prompt": "Category: Forest\nSetting: Mysterious forest outskirts\nDescription: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.\nCurrent_Connections: [('East', \"Hunters' cabins\")]\n", "completion": "Connections: [('East', \"Hunters' cabins\"), ('Inside', 'Mythical dragon castle'), ('Outside', 'castle entrance')]\n###\n"}
# {"prompt": "Category: Forest\nSetting: Mysterious forest outskirts\nDescription: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.\nCurrent_Connections: [('Inside', 'Mythical dragon castle'), ('Outside', 'castle entrance')]\n", "completion": "Connections: [('East', \"Hunters' cabins\"), ('Inside', 'Mythical dragon castle'), ('Outside', 'castle entrance')]\n###\n"}
# {"prompt": "Category: Forest\nSetting: Mysterious forest outskirts\nDescription: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.\nCurrent_Connections: [('Inside', 'Mythical dragon castle')]\n", "completion": "Connections: [('East', \"Hunters' cabins\"), ('Inside', 'Mythical dragon castle'), ('Outside', 'castle entrance')]\n###\n"}
# {"prompt": "Category: Forest\nSetting: Mysterious forest outskirts\nDescription: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.\nCurrent_Connections: [('Outside', 'castle entrance')]\n", "completion": "Connections: [('East', \"Hunters' cabins\"), ('Inside', 'Mythical dragon castle'), ('Outside', 'castle entrance')]\n###\n"}
# {"prompt": "Category: Forest\nSetting: Mysterious forest outskirts\nDescription: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.\nCurrent_Connections: []\n", "completion": "Connections: [('East', \"Hunters' cabins\"), ('Inside', 'Mythical dragon castle'), ('Outside', 'castle entrance')]\n###\n"}
# {"prompt": "Category: Forest\nSetting: Flower garden\nDescription: This clearing is in reveal a wide circle of trees. Proud oaks stand close enough that only the smallest of fauna can squeeze through, protecting the garden within from curious deer and hungry rabbits. Flowers of every hue and shade crowd the soft lawn of grass, soaking up what light they can through the shadows cast by the branches above. Purple, yellow, red, blue - even green blossoms bob in the breeze, their scents mixing to create a heady perfume. Vines and creepers climb up the tree trunks, dripping with grapes and berries.\nCurrent_Connections: [('North', 'The Brush Den')]\n", "completion": "Connections: [('North', 'The Brush Den')]\n###\n"}
# {"prompt": "Category: Forest\nSetting: Flower garden\nDescription: This clearing is in reveal a wide circle of trees. Proud oaks stand close enough that only the smallest of fauna can squeeze through, protecting the garden within from curious deer and hungry rabbits. Flowers of every hue and shade crowd the soft lawn of grass, soaking up what light they can through the shadows cast by the branches above. Purple, yellow, red, blue - even green blossoms bob in the breeze, their scents mixing to create a heady perfume. Vines and creepers climb up the tree trunks, dripping with grapes and berries.\nCurrent_Connections: []\n", "completion": "Connections: [('North', 'The Brush Den')]\n###\n"}

# %%
# !openai api fine_tunes.create -t fine_tuning_location_connections.jsonl -m curie
# Out:
# Upload progress: 100% 982k/982k [00:00<00:00, 1.23Git/s]
# Uploaded file from fine_tuning_location_connections.jsonl: file-5QmZ486f8rOFcMUKpUAsgQrb
# Created fine-tune: ft-Wh2fqxmljuNDBigyORpQ7AWP
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2022-01-29 23:09:43] Created fine-tune: ft-Wh2fqxmljuNDBigyORpQ7AWP
# [2022-01-29 23:09:54] Fine-tune costs $2.67
# [2022-01-29 23:09:54] Fine-tune enqueued. Queue number: 0
# [2022-01-29 23:09:59] Fine-tune started
#
# Stream interrupted (client disconnected).
# To resume the stream, run:
#
#   openai api fine_tunes.follow -i ft-Wh2fqxmljuNDBigyORpQ7AWP

# %%
# !openai api fine_tunes.follow -i ft-Wh2fqxmljuNDBigyORpQ7AWP
# Out:
# [2022-01-29 23:09:43] Created fine-tune: ft-Wh2fqxmljuNDBigyORpQ7AWP
# [2022-01-29 23:09:54] Fine-tune costs $2.67
# [2022-01-29 23:09:54] Fine-tune enqueued. Queue number: 0
# [2022-01-29 23:09:59] Fine-tune started
# [2022-01-29 23:21:29] Completed epoch 1/4
# [2022-01-29 23:46:37] Completed epoch 3/4
# [2022-01-29 23:57:24] Completed epoch 4/4
# [2022-01-29 23:57:55] Uploaded model: curie:ft-cis-700-31-2022-01-29-23-57-53
# [2022-01-29 23:57:59] Uploaded result file: file-IrVQrBxle5O2FLoE7k3KoUnb
# [2022-01-29 23:57:59] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m curie:ft-cis-700-31-2022-01-29-23-57-53 -p <YOUR_PROMPT>

# %%
def get_connections(category, location_name, location_description, finetuned_model, current_connections=[]):
  response = openai.Completion.create(
      model=finetuned_model,
      prompt="Category: {category}\nLocation: {location}\nDescription: {description}\nCurrent_Connections: {cconnections}\nConnections:".format(
          category=category.capitalize(),
          location=location_name.capitalize(),
          description=location_description.capitalize(),
          cconnections=current_connections.capitalize()
      ),
      temperature=0.7,
      max_tokens=64,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0,
      stop=["###"]
      )
  string_result=response['choices'][0]['text'].replace("[","").replace("]","").strip()
  array=string_result.split("), (")
  result=[]
  for item in array:
    item=item.replace("(","").replace(")","").replace("'","")
    parts=item.split(", ")
    if len(parts)!=2:
      continue
    to_append=(parts[0],parts[1])
    result.append(to_append)
  return result

# Replace with your model's name
finetuned_model = "curie:ft-cis-700-31-2022-01-29-23-57-53"
category = "Underwater aquapolis"
location_name = "Neptune's throne room"
location_description = "A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves."
current_connections = "[('east', 'Underwater park')]"

connections = get_connections(category, location_name, location_description, finetuned_model, current_connections)
print(connections)
# Out:
# [('outside', 'Courtyard'), ('east', 'underwater park')]

# %%
# get property of one item
def get_property(item_name, item_description, property_description, property_score):
  """
  This generates a prompt and a completion which can be used to fine-tune OpenAI.
  This version just gnnerates 
  """
  prompt = ""
  completion = ""
  prompt += "Item: {item_name}\n".format(item_name=item_name)
  prompt += "Item_Description: {item_description}\n".format(item_description=item_description)
  prompt += "Property_Description: {property_description}\n".format(property_description=property_description)
  completion += "True_Or_False: {score}\n".format(score=property_score)
  completion += "###\n"

  return prompt, completion


def create_item_property_finetuning_data(filename='fine_tuning_single_item_property.jsonl'):
  fine_tuning_data = []
  for item_id in light_environment["objects"].keys():
    for property_description in ["is_container", "is_drink", "is_food", "is_gettable", "is_surface", "is_weapon", "is_wearable"]:
      data = {}
      item=light_environment["objects"][item_id]
      item_name=item["name"]
      item_description=item["descriptions"]
      property_score=item[property_description]
      prompt, completion = get_property(item_name, item_description, property_description, property_score)
      data['prompt'] = prompt
      data['completion'] = completion
      print(prompt, end="")
      print(completion)
      fine_tuning_data.append(data)

  with open(filename, 'w') as out:
    for data in fine_tuning_data:
        out.write(json.dumps(data))
        out.write('\n')

create_item_property_finetuning_data()
# Out:
# Streaming output truncated to the last 5000 lines.
# ###
#
# Item: vase
# Item_Description: ['The vase looks like a mosaic covered in emeralds and rubies.']
# Property_Description: is_container
# True_Or_False: 1.0
# ###
#
# Item: vase
# Item_Description: ['The vase looks like a mosaic covered in emeralds and rubies.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: vase
# Item_Description: ['The vase looks like a mosaic covered in emeralds and rubies.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: vase
# Item_Description: ['The vase looks like a mosaic covered in emeralds and rubies.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: vase
# Item_Description: ['The vase looks like a mosaic covered in emeralds and rubies.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: vase
# Item_Description: ['The vase looks like a mosaic covered in emeralds and rubies.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: vase
# Item_Description: ['The vase looks like a mosaic covered in emeralds and rubies.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: bucket
# Item_Description: ['The bucket is dulled over and silver.']
# Property_Description: is_container
# True_Or_False: 1.0
# ###
#
# Item: bucket
# Item_Description: ['The bucket is dulled over and silver.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: bucket
# Item_Description: ['The bucket is dulled over and silver.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: bucket
# Item_Description: ['The bucket is dulled over and silver.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: bucket
# Item_Description: ['The bucket is dulled over and silver.']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: bucket
# Item_Description: ['The bucket is dulled over and silver.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: bucket
# Item_Description: ['The bucket is dulled over and silver.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: candles
# Item_Description: ['The room was aglow from candles on the table. Each candle dripped white wax.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: candles
# Item_Description: ['The room was aglow from candles on the table. Each candle dripped white wax.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: candles
# Item_Description: ['The room was aglow from candles on the table. Each candle dripped white wax.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: candles
# Item_Description: ['The room was aglow from candles on the table. Each candle dripped white wax.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: candles
# Item_Description: ['The room was aglow from candles on the table. Each candle dripped white wax.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: candles
# Item_Description: ['The room was aglow from candles on the table. Each candle dripped white wax.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: candles
# Item_Description: ['The room was aglow from candles on the table. Each candle dripped white wax.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: seeds
# Item_Description: ['The tiny seed is almost a reddish brown and perfectly round in shape, almost as if man made.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: seeds
# Item_Description: ['The tiny seed is almost a reddish brown and perfectly round in shape, almost as if man made.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: seeds
# Item_Description: ['The tiny seed is almost a reddish brown and perfectly round in shape, almost as if man made.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: seeds
# Item_Description: ['The tiny seed is almost a reddish brown and perfectly round in shape, almost as if man made.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: seeds
# Item_Description: ['The tiny seed is almost a reddish brown and perfectly round in shape, almost as if man made.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: seeds
# Item_Description: ['The tiny seed is almost a reddish brown and perfectly round in shape, almost as if man made.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: seeds
# Item_Description: ['The tiny seed is almost a reddish brown and perfectly round in shape, almost as if man made.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: rusted helmet
# Item_Description: ['The helmet is old and silver with bouts of red rust along it.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: rusted helmet
# Item_Description: ['The helmet is old and silver with bouts of red rust along it.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: rusted helmet
# Item_Description: ['The helmet is old and silver with bouts of red rust along it.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: rusted helmet
# Item_Description: ['The helmet is old and silver with bouts of red rust along it.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: rusted helmet
# Item_Description: ['The helmet is old and silver with bouts of red rust along it.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: rusted helmet
# Item_Description: ['The helmet is old and silver with bouts of red rust along it.']
# Property_Description: is_weapon
# True_Or_False: 1.0
# ###
#
# Item: rusted helmet
# Item_Description: ['The helmet is old and silver with bouts of red rust along it.']
# Property_Description: is_wearable
# True_Or_False: 1.0
# ###
#
# Item: dozens of telescopes
# Item_Description: ['The dozens of telescopes piled up formed a mountain of sorts.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: dozens of telescopes
# Item_Description: ['The dozens of telescopes piled up formed a mountain of sorts.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: dozens of telescopes
# Item_Description: ['The dozens of telescopes piled up formed a mountain of sorts.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: dozens of telescopes
# Item_Description: ['The dozens of telescopes piled up formed a mountain of sorts.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: dozens of telescopes
# Item_Description: ['The dozens of telescopes piled up formed a mountain of sorts.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: dozens of telescopes
# Item_Description: ['The dozens of telescopes piled up formed a mountain of sorts.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: dozens of telescopes
# Item_Description: ['The dozens of telescopes piled up formed a mountain of sorts.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: water
# Item_Description: ["The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven."]
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: water
# Item_Description: ["The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven."]
# Property_Description: is_drink
# True_Or_False: 1.0
# ###
#
# Item: water
# Item_Description: ["The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven."]
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: water
# Item_Description: ["The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven."]
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: water
# Item_Description: ["The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven."]
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: water
# Item_Description: ["The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven."]
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: water
# Item_Description: ["The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven."]
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: decorative shells
# Item_Description: ['The shell looks clean and delicate.  It looks like it has been washed.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: decorative shells
# Item_Description: ['The shell looks clean and delicate.  It looks like it has been washed.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: decorative shells
# Item_Description: ['The shell looks clean and delicate.  It looks like it has been washed.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: decorative shells
# Item_Description: ['The shell looks clean and delicate.  It looks like it has been washed.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: decorative shells
# Item_Description: ['The shell looks clean and delicate.  It looks like it has been washed.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: decorative shells
# Item_Description: ['The shell looks clean and delicate.  It looks like it has been washed.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: decorative shells
# Item_Description: ['The shell looks clean and delicate.  It looks like it has been washed.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: crests
# Item_Description: ['The crest displays a red shield surrounded by many green and yellow flourishes along with a black cat arched in the center.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: crests
# Item_Description: ['The crest displays a red shield surrounded by many green and yellow flourishes along with a black cat arched in the center.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: crests
# Item_Description: ['The crest displays a red shield surrounded by many green and yellow flourishes along with a black cat arched in the center.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: crests
# Item_Description: ['The crest displays a red shield surrounded by many green and yellow flourishes along with a black cat arched in the center.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: crests
# Item_Description: ['The crest displays a red shield surrounded by many green and yellow flourishes along with a black cat arched in the center.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: crests
# Item_Description: ['The crest displays a red shield surrounded by many green and yellow flourishes along with a black cat arched in the center.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: crests
# Item_Description: ['The crest displays a red shield surrounded by many green and yellow flourishes along with a black cat arched in the center.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: green grass
# Item_Description: ['You observe that the grass is tall and hard to wade through.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: green grass
# Item_Description: ['You observe that the grass is tall and hard to wade through.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: green grass
# Item_Description: ['You observe that the grass is tall and hard to wade through.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: green grass
# Item_Description: ['You observe that the grass is tall and hard to wade through.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: green grass
# Item_Description: ['You observe that the grass is tall and hard to wade through.']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: green grass
# Item_Description: ['You observe that the grass is tall and hard to wade through.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: green grass
# Item_Description: ['You observe that the grass is tall and hard to wade through.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: meals
# Item_Description: ['A warm and savory meal which fills the air with delicious aroma.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: meals
# Item_Description: ['A warm and savory meal which fills the air with delicious aroma.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: meals
# Item_Description: ['A warm and savory meal which fills the air with delicious aroma.']
# Property_Description: is_food
# True_Or_False: 1.0
# ###
#
# Item: meals
# Item_Description: ['A warm and savory meal which fills the air with delicious aroma.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: meals
# Item_Description: ['A warm and savory meal which fills the air with delicious aroma.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: meals
# Item_Description: ['A warm and savory meal which fills the air with delicious aroma.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: meals
# Item_Description: ['A warm and savory meal which fills the air with delicious aroma.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: wand
# Item_Description: ['A wand appeared and with it, a very dark feeling. A feeling of dark magic.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: wand
# Item_Description: ['A wand appeared and with it, a very dark feeling. A feeling of dark magic.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: wand
# Item_Description: ['A wand appeared and with it, a very dark feeling. A feeling of dark magic.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: wand
# Item_Description: ['A wand appeared and with it, a very dark feeling. A feeling of dark magic.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: wand
# Item_Description: ['A wand appeared and with it, a very dark feeling. A feeling of dark magic.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: wand
# Item_Description: ['A wand appeared and with it, a very dark feeling. A feeling of dark magic.']
# Property_Description: is_weapon
# True_Or_False: 1.0
# ###
#
# Item: wand
# Item_Description: ['A wand appeared and with it, a very dark feeling. A feeling of dark magic.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: some illustrations in a book
# Item_Description: ['The illustration on this page does not seem suitable for children.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: some illustrations in a book
# Item_Description: ['The illustration on this page does not seem suitable for children.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: some illustrations in a book
# Item_Description: ['The illustration on this page does not seem suitable for children.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: some illustrations in a book
# Item_Description: ['The illustration on this page does not seem suitable for children.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: some illustrations in a book
# Item_Description: ['The illustration on this page does not seem suitable for children.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: some illustrations in a book
# Item_Description: ['The illustration on this page does not seem suitable for children.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: some illustrations in a book
# Item_Description: ['The illustration on this page does not seem suitable for children.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: abode
# Item_Description: ['A humble and rustic hut with a rounded roof. Simple and only the single room within.']
# Property_Description: is_container
# True_Or_False: 1.0
# ###
#
# Item: abode
# Item_Description: ['A humble and rustic hut with a rounded roof. Simple and only the single room within.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: abode
# Item_Description: ['A humble and rustic hut with a rounded roof. Simple and only the single room within.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: abode
# Item_Description: ['A humble and rustic hut with a rounded roof. Simple and only the single room within.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: abode
# Item_Description: ['A humble and rustic hut with a rounded roof. Simple and only the single room within.']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: abode
# Item_Description: ['A humble and rustic hut with a rounded roof. Simple and only the single room within.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: abode
# Item_Description: ['A humble and rustic hut with a rounded roof. Simple and only the single room within.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: branches
# Item_Description: ['The branch is really sharp and could probably be used as a spear']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: branches
# Item_Description: ['The branch is really sharp and could probably be used as a spear']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: branches
# Item_Description: ['The branch is really sharp and could probably be used as a spear']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: branches
# Item_Description: ['The branch is really sharp and could probably be used as a spear']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: branches
# Item_Description: ['The branch is really sharp and could probably be used as a spear']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: branches
# Item_Description: ['The branch is really sharp and could probably be used as a spear']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: branches
# Item_Description: ['The branch is really sharp and could probably be used as a spear']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: gray stones
# Item_Description: ["A hard grey stone, you wouldn't think much of it due to how ordinary it is."]
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: gray stones
# Item_Description: ["A hard grey stone, you wouldn't think much of it due to how ordinary it is."]
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: gray stones
# Item_Description: ["A hard grey stone, you wouldn't think much of it due to how ordinary it is."]
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: gray stones
# Item_Description: ["A hard grey stone, you wouldn't think much of it due to how ordinary it is."]
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: gray stones
# Item_Description: ["A hard grey stone, you wouldn't think much of it due to how ordinary it is."]
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: gray stones
# Item_Description: ["A hard grey stone, you wouldn't think much of it due to how ordinary it is."]
# Property_Description: is_weapon
# True_Or_False: 1.0
# ###
#
# Item: gray stones
# Item_Description: ["A hard grey stone, you wouldn't think much of it due to how ordinary it is."]
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: jewels
# Item_Description: ['the jewels are usually expensive, a precious stone, typically a single crystal or piece of a hard lustrous or translucent mineral cut into shape with flat facets or smoothed and polished for use as an ornament.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: jewels
# Item_Description: ['the jewels are usually expensive, a precious stone, typically a single crystal or piece of a hard lustrous or translucent mineral cut into shape with flat facets or smoothed and polished for use as an ornament.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: jewels
# Item_Description: ['the jewels are usually expensive, a precious stone, typically a single crystal or piece of a hard lustrous or translucent mineral cut into shape with flat facets or smoothed and polished for use as an ornament.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: jewels
# Item_Description: ['the jewels are usually expensive, a precious stone, typically a single crystal or piece of a hard lustrous or translucent mineral cut into shape with flat facets or smoothed and polished for use as an ornament.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: jewels
# Item_Description: ['the jewels are usually expensive, a precious stone, typically a single crystal or piece of a hard lustrous or translucent mineral cut into shape with flat facets or smoothed and polished for use as an ornament.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: jewels
# Item_Description: ['the jewels are usually expensive, a precious stone, typically a single crystal or piece of a hard lustrous or translucent mineral cut into shape with flat facets or smoothed and polished for use as an ornament.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: jewels
# Item_Description: ['the jewels are usually expensive, a precious stone, typically a single crystal or piece of a hard lustrous or translucent mineral cut into shape with flat facets or smoothed and polished for use as an ornament.']
# Property_Description: is_wearable
# True_Or_False: 1.0
# ###
#
# Item: sand
# Item_Description: ['The sand is scratchy, and piled in heaps.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: sand
# Item_Description: ['The sand is scratchy, and piled in heaps.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: sand
# Item_Description: ['The sand is scratchy, and piled in heaps.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: sand
# Item_Description: ['The sand is scratchy, and piled in heaps.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: sand
# Item_Description: ['The sand is scratchy, and piled in heaps.']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: sand
# Item_Description: ['The sand is scratchy, and piled in heaps.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: sand
# Item_Description: ['The sand is scratchy, and piled in heaps.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: fireplace
# Item_Description: ['The fireplace was large but simple, it looked like it could fit in any home, it has a tasteful but simple mantle with a large picture hanging over it.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: fireplace
# Item_Description: ['The fireplace was large but simple, it looked like it could fit in any home, it has a tasteful but simple mantle with a large picture hanging over it.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: fireplace
# Item_Description: ['The fireplace was large but simple, it looked like it could fit in any home, it has a tasteful but simple mantle with a large picture hanging over it.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: fireplace
# Item_Description: ['The fireplace was large but simple, it looked like it could fit in any home, it has a tasteful but simple mantle with a large picture hanging over it.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: fireplace
# Item_Description: ['The fireplace was large but simple, it looked like it could fit in any home, it has a tasteful but simple mantle with a large picture hanging over it.']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: fireplace
# Item_Description: ['The fireplace was large but simple, it looked like it could fit in any home, it has a tasteful but simple mantle with a large picture hanging over it.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: fireplace
# Item_Description: ['The fireplace was large but simple, it looked like it could fit in any home, it has a tasteful but simple mantle with a large picture hanging over it.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: teeth
# Item_Description: ["These are some pearly white teeth. You're pretty sure they should be in a mouth, and the fact that they aren't is a little unnerving."]
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: teeth
# Item_Description: ["These are some pearly white teeth. You're pretty sure they should be in a mouth, and the fact that they aren't is a little unnerving."]
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: teeth
# Item_Description: ["These are some pearly white teeth. You're pretty sure they should be in a mouth, and the fact that they aren't is a little unnerving."]
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: teeth
# Item_Description: ["These are some pearly white teeth. You're pretty sure they should be in a mouth, and the fact that they aren't is a little unnerving."]
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: teeth
# Item_Description: ["These are some pearly white teeth. You're pretty sure they should be in a mouth, and the fact that they aren't is a little unnerving."]
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: teeth
# Item_Description: ["These are some pearly white teeth. You're pretty sure they should be in a mouth, and the fact that they aren't is a little unnerving."]
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: teeth
# Item_Description: ["These are some pearly white teeth. You're pretty sure they should be in a mouth, and the fact that they aren't is a little unnerving."]
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: flame
# Item_Description: ['The flame glistens a vibrant red.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: flame
# Item_Description: ['The flame glistens a vibrant red.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: flame
# Item_Description: ['The flame glistens a vibrant red.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: flame
# Item_Description: ['The flame glistens a vibrant red.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: flame
# Item_Description: ['The flame glistens a vibrant red.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: flame
# Item_Description: ['The flame glistens a vibrant red.']
# Property_Description: is_weapon
# True_Or_False: 1.0
# ###
#
# Item: flame
# Item_Description: ['The flame glistens a vibrant red.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: pianos
# Item_Description: ['The pianos sat unplayed and covered in dust. It had been years since they broke the silence of the empty room.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: pianos
# Item_Description: ['The pianos sat unplayed and covered in dust. It had been years since they broke the silence of the empty room.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: pianos
# Item_Description: ['The pianos sat unplayed and covered in dust. It had been years since they broke the silence of the empty room.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: pianos
# Item_Description: ['The pianos sat unplayed and covered in dust. It had been years since they broke the silence of the empty room.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: pianos
# Item_Description: ['The pianos sat unplayed and covered in dust. It had been years since they broke the silence of the empty room.']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: pianos
# Item_Description: ['The pianos sat unplayed and covered in dust. It had been years since they broke the silence of the empty room.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: pianos
# Item_Description: ['The pianos sat unplayed and covered in dust. It had been years since they broke the silence of the empty room.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: glitter
# Item_Description: ['This was very fine looking glitter, almost like powder but it was more sparkly than anything I have ever seen, it seemed to have a magical aura about it.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: glitter
# Item_Description: ['This was very fine looking glitter, almost like powder but it was more sparkly than anything I have ever seen, it seemed to have a magical aura about it.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: glitter
# Item_Description: ['This was very fine looking glitter, almost like powder but it was more sparkly than anything I have ever seen, it seemed to have a magical aura about it.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: glitter
# Item_Description: ['This was very fine looking glitter, almost like powder but it was more sparkly than anything I have ever seen, it seemed to have a magical aura about it.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: glitter
# Item_Description: ['This was very fine looking glitter, almost like powder but it was more sparkly than anything I have ever seen, it seemed to have a magical aura about it.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: glitter
# Item_Description: ['This was very fine looking glitter, almost like powder but it was more sparkly than anything I have ever seen, it seemed to have a magical aura about it.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: glitter
# Item_Description: ['This was very fine looking glitter, almost like powder but it was more sparkly than anything I have ever seen, it seemed to have a magical aura about it.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: benches
# Item_Description: ['The benches were made of carefully crafted iron and adorned with a crest of the royal family.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: benches
# Item_Description: ['The benches were made of carefully crafted iron and adorned with a crest of the royal family.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: benches
# Item_Description: ['The benches were made of carefully crafted iron and adorned with a crest of the royal family.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: benches
# Item_Description: ['The benches were made of carefully crafted iron and adorned with a crest of the royal family.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: benches
# Item_Description: ['The benches were made of carefully crafted iron and adorned with a crest of the royal family.']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: benches
# Item_Description: ['The benches were made of carefully crafted iron and adorned with a crest of the royal family.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: benches
# Item_Description: ['The benches were made of carefully crafted iron and adorned with a crest of the royal family.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: frames
# Item_Description: ['A sturdy wooden frame, stained and held together with nails. Perfect thing for mounting canvass']
# Property_Description: is_container
# True_Or_False: 1.0
# ###
#
# Item: frames
# Item_Description: ['A sturdy wooden frame, stained and held together with nails. Perfect thing for mounting canvass']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: frames
# Item_Description: ['A sturdy wooden frame, stained and held together with nails. Perfect thing for mounting canvass']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: frames
# Item_Description: ['A sturdy wooden frame, stained and held together with nails. Perfect thing for mounting canvass']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: frames
# Item_Description: ['A sturdy wooden frame, stained and held together with nails. Perfect thing for mounting canvass']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: frames
# Item_Description: ['A sturdy wooden frame, stained and held together with nails. Perfect thing for mounting canvass']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: frames
# Item_Description: ['A sturdy wooden frame, stained and held together with nails. Perfect thing for mounting canvass']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: vials of blood
# Item_Description: ['The vial is cracked and seems to have contained some sort of elixir']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: vials of blood
# Item_Description: ['The vial is cracked and seems to have contained some sort of elixir']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: vials of blood
# Item_Description: ['The vial is cracked and seems to have contained some sort of elixir']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: vials of blood
# Item_Description: ['The vial is cracked and seems to have contained some sort of elixir']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: vials of blood
# Item_Description: ['The vial is cracked and seems to have contained some sort of elixir']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: vials of blood
# Item_Description: ['The vial is cracked and seems to have contained some sort of elixir']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: vials of blood
# Item_Description: ['The vial is cracked and seems to have contained some sort of elixir']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: seats
# Item_Description: ['The seat is embedded with expensive diamonds and made of the finest wood']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: seats
# Item_Description: ['The seat is embedded with expensive diamonds and made of the finest wood']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: seats
# Item_Description: ['The seat is embedded with expensive diamonds and made of the finest wood']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: seats
# Item_Description: ['The seat is embedded with expensive diamonds and made of the finest wood']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: seats
# Item_Description: ['The seat is embedded with expensive diamonds and made of the finest wood']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: seats
# Item_Description: ['The seat is embedded with expensive diamonds and made of the finest wood']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: seats
# Item_Description: ['The seat is embedded with expensive diamonds and made of the finest wood']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: pads
# Item_Description: ['these pads are new, extra comfortable and easy to install in the leggings of armor']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: pads
# Item_Description: ['these pads are new, extra comfortable and easy to install in the leggings of armor']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: pads
# Item_Description: ['these pads are new, extra comfortable and easy to install in the leggings of armor']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: pads
# Item_Description: ['these pads are new, extra comfortable and easy to install in the leggings of armor']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: pads
# Item_Description: ['these pads are new, extra comfortable and easy to install in the leggings of armor']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: pads
# Item_Description: ['these pads are new, extra comfortable and easy to install in the leggings of armor']
# Property_Description: is_weapon
# True_Or_False: 1.0
# ###
#
# Item: pads
# Item_Description: ['these pads are new, extra comfortable and easy to install in the leggings of armor']
# Property_Description: is_wearable
# True_Or_False: 1.0
# ###
#
# Item: colorful dyes
# Item_Description: ['There are many leftover colorful dyes. These look like they would be good for coloring clothing.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: colorful dyes
# Item_Description: ['There are many leftover colorful dyes. These look like they would be good for coloring clothing.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: colorful dyes
# Item_Description: ['There are many leftover colorful dyes. These look like they would be good for coloring clothing.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: colorful dyes
# Item_Description: ['There are many leftover colorful dyes. These look like they would be good for coloring clothing.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: colorful dyes
# Item_Description: ['There are many leftover colorful dyes. These look like they would be good for coloring clothing.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: colorful dyes
# Item_Description: ['There are many leftover colorful dyes. These look like they would be good for coloring clothing.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: colorful dyes
# Item_Description: ['There are many leftover colorful dyes. These look like they would be good for coloring clothing.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: small table with a candle
# Item_Description: ['This small wooden table, suitable for setting down your wares, is illuminated by a candle placed in the middle.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: small table with a candle
# Item_Description: ['This small wooden table, suitable for setting down your wares, is illuminated by a candle placed in the middle.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: small table with a candle
# Item_Description: ['This small wooden table, suitable for setting down your wares, is illuminated by a candle placed in the middle.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: small table with a candle
# Item_Description: ['This small wooden table, suitable for setting down your wares, is illuminated by a candle placed in the middle.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: small table with a candle
# Item_Description: ['This small wooden table, suitable for setting down your wares, is illuminated by a candle placed in the middle.']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: small table with a candle
# Item_Description: ['This small wooden table, suitable for setting down your wares, is illuminated by a candle placed in the middle.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: small table with a candle
# Item_Description: ['This small wooden table, suitable for setting down your wares, is illuminated by a candle placed in the middle.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: trident
# Item_Description: ['This trident is very beautiful but deadly']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: trident
# Item_Description: ['This trident is very beautiful but deadly']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: trident
# Item_Description: ['This trident is very beautiful but deadly']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: trident
# Item_Description: ['This trident is very beautiful but deadly']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: trident
# Item_Description: ['This trident is very beautiful but deadly']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: trident
# Item_Description: ['This trident is very beautiful but deadly']
# Property_Description: is_weapon
# True_Or_False: 1.0
# ###
#
# Item: trident
# Item_Description: ['This trident is very beautiful but deadly']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: spider
# Item_Description: ['The tiny spider flaunts bright, iridescent colors notably blue, green and purple.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: spider
# Item_Description: ['The tiny spider flaunts bright, iridescent colors notably blue, green and purple.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: spider
# Item_Description: ['The tiny spider flaunts bright, iridescent colors notably blue, green and purple.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: spider
# Item_Description: ['The tiny spider flaunts bright, iridescent colors notably blue, green and purple.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: spider
# Item_Description: ['The tiny spider flaunts bright, iridescent colors notably blue, green and purple.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: spider
# Item_Description: ['The tiny spider flaunts bright, iridescent colors notably blue, green and purple.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: spider
# Item_Description: ['The tiny spider flaunts bright, iridescent colors notably blue, green and purple.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: grass
# Item_Description: ['The cool, green grass stretched far and wide.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: grass
# Item_Description: ['The cool, green grass stretched far and wide.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: grass
# Item_Description: ['The cool, green grass stretched far and wide.']
# Property_Description: is_food
# True_Or_False: 1.0
# ###
#
# Item: grass
# Item_Description: ['The cool, green grass stretched far and wide.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: grass
# Item_Description: ['The cool, green grass stretched far and wide.']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: grass
# Item_Description: ['The cool, green grass stretched far and wide.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: grass
# Item_Description: ['The cool, green grass stretched far and wide.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: seaweed
# Item_Description: ['The beach is destroyed from the storm, there is seaweed every where.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: seaweed
# Item_Description: ['The beach is destroyed from the storm, there is seaweed every where.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: seaweed
# Item_Description: ['The beach is destroyed from the storm, there is seaweed every where.']
# Property_Description: is_food
# True_Or_False: 1.0
# ###
#
# Item: seaweed
# Item_Description: ['The beach is destroyed from the storm, there is seaweed every where.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: seaweed
# Item_Description: ['The beach is destroyed from the storm, there is seaweed every where.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: seaweed
# Item_Description: ['The beach is destroyed from the storm, there is seaweed every where.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: seaweed
# Item_Description: ['The beach is destroyed from the storm, there is seaweed every where.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: sword
# Item_Description: ['A glimmering, well maintained sword is a sight to behold. You can see your reflection marveling at the gem studded hilt in the polished blade.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: sword
# Item_Description: ['A glimmering, well maintained sword is a sight to behold. You can see your reflection marveling at the gem studded hilt in the polished blade.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: sword
# Item_Description: ['A glimmering, well maintained sword is a sight to behold. You can see your reflection marveling at the gem studded hilt in the polished blade.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: sword
# Item_Description: ['A glimmering, well maintained sword is a sight to behold. You can see your reflection marveling at the gem studded hilt in the polished blade.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: sword
# Item_Description: ['A glimmering, well maintained sword is a sight to behold. You can see your reflection marveling at the gem studded hilt in the polished blade.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: sword
# Item_Description: ['A glimmering, well maintained sword is a sight to behold. You can see your reflection marveling at the gem studded hilt in the polished blade.']
# Property_Description: is_weapon
# True_Or_False: 1.0
# ###
#
# Item: sword
# Item_Description: ['A glimmering, well maintained sword is a sight to behold. You can see your reflection marveling at the gem studded hilt in the polished blade.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: structure
# Item_Description: ['The large structure is grayed and worn from use by knights.']
# Property_Description: is_container
# True_Or_False: 1.0
# ###
#
# Item: structure
# Item_Description: ['The large structure is grayed and worn from use by knights.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: structure
# Item_Description: ['The large structure is grayed and worn from use by knights.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: structure
# Item_Description: ['The large structure is grayed and worn from use by knights.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: structure
# Item_Description: ['The large structure is grayed and worn from use by knights.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: structure
# Item_Description: ['The large structure is grayed and worn from use by knights.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: structure
# Item_Description: ['The large structure is grayed and worn from use by knights.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: walls
# Item_Description: ['The wall was painted blue. The wallpaper appears to have been painted over.']
# Property_Description: is_container
# True_Or_False: 1.0
# ###
#
# Item: walls
# Item_Description: ['The wall was painted blue. The wallpaper appears to have been painted over.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: walls
# Item_Description: ['The wall was painted blue. The wallpaper appears to have been painted over.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: walls
# Item_Description: ['The wall was painted blue. The wallpaper appears to have been painted over.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: walls
# Item_Description: ['The wall was painted blue. The wallpaper appears to have been painted over.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: walls
# Item_Description: ['The wall was painted blue. The wallpaper appears to have been painted over.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: walls
# Item_Description: ['The wall was painted blue. The wallpaper appears to have been painted over.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: shed
# Item_Description: ['A shed is like a llitle house or a garage where you can keep your things, the sheds are usually in the back yards of the houses']
# Property_Description: is_container
# True_Or_False: 1.0
# ###
#
# Item: shed
# Item_Description: ['A shed is like a llitle house or a garage where you can keep your things, the sheds are usually in the back yards of the houses']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: shed
# Item_Description: ['A shed is like a llitle house or a garage where you can keep your things, the sheds are usually in the back yards of the houses']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: shed
# Item_Description: ['A shed is like a llitle house or a garage where you can keep your things, the sheds are usually in the back yards of the houses']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: shed
# Item_Description: ['A shed is like a llitle house or a garage where you can keep your things, the sheds are usually in the back yards of the houses']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: shed
# ...
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: market stand
# Item_Description: ['full of stains and scratches, this market stand seems to have been in use for years.']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: market stand
# Item_Description: ['full of stains and scratches, this market stand seems to have been in use for years.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: market stand
# Item_Description: ['full of stains and scratches, this market stand seems to have been in use for years.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: heavy cloth
# Item_Description: ['The cloth is made of heavy material.  It has a hole in it and a red stain.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: heavy cloth
# Item_Description: ['The cloth is made of heavy material.  It has a hole in it and a red stain.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: heavy cloth
# Item_Description: ['The cloth is made of heavy material.  It has a hole in it and a red stain.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: heavy cloth
# Item_Description: ['The cloth is made of heavy material.  It has a hole in it and a red stain.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: heavy cloth
# Item_Description: ['The cloth is made of heavy material.  It has a hole in it and a red stain.']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: heavy cloth
# Item_Description: ['The cloth is made of heavy material.  It has a hole in it and a red stain.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: heavy cloth
# Item_Description: ['The cloth is made of heavy material.  It has a hole in it and a red stain.']
# Property_Description: is_wearable
# True_Or_False: 1.0
# ###
#
# Item: castle
# Item_Description: ['A stalwart castle built to withstand the heaviest siege.']
# Property_Description: is_container
# True_Or_False: 1.0
# ###
#
# Item: castle
# Item_Description: ['A stalwart castle built to withstand the heaviest siege.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: castle
# Item_Description: ['A stalwart castle built to withstand the heaviest siege.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: castle
# Item_Description: ['A stalwart castle built to withstand the heaviest siege.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: castle
# Item_Description: ['A stalwart castle built to withstand the heaviest siege.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: castle
# Item_Description: ['A stalwart castle built to withstand the heaviest siege.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: castle
# Item_Description: ['A stalwart castle built to withstand the heaviest siege.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: plants
# Item_Description: ['I would imagine these plants would be something to be made into something else. It might be for food, or medicine.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: plants
# Item_Description: ['I would imagine these plants would be something to be made into something else. It might be for food, or medicine.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: plants
# Item_Description: ['I would imagine these plants would be something to be made into something else. It might be for food, or medicine.']
# Property_Description: is_food
# True_Or_False: 1.0
# ###
#
# Item: plants
# Item_Description: ['I would imagine these plants would be something to be made into something else. It might be for food, or medicine.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: plants
# Item_Description: ['I would imagine these plants would be something to be made into something else. It might be for food, or medicine.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: plants
# Item_Description: ['I would imagine these plants would be something to be made into something else. It might be for food, or medicine.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: plants
# Item_Description: ['I would imagine these plants would be something to be made into something else. It might be for food, or medicine.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: paintings
# Item_Description: ['Bring on the prehistoric cave painting']
# Property_Description: is_container
# True_Or_False: 1.0
# ###
#
# Item: paintings
# Item_Description: ['Bring on the prehistoric cave painting']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: paintings
# Item_Description: ['Bring on the prehistoric cave painting']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: paintings
# Item_Description: ['Bring on the prehistoric cave painting']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: paintings
# Item_Description: ['Bring on the prehistoric cave painting']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: paintings
# Item_Description: ['Bring on the prehistoric cave painting']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: paintings
# Item_Description: ['Bring on the prehistoric cave painting']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: stream
# Item_Description: ['And they move up the value stream of the econamy']
# Property_Description: is_container
# True_Or_False: 1.0
# ###
#
# Item: stream
# Item_Description: ['And they move up the value stream of the econamy']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: stream
# Item_Description: ['And they move up the value stream of the econamy']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: stream
# Item_Description: ['And they move up the value stream of the econamy']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: stream
# Item_Description: ['And they move up the value stream of the econamy']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: stream
# Item_Description: ['And they move up the value stream of the econamy']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: stream
# Item_Description: ['And they move up the value stream of the econamy']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: precious stones
# Item_Description: ['The stone is cut into a diamond shape and shines a bright blue color.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: precious stones
# Item_Description: ['The stone is cut into a diamond shape and shines a bright blue color.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: precious stones
# Item_Description: ['The stone is cut into a diamond shape and shines a bright blue color.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: precious stones
# Item_Description: ['The stone is cut into a diamond shape and shines a bright blue color.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: precious stones
# Item_Description: ['The stone is cut into a diamond shape and shines a bright blue color.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: precious stones
# Item_Description: ['The stone is cut into a diamond shape and shines a bright blue color.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: precious stones
# Item_Description: ['The stone is cut into a diamond shape and shines a bright blue color.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: rocky cliffs
# Item_Description: ['The haunting, gray cliffs rest aside the ocean']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: rocky cliffs
# Item_Description: ['The haunting, gray cliffs rest aside the ocean']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: rocky cliffs
# Item_Description: ['The haunting, gray cliffs rest aside the ocean']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: rocky cliffs
# Item_Description: ['The haunting, gray cliffs rest aside the ocean']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: rocky cliffs
# Item_Description: ['The haunting, gray cliffs rest aside the ocean']
# Property_Description: is_surface
# True_Or_False: 1.0
# ###
#
# Item: rocky cliffs
# Item_Description: ['The haunting, gray cliffs rest aside the ocean']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: rocky cliffs
# Item_Description: ['The haunting, gray cliffs rest aside the ocean']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: dusty rug
# Item_Description: ['The rug was once beautifully patterned but has now become dusty and tattered after decades of abuse.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: dusty rug
# Item_Description: ['The rug was once beautifully patterned but has now become dusty and tattered after decades of abuse.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: dusty rug
# Item_Description: ['The rug was once beautifully patterned but has now become dusty and tattered after decades of abuse.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: dusty rug
# Item_Description: ['The rug was once beautifully patterned but has now become dusty and tattered after decades of abuse.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: dusty rug
# Item_Description: ['The rug was once beautifully patterned but has now become dusty and tattered after decades of abuse.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: dusty rug
# Item_Description: ['The rug was once beautifully patterned but has now become dusty and tattered after decades of abuse.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: dusty rug
# Item_Description: ['The rug was once beautifully patterned but has now become dusty and tattered after decades of abuse.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: jukebox
# Item_Description: ['The jukebox is loud and purple in appearance.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: jukebox
# Item_Description: ['The jukebox is loud and purple in appearance.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: jukebox
# Item_Description: ['The jukebox is loud and purple in appearance.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: jukebox
# Item_Description: ['The jukebox is loud and purple in appearance.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: jukebox
# Item_Description: ['The jukebox is loud and purple in appearance.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: jukebox
# Item_Description: ['The jukebox is loud and purple in appearance.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: jukebox
# Item_Description: ['The jukebox is loud and purple in appearance.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: good drinks
# Item_Description: ['The good drink is frothy, fizzy, and clear.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: good drinks
# Item_Description: ['The good drink is frothy, fizzy, and clear.']
# Property_Description: is_drink
# True_Or_False: 1.0
# ###
#
# Item: good drinks
# Item_Description: ['The good drink is frothy, fizzy, and clear.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: good drinks
# Item_Description: ['The good drink is frothy, fizzy, and clear.']
# Property_Description: is_gettable
# True_Or_False: 0.0
# ###
#
# Item: good drinks
# Item_Description: ['The good drink is frothy, fizzy, and clear.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: good drinks
# Item_Description: ['The good drink is frothy, fizzy, and clear.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: good drinks
# Item_Description: ['The good drink is frothy, fizzy, and clear.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: globes and scales
# Item_Description: ['Your attention is drawn first to the detailed borders on the globe, then to the glimmering gold finish of the scales. This equipment is high quality, no doubt about it.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: globes and scales
# Item_Description: ['Your attention is drawn first to the detailed borders on the globe, then to the glimmering gold finish of the scales. This equipment is high quality, no doubt about it.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: globes and scales
# Item_Description: ['Your attention is drawn first to the detailed borders on the globe, then to the glimmering gold finish of the scales. This equipment is high quality, no doubt about it.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: globes and scales
# Item_Description: ['Your attention is drawn first to the detailed borders on the globe, then to the glimmering gold finish of the scales. This equipment is high quality, no doubt about it.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: globes and scales
# Item_Description: ['Your attention is drawn first to the detailed borders on the globe, then to the glimmering gold finish of the scales. This equipment is high quality, no doubt about it.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: globes and scales
# Item_Description: ['Your attention is drawn first to the detailed borders on the globe, then to the glimmering gold finish of the scales. This equipment is high quality, no doubt about it.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: globes and scales
# Item_Description: ['Your attention is drawn first to the detailed borders on the globe, then to the glimmering gold finish of the scales. This equipment is high quality, no doubt about it.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: bones
# Item_Description: ['Dry and brittle from years in the harsh sun, the bone is bleached perfectly white.']
# Property_Description: is_container
# True_Or_False: 0.0
# ###
#
# Item: bones
# Item_Description: ['Dry and brittle from years in the harsh sun, the bone is bleached perfectly white.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: bones
# Item_Description: ['Dry and brittle from years in the harsh sun, the bone is bleached perfectly white.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: bones
# Item_Description: ['Dry and brittle from years in the harsh sun, the bone is bleached perfectly white.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: bones
# Item_Description: ['Dry and brittle from years in the harsh sun, the bone is bleached perfectly white.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: bones
# Item_Description: ['Dry and brittle from years in the harsh sun, the bone is bleached perfectly white.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: bones
# Item_Description: ['Dry and brittle from years in the harsh sun, the bone is bleached perfectly white.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###
#
# Item: barrels
# Item_Description: ['The barrel fills to the top and sparkles with clear liquid.']
# Property_Description: is_container
# True_Or_False: 1.0
# ###
#
# Item: barrels
# Item_Description: ['The barrel fills to the top and sparkles with clear liquid.']
# Property_Description: is_drink
# True_Or_False: 0.0
# ###
#
# Item: barrels
# Item_Description: ['The barrel fills to the top and sparkles with clear liquid.']
# Property_Description: is_food
# True_Or_False: 0.0
# ###
#
# Item: barrels
# Item_Description: ['The barrel fills to the top and sparkles with clear liquid.']
# Property_Description: is_gettable
# True_Or_False: 1.0
# ###
#
# Item: barrels
# Item_Description: ['The barrel fills to the top and sparkles with clear liquid.']
# Property_Description: is_surface
# True_Or_False: 0.0
# ###
#
# Item: barrels
# Item_Description: ['The barrel fills to the top and sparkles with clear liquid.']
# Property_Description: is_weapon
# True_Or_False: 0.0
# ###
#
# Item: barrels
# Item_Description: ['The barrel fills to the top and sparkles with clear liquid.']
# Property_Description: is_wearable
# True_Or_False: 0.0
# ###

# %%
# !head fine_tuning_single_item_property.jsonl
# Out:
# {"prompt": "Item: towering pine trees\nItem_Description: ['the tree is tall and leafy']\nProperty_Description: is_container\n", "completion": "True_Or_False: 0.0\n###\n"}
# {"prompt": "Item: towering pine trees\nItem_Description: ['the tree is tall and leafy']\nProperty_Description: is_drink\n", "completion": "True_Or_False: 0.0\n###\n"}
# {"prompt": "Item: towering pine trees\nItem_Description: ['the tree is tall and leafy']\nProperty_Description: is_food\n", "completion": "True_Or_False: 0.0\n###\n"}
# {"prompt": "Item: towering pine trees\nItem_Description: ['the tree is tall and leafy']\nProperty_Description: is_gettable\n", "completion": "True_Or_False: 1.0\n###\n"}
# {"prompt": "Item: towering pine trees\nItem_Description: ['the tree is tall and leafy']\nProperty_Description: is_surface\n", "completion": "True_Or_False: 0.0\n###\n"}
# {"prompt": "Item: towering pine trees\nItem_Description: ['the tree is tall and leafy']\nProperty_Description: is_weapon\n", "completion": "True_Or_False: 0.0\n###\n"}
# {"prompt": "Item: towering pine trees\nItem_Description: ['the tree is tall and leafy']\nProperty_Description: is_wearable\n", "completion": "True_Or_False: 0.0\n###\n"}
# {"prompt": "Item: Long skinny trees\nItem_Description: [\"the tree has so tall and skinny it was as if it almost couldn't be seen\", 'This tree stretches up into the sky, although it seems a bit too slender for you to climb.  The bark is white with mottled patches of black on it, and its leaves are a deep emerald green hue.']\nProperty_Description: is_container\n", "completion": "True_Or_False: 0.0\n###\n"}
# {"prompt": "Item: Long skinny trees\nItem_Description: [\"the tree has so tall and skinny it was as if it almost couldn't be seen\", 'This tree stretches up into the sky, although it seems a bit too slender for you to climb.  The bark is white with mottled patches of black on it, and its leaves are a deep emerald green hue.']\nProperty_Description: is_drink\n", "completion": "True_Or_False: 0.0\n###\n"}
# {"prompt": "Item: Long skinny trees\nItem_Description: [\"the tree has so tall and skinny it was as if it almost couldn't be seen\", 'This tree stretches up into the sky, although it seems a bit too slender for you to climb.  The bark is white with mottled patches of black on it, and its leaves are a deep emerald green hue.']\nProperty_Description: is_food\n", "completion": "True_Or_False: 0.0\n###\n"}

# %%
# !openai api fine_tunes.create -t fine_tuning_single_item_property.jsonl -m curie
# Out:
# Upload progress: 100% 2.69M/2.69M [00:00<00:00, 5.23Git/s]
# Uploaded file from fine_tuning_single_item_property.jsonl: file-BLR5HrxDGE8x0bF7XN36IWRc
# Created fine-tune: ft-lo4O9zmygNjxibLcPIbztVXy
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2022-01-30 01:13:47] Created fine-tune: ft-lo4O9zmygNjxibLcPIbztVXy
# [2022-01-30 01:13:56] Fine-tune costs $7.58
# [2022-01-30 01:13:57] Fine-tune enqueued. Queue number: 0
# [2022-01-30 01:14:01] Fine-tune started
#
# Stream interrupted (client disconnected).
# To resume the stream, run:
#
#   openai api fine_tunes.follow -i ft-lo4O9zmygNjxibLcPIbztVXy

# %%
# !openai api fine_tunes.follow -i ft-lo4O9zmygNjxibLcPIbztVXy
# Out:
# [2022-01-30 01:13:47] Created fine-tune: ft-lo4O9zmygNjxibLcPIbztVXy
# [2022-01-30 01:13:56] Fine-tune costs $7.58
# [2022-01-30 01:13:57] Fine-tune enqueued. Queue number: 0
# [2022-01-30 01:14:01] Fine-tune started
# [2022-01-30 01:22:55] Completed epoch 1/4
# [2022-01-30 01:31:05] Completed epoch 2/4
# [2022-01-30 01:39:16] Completed epoch 3/4
# [2022-01-30 01:47:27] Completed epoch 4/4
# [2022-01-30 01:47:54] Uploaded model: curie:ft-cis-700-31-2022-01-30-01-47-52
# [2022-01-30 01:47:57] Uploaded result file: file-LuljqyvT9WcaoqcFLT5qHmwi
# [2022-01-30 01:47:57] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m curie:ft-cis-700-31-2022-01-30-01-47-52 -p <YOUR_PROMPT>

# %%
def get_item_property(property_name, item_name, item_description, finetuned_model, property_description=""):
  response = openai.Completion.create(
      model=finetuned_model,
      prompt="Item: {item}\nItem_Description: {description}\nProperty_Description: {property_des}\nTrue_Or_False:".format(
          item=item_name,
          description=item_description,
          property_des=property_description
      ),
      temperature=0.7,
      max_tokens=64,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0,
      stop=["###"]
      )
  return float(response['choices'][0]['text'].strip()[:3])==1.0

def is_gettable(item_name, item_description, finetuned_model, property_description="A player can pick this item up and add it to their inventory."):
  return get_item_property("is_gettable", item_name, item_description, finetuned_model, property_description)

def is_weapon(item_name, item_description, finetuned_model, property_description="This item can be used as a weapon."):
  return get_item_property("is_weapon", item_name, item_description, finetuned_model, property_description)

def is_surface(item_name, item_description, finetuned_model, property_description="Another item can be placed on top of this item."):
  return get_item_property("is_surface", item_name, item_description, finetuned_model, property_description)

def is_container(item_name, item_description, finetuned_model, property_description="Other items can be stored inside of this item."):
  return get_item_property("is_container", item_name, item_description, finetuned_model, property_description)

def is_wearable(item_name, item_description, finetuned_model, property_description="This item can be worn as an item of cloting."):
  return get_item_property("is_wearable", item_name, item_description, finetuned_model, property_description)

def is_drink(item_name, item_description, finetuned_model, property_description="This item is a liquid that can be drunk."):
  return get_item_property("is_drink", item_name, item_description, finetuned_model, property_description)

def is_food(item_name, item_description, finetuned_model, property_description="This item can be eaten."):
  return get_item_property("is_food", item_name, item_description, finetuned_model, property_description)

print(is_gettable("water", "water tastes good", "curie:ft-cis-700-31-2022-01-30-01-47-52"))
print(is_weapon("water", "water tastes good", "curie:ft-cis-700-31-2022-01-30-01-47-52"))
print(is_surface("water", "water tastes good", "curie:ft-cis-700-31-2022-01-30-01-47-52"))
print(is_container("water", "water tastes good", "curie:ft-cis-700-31-2022-01-30-01-47-52"))
print(is_wearable("water", "water tastes good", "curie:ft-cis-700-31-2022-01-30-01-47-52"))
print(is_drink("water", "water tastes good", "curie:ft-cis-700-31-2022-01-30-01-47-52"))
print(is_food("water", "water tastes good", "curie:ft-cis-700-31-2022-01-30-01-47-52"))
# Out:
# True
# True
# False
# False
# False
# True
# False

# %% [markdown]
# # TODO: Generate A Game
#
# You now have all of the pieces that you need to generate a game!
#
# Build a game using your automatic methods, and then export it in the same JSON format as the LIGHT Environment Data.
#
# You'll upload your JSON file to Gradescope along with this notebook.
#
# If you'd like, you can build a game using the same theme and location names as the one that you did in HW1.

# %%
#Escape Room Game (categories, rooms, neighbors, objects)
def build_game(category="apartment", initial_location_name="bedroom"):
  #return get_connections("apartment", "bedroom", "you wake up in the bedroom", "curie:ft-cis-700-31-2022-01-29-23-57-53", "")
  room_count=1
  connection_count=0
  object_count=0
  myDict={"categories": {"1": category}}
  myDict["rooms"]={}
  myDict["neighbors"]={}
  myDict["objects"]={}
  rooms_visited=set()
  rooms_visited.add(initial_location_name.strip().capitalize())
  objects_visited={}
  flag = 1
  def set_up(location_name):
    nonlocal room_count, connection_count, object_count, myDict, rooms_visited, objects_visited, flag
    if flag == 10:
      return
    flag+=1
    myDict["rooms"][str(room_count)]={"category": category, "setting": location_name}
    description = get_location_description(category, location_name, "curie:ft-cis-700-31-2022-01-28-18-27-32")
    in_objects = get_items_at_location(category, location_name, description, "curie:ft-cis-700-31-2022-01-30-18-34-23")
    tmp=[]
    for obj in in_objects:
      if obj not in objects_visited:
        object_count+=1
        objects_visited[obj.strip().capitalize()]=object_count
        item_description=get_item_description(category, obj, "curie:ft-cis-700-31-2022-01-29-02-12-53", location_name)
        myDict["objects"][str(object_count)]={}
        myDict["objects"][str(object_count)]["is_container"]=float(is_container(obj, item_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))
        myDict["objects"][str(object_count)]["is_drink"]=float(is_drink(obj, item_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))
        myDict["objects"][str(object_count)]["is_food"]=float(is_food(obj, item_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))
        myDict["objects"][str(object_count)]["is_gettable"]=float(is_gettable(obj, item_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))
        myDict["objects"][str(object_count)]["is_surface"]=float(is_surface(obj, item_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))
        myDict["objects"][str(object_count)]["is_wearable"]=float(is_wearable(obj, item_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))
        myDict["objects"][str(object_count)]["is_weapon"]=float(is_weapon(obj, item_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))
        myDict["objects"][str(object_count)]["name"]=obj
      tmp.append(objects_visited[obj.strip().capitalize()])
    myDict["rooms"][str(room_count)]["in_objects"] = tmp
    myDict["rooms"][str(room_count)]["description"] = description
    myDict["rooms"][str(room_count)]["neighbors"] = []
    connections = get_connections(category, location_name, str(description), "curie:ft-cis-700-31-2022-01-29-23-57-53", str([]))
    neighbors=[]
    original_room_count=room_count
    for direction, neighbor in connections:
      connection_count+=1
      myDict["rooms"][str(original_room_count)]["neighbors"].append(connection_count)
      myDict["neighbors"][str(connection_count)]={"destination": neighbor, "direction": direction, "room_id": original_room_count}
      if neighbor not in rooms_visited:
        room_count+=1
        rooms_visited.add(neighbor.strip().capitalize())
        set_up(neighbor)
  set_up(initial_location_name)
  game = myDict
  return game

game = build_game()

# %%
def export_game_json(game, output_filename="my_gpt3_game.json"):
  with open(output_filename, "w") as outfile:
    json.dump(game, outfile, indent=4)

export_game_json(game)

# %% [markdown]
# # TODO: Evaluation
#
# An important part of NLP and machine learning is determining how good your models are.  It's very tricky to reliably evaluate generation output automatically.  For now, we'll evaluate the predictions of the model.
#
# For your model's attribute predictions, you should compute it's precision and recall for each attribute type on the LIGHT development data.

# %%
# !wget https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class-data/master/light_dialogue/light_environment_dev.json
# Out:
# --2022-01-30 20:38:24--  https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class-data/master/light_dialogue/light_environment_dev.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 485111 (474K) [text/plain]
# Saving to: ‘light_environment_dev.json’
#
# light_environment_d 100%[===================>] 473.74K  --.-KB/s    in 0.03s
#
# 2022-01-30 20:38:24 (16.9 MB/s) - ‘light_environment_dev.json’ saved [485111/485111]

# %%
f = open('light_environment_dev.json')
light_environment_dev = json.load(f)
gold_standard_objects_by_property = sort_objects_by_property(light_environment_dev['objects'])

# You can modify this function definition
def compute_precision_and_recall_for_each_properites(gold_standard_objects_by_property):
  properties = ["is_gettable", "is_weapon", "is_surface", "is_container", "is_wearable", "is_drink", "is_food"]
  total_count=0
  correct=0
  for property in properties:
    for obj_number in gold_standard_objects_by_property[property]:
      obj_name=light_environment_dev['objects'][obj_number]["name"]
      obj_description=str(light_environment_dev['objects'][obj_number]["descriptions"])
      property_score=light_environment_dev['objects'][obj_number][property]
      if property=="is_gettable":
        correct+=float(is_gettable(obj_name, obj_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))==property_score
      if property=="is_weapon":
        correct+=float(is_weapon(obj_name, obj_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))==property_score
      if property=="is_surface":
        correct+=float(is_surface(obj_name, obj_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))==property_score
      if property=="is_container":
        correct+=float(is_container(obj_name, obj_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))==property_score
      if property=="is_wearable":
        correct+=float(is_wearable(obj_name, obj_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))==property_score
      if property=="is_drink":
        correct+=float(is_drink(obj_name, obj_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))==property_score
      if property=="is_food":
        correct+=float(is_food(obj_name, obj_description, "curie:ft-cis-700-31-2022-01-30-01-47-52"))==property_score
      total_count+=1
  return correct/total_count

compute_precision_and_recall_for_each_properites(gold_standard_objects_by_property)
# Out:
# 0.5518394648829431
